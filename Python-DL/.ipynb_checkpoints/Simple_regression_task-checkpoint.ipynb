# %% [markdown]
# # Deep learning programming I-A: Regression
# Felix Wiewel, Institute of Signal Processing and System Theory, University of Stuttgart, 24.04.2020
#
# ## Introduction
# This programming exercise is the first of a series of exercises, which are intended as a supplement to the theoretical part of the Deep Learning course offered by the ISS. The goal is to introduce you to basic tasks and applications of methods you have encountered in the lecture. After completing the exercise you should be familiar with the basic ideas and one, possibly simple, way of solving the respective task. It is worth mentioning that most of the tasks can be solved in many different, not necessarily deep learning based, ways and the solution presented here is just one of them.
#
# ## Regression
#
# In this exercise we consider the problem of regression, where we are interested in modeling a functional dependence between different variables with, possibly noisy, observations of input-output pairs. Mathematically such a dependence can be formulated as
#
# $\mathbf{y}=f(\mathbf{x})+\boldsymbol{\epsilon}$,
#
# where $\mathbf{y}\in\mathbb{R}^{M}$ and $\mathbf{x}\in\mathbb{R}^{N}$ are the input and output observations, $f:\mathbb{R}^{N}\rightarrow\mathbb{R}^{M}$ is the function mapping inputs to outputs and $\boldsymbol{\epsilon}\in\mathbb{R}^{M}$ is a random vector, which models noise in our observations. Note that this assumes additive noise that only acts on the output and not on the input variable, which might not be true in all practical applications but is a reasonable approximation. For regression we are now interested in estimating the functional relationship $f$ between the inputs and outputs. This can be done in many different ways, not just with neural networks, but for this exercise we focus on approximating this relationship with a neural network $g_{\boldsymbol{\theta}}:\mathbb{R}^{N}\rightarrow\mathbb{R}^{M}$ with parameter vector $\boldsymbol{\theta}$. The task is now to choose the parameters of the neural network in a way that results in a "good" approximation of $f$ with $g_{\boldsymbol{\theta}}$.
#
# In order to quantify how "good" our neural network can approximate $f$, we adopt a probabilistic view. For this we make the assumption that the noise $\boldsymbol{\epsilon}$ is a random vector drawn from a known dustribution, which enables us to derive a suitable cost function for training our neural network and also for quantifying a "good" approximation.
#
# ### Mathematical formulation
# If we assume that the noise $\boldsymbol{\epsilon}$ is drawn from a gaussian distribution, e.g. $\boldsymbol{\epsilon}\sim\mathcal{N}(\mathbf{0},\sigma^{2}\mathbf{I})$, we can use
#
# $\mathbf{y}=g_{\boldsymbol{\theta}}(\mathbf{x})+\boldsymbol{\epsilon}\Rightarrow \mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})=\boldsymbol{\epsilon}$
#
# to derive a log likelihood. Since the probability density function (pdf) of a multivariate normal distribution is given by
#
# $p(\mathbf{x})=\dfrac{1}{\sqrt{(2\pi)^{D}\vert\mathbf{C}\vert}}\mathrm{e}^{-\dfrac{1}{2}(\mathbf{x}-\boldsymbol{\mu})\mathbf{C}^{-1}(\mathbf{x}-\boldsymbol{\mu})^{T}}$,
#
# we get
#
# $\ln{p(\boldsymbol{\epsilon})}=\ln{\dfrac{1}{\sqrt{(2\pi)^{M}\sigma^{2}}}\mathrm{e}^{-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\epsilon}\Vert_{2}^{2}}}=-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\epsilon}\Vert_{2}^{2}-\dfrac{1}{2}\ln{(2\pi)^{M}\sigma^{2}}$.
#
# Replacing $\boldsymbol{\epsilon}$ by $\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})$ yields the log likelihood for one particular input-output pair:
#
# $\mathcal{L}(\mathbf{x},\mathbf{y},\boldsymbol{\theta})=\ln {p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})}=-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})}\Vert_{2}^{2}-\dfrac{1}{2}\ln{(2\pi)^{M}\sigma^{2}}$
#
# This log likelihood measures how likely the input-output pair is and we can use it to train our neural network. For this we maximize the expected log likelihood over all input-output pairs under the assumption that the noise is idependent and identically distributed (i.i.d.) over all input-output pairs. This corresponds to finding the parameters $\boldsymbol{\theta}^{\star}$ of our neural network, which maximize the the expected probability for observing the corresponding input-output pairs. Mathematically the optimal parameters for our neural network are given by
#
# $\boldsymbol{\theta}^{\star}=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[\mathcal{L}(\mathbf{x},\mathbf{y},\boldsymbol{\theta})\right]=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[-\Vert\boldsymbol{\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})}\Vert_{2}^{2}\right]\approx\arg\min_{\boldsymbol{\theta}}\dfrac{1}{N_{D}}\sum_{i=1}^{N_{D}}\Vert\boldsymbol{\mathbf{y}_{i}-g_{\boldsymbol{\theta}}(\mathbf{x}_{i})}\Vert_{2}^{2}$,
#
# where all terms, which are independent of $\boldsymbol{\theta}$, are ignored and the expectation operator is approximated by the mean over all $N_{D}$ input-output pairs. In other words we are maximizing the log likelihood by minimizing the mean squared error loss over all input-output pairs in our dataset, hence this approach is called Maximum Likelihood (ML) estimation. For solving this optimization problem and obtaining the optimal network parameters, stochastic gradient descent (SGD) or one of it's many variants is typically used.
#
# It is worth noting, that choosing different distributions for the noise $\boldsymbol{\epsilon}$ leads to different log likelihoods and therefore different cost functions for training the neural network. Another commonly used distribution for modelling the noise in regression tasks is the laplace distribution. Deriving the log likelihood and the corresponding costfunction leads to the mean absolute error, which is given by the $l_{1}$-norm of the difference between observations predictions of the neural network. This cost function is considered more robust against outliers since these have less influence on the averall loss compared to the mean squared error.
#
# ###  Implementation
#
# In the following we consider a simple regression task, implement a neural network and train it based on the mathematical fomrulation above. For this we first need to create a set of input-output pairs, which then needs to be partitioned into a training, validation and test set. We also define some constants to be used for partitioning the data and the hyperparameters for our neural network.
#
# But before we can start, we need to import the necessary packages tensorflow, numpy and matplotlib.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
config = tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# Next we define our constants and set the random seeds of tensorflow and numpy in order to get reproducable results.

# %%
N_train_samples = 600
N_validation_samples = 100
N_test_samples = 100
N_samples = N_train_samples + N_validation_samples + N_test_samples
noise_sig = 0.1
N_epochs = 500
batch_size = 8
learning_rate = 0.01

tf.random.set_seed(0)
np.random.seed(0)

# %% [markdown]
# We create $600$ training samples, $100$ validation samples to optimize our hyperparameters and $100$ test samples, which are used to check if our model can generalize to unseen data. Furthermore we set the level of noise added to the observations. For training the model we plan to train it for $150$ epochs with a batch size of $8$ and a learning rate of $0.01$. Next we create the actual input-output pairs $\mathbf{x},\mathbf{y}$ for which we want to learn the regression model and plot them. In this simple example we choose scalar inputs as well as output but in general $\mathbf{x}$ and $\mathbf{y}$ can be vectors.

# %%
x = np.linspace(0.0, 3.0, N_samples, dtype=np.float32)
y = np.expand_dims(np.sin(1.0+x*x) + noise_sig*np.random.randn(N_samples).astype(np.float32), axis=-1)
y_true = np.sin(1.0+x*x)

plt.plot(x, y)
plt.plot(x, y_true)
plt.legend(["Observation", "Ground truth"])
plt.show()

# %% [markdown]
# With the input-output pairs created, your first task is now to partition the data in the training, validation and test sets. Keep in mind that we have created the data in a structured way, i.e. the input-output pairs are ordered. This means you need to shuffle the data before partitioning it.

# %%
""" Shuffle and partition the data set accordingly. you can use the predefined constants "N_train_samples", "N_validation_samples" and "N_test_samples". Use the variable names that are already in the below code 
to store the final shuffled and partitioned data. Hint: Shuffle the data and the labels in such a way that the pairing between an image and it's label is preserved."""
# Shuffle the data
y_reshaped = y.reshape(1,800)
y_full = np.vstack((y_reshaped[0], y_true))
full_array  = np.vstack((y_full, x)).T
# full_array.dtype
# full_array.shape
np.random.shuffle(full_array)
""" full array[0] is y  , full array[1] is y_true , full array[2] is all shuffled the same way  , without the transpose operator an array of tuples is returned"""
full_array = full_array.T
""" when other packages are allowed another solution would be
from sklearn.utils import shuffle
y_reshaped = y.reshape(1,800)
y_shuffeled, x_shuffled = shuffle(y_reshaped[0], x)"""
# Partition the data
x_train = full_array[2, 0:N_train_samples] 
y_train = full_array[0, 0:N_train_samples]
x_validation = full_array[2, N_train_samples:N_train_samples+ N_validation_samples]
y_validation = full_array[0, N_train_samples:N_train_samples+ N_validation_samples]
x_test = full_array[2, N_train_samples+ N_validation_samples:N_train_samples+ N_validation_samples +N_test_samples]
y_test = full_array[0, N_train_samples+ N_validation_samples:N_train_samples+ N_validation_samples +N_test_samples]
# len(x_train)
# len(x_validation)
# len(x_test)

# %% [markdown]
# In order to feed the data to our model, we will use the Dataset class provided by Tensorflow. This class is simple to use and provides all the functionality we need for shuffling, batching and feeding the data to our model. It is also tightly integrated into the Tensorflow framework, which makes it very performant. Performance is not an aspect we need to worry about in this exercise, but it is important in more demanding applications.
#
# In this exercise we instantiate a separate Dataset object for the training, validation and test data sets, where we shuffle and repeat just the training data set. Shuffling the validation and test data sets is not necessary, since we only evaluate the loss on those data sets and do not perform SGD on it. Please fill in the missing part of the code.

# %%
""" Create three tensorflow Dataset objects that can be used to feed the training test and validation data to a neural network. Hint: For the training data set use shuffling, batching with the size according to
the predefined constant "batch_size" and repeat the data set indefinetly. For the validation and test data sets no shuffling or batching is needed."""

train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_ds = train_ds.repeat(20)
train_ds = train_ds.shuffle(12000)
train_ds =train_ds.batch(batch_size=batch_size)
""" Implementation from the second part produces worse results than shuffling after repeating"""
#train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(N_train_samples).batch(batch_size).repeat()
validation_ds = tf.data.Dataset.from_tensor_slices([(x_validation, y_validation)])
test_ds = tf.data.Dataset.from_tensor_slices([(x_test, y_test)])

# %% [markdown]
# In this exercise we will create a a simple neural network with two hidden layers containing $10$ neurons. For creating a model and keeping track of its weights a class called MyModel is used. When initializing an instance of this class the necessary variables are created and stored in a list called "trainable_variables". This makes it easy to get all trainable variables of the model. We also override the \__call__ method of this class in order to implement the forward pass of the neural network. This method should accept the inputs to the neural network and should return the result of the forward pass as an output. Please fill in the missing part of the code and select suitable activation functions for the different layers.

# %%
""" Implement a neural network with two hidden dense layers containing 10 neurons each. As an activation function use the tangens hyperbolicus (tf.nn.tanh()). Since we are not using Keras, we need to create and 
manage all the variables that we need ourselves. The varaibles are created in the constructor of our model class. Since we want to be able to just call the class with some inputs in order to make a prediction, 
we implement a __call__ method which computes the forward pass and returns the output of the network."""
initializer = tf.initializers.glorot_uniform()
# use tanh to activate
#initializer(10)
class MyModel(object):
    def __init__(self):
        # Create model variables
        self.W0 = tf.Variable(name = 'weight_0',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([1, 10])))
        self.b0 = tf.Variable(name = 'bias_0',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([ 10])))
        self.W1 = tf.Variable(name = 'weight_1',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([10, 10])))
        self.b1 = tf.Variable(name = 'bias_1',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([ 10])))
        self.W2 = tf.Variable(name = 'weight_2',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([10, 1])))
        self.b2 = tf.Variable(name = 'bias_2',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([ 1])))
        self.trainable_variables = [self.W0, self.b0, self.W1, self.b1, self.W2, self.b2]

    def __call__(self, inputs):
        # Compute forward pass
        output = tf.reshape(inputs, [-1, 1])
        output = tf.nn.tanh( tf.add(tf.matmul(output, self.W0), self.b0))
        output =tf.nn.tanh( tf.add(tf.matmul(output, self.W1), self.b1))
        output = tf.add(tf.matmul(output, self.W2), self.b2)
        return output

# %% [markdown]
# Now after the model class is defined we can instantiate a MyModel object by running

# %%
mdl = MyModel()

# %% [markdown]
# We can now use the model to make predictions by calling it. In the following we predict on the inputs an plot the result.

# %%
""" We want to plot a prediction on the complete data set with a model before training. For this make a prediction on the variable "x". """

y_pred = mdl.__call__(x)
plt.plot(x, y)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# Since we have initialized the variables of the neural network randomly, it's prediction is also random. In order to fit the model we need to minimize the expected mean squared error over all input-ouput pairs in our training data set. For this we need to create a function, that performs a training step when provided with the model, an optimizer and a batch of input-ouput pairs.

# %%
""" For training we need to implement a function that executes one training step. Fill in the missing code pieces for this function."""

def train_step(model, optimizer, x, y):
    with tf.GradientTape() as tape:
        tape.watch(model.trainable_variables)
        y_pred = model.__call__(x)# Compute a prediction with "model" on the input "x"
        y = tf.reshape(y, [-1,1])
        loss_val = tf.compat.v1.losses.mean_squared_error(y, y_pred) # Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y"
    grads = tape.gradient(loss_val, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    return loss_val

# %% [markdown]
# This function uses the GradientTape to record the operations for which gradients have to be calculated. In our case this is the forward pass through our model and the computation of the loss function. After these operations are recoded we can get their gradients and apply these through the use of an optimizer. Finally we return the loss value in order to print it.
#
# With the training step function defined we now need to choose a suitable optimizer. Tensorflow offers a wide variety of optimizers but in this exercise we will use the RMSprop optimizer.

# %%
opt = tf.optimizers.RMSprop(learning_rate)

# %% [markdown]
# We now have everything we need to start training the model. For this we repeatedly sample a batch of input-output pairs from our training data set and use the train_step function to minimize the loss function over this batch. We repeat this until we have iterated over the complete training data set once. After this we compute the loss on the validation data set, print it and repeat with another epoch until we have reached $N\_epochs$ epochs.

# %%
""" We can now use the train_step function to perform the training. Fill in the missing code parts."""

epoch = 0
train_iters = 0
train_loss = 0.0
for x_t, y_t in train_ds:
    train_loss += train_step(mdl, opt, x_t,y_t) # Perform a training step with the model "mdl" and the optimizer "opt" on the inputs "x_t" and the corresponding targets "y_t"
    train_iters += 1
    if train_iters == N_train_samples/batch_size :  # An epoch is completed
        for x_v, y_v in validation_ds:
            y_pred = mdl.__call__(x_v)# Compute a prediction with "mdl" on the input "x_v"
            y_v =tf.reshape(y_v, [-1,1])
            validation_loss =tf.compat.v1.losses.mean_squared_error(y_v, y_pred) # Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_v"
        print('epoch' +str(epoch))
        print('train_loss' + str(train_loss))
        print('train_iters' + str(train_iters))
        print('val_loss' + str(validation_loss))
        #print('val_iters' + str(val_iters))    
        print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
        train_iters = 0
        train_loss = 0.0
        epoch += 1
    if (epoch == N_epochs):
        break
# Out:
# epoch0
# train_losstf.Tensor(19.85639, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.14753537, shape=(), dtype=float32)
# Epoch: 0 Train loss: 0.26475 Validation loss: 0.14754
# epoch1
# train_losstf.Tensor(11.446978, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.07083461, shape=(), dtype=float32)
# Epoch: 1 Train loss: 0.15263 Validation loss: 0.070835
# epoch2
# train_losstf.Tensor(8.373209, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.07214807, shape=(), dtype=float32)
# Epoch: 2 Train loss: 0.11164 Validation loss: 0.072148
# epoch3
# train_losstf.Tensor(7.177331, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.052069668, shape=(), dtype=float32)
# Epoch: 3 Train loss: 0.095698 Validation loss: 0.05207
# epoch4
# train_losstf.Tensor(6.481388, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.048526045, shape=(), dtype=float32)
# Epoch: 4 Train loss: 0.086419 Validation loss: 0.048526
# epoch5
# train_losstf.Tensor(8.39853, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.049535956, shape=(), dtype=float32)
# Epoch: 5 Train loss: 0.11198 Validation loss: 0.049536
# epoch6
# train_losstf.Tensor(6.989224, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.030340418, shape=(), dtype=float32)
# Epoch: 6 Train loss: 0.09319 Validation loss: 0.03034
# epoch7
# train_losstf.Tensor(7.2791653, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.030868204, shape=(), dtype=float32)
# Epoch: 7 Train loss: 0.097056 Validation loss: 0.030868
# epoch8
# train_losstf.Tensor(5.9125395, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.076744415, shape=(), dtype=float32)
# Epoch: 8 Train loss: 0.078834 Validation loss: 0.076744
# epoch9
# train_losstf.Tensor(5.8584585, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.03227505, shape=(), dtype=float32)
# Epoch: 9 Train loss: 0.078113 Validation loss: 0.032275
# epoch10
# train_losstf.Tensor(4.846879, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.030269718, shape=(), dtype=float32)
# Epoch: 10 Train loss: 0.064625 Validation loss: 0.03027
# epoch11
# train_losstf.Tensor(5.761345, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.02325383, shape=(), dtype=float32)
# Epoch: 11 Train loss: 0.076818 Validation loss: 0.023254
# epoch12
# train_losstf.Tensor(4.5734963, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.025190743, shape=(), dtype=float32)
# Epoch: 12 Train loss: 0.06098 Validation loss: 0.025191
# epoch13
# train_losstf.Tensor(3.7843204, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.019832784, shape=(), dtype=float32)
# Epoch: 13 Train loss: 0.050458 Validation loss: 0.019833
# epoch14
# train_losstf.Tensor(3.838884, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.024048377, shape=(), dtype=float32)
# Epoch: 14 Train loss: 0.051185 Validation loss: 0.024048
# epoch15
# train_losstf.Tensor(3.8727214, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.03493544, shape=(), dtype=float32)
# Epoch: 15 Train loss: 0.051636 Validation loss: 0.034935
# epoch16
# train_losstf.Tensor(3.3245115, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.020688483, shape=(), dtype=float32)
# Epoch: 16 Train loss: 0.044327 Validation loss: 0.020688
# epoch17
# train_losstf.Tensor(2.9687212, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.022568181, shape=(), dtype=float32)
# Epoch: 17 Train loss: 0.039583 Validation loss: 0.022568
# epoch18
# train_losstf.Tensor(2.818028, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.02273507, shape=(), dtype=float32)
# Epoch: 18 Train loss: 0.037574 Validation loss: 0.022735
# epoch19
# train_losstf.Tensor(2.8783073, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.02020273, shape=(), dtype=float32)
# Epoch: 19 Train loss: 0.038377 Validation loss: 0.020203

# %% [markdown]
# After completion of the training process we use the test data set to test the models generalization to unseen data.

# %%
for x_t, y_t in test_ds:
    y_pred = mdl.__call__(x_t)
    y_t =tf.reshape(y_t, [-1,1]) # Compute a prediction with "mdl" on the input "x_t"
    test_loss = tf.compat.v1.losses.mean_squared_error(y_t, y_pred)# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_t"
print("Test loss: {:.5}".format(test_loss))
# Out:
# Test loss: 0.024473

# %% [markdown]
# After we have verified that our model achieves a similar loss on the test as on the validation and training data set, we can conclude that our model is not overfitting or underfitting and generalizes to unseen data. We can now predict on the inputs again and plot the results.

# %%
""" Now we want to plot the prediction after training. Predict on the variable "x" again. """

y_pred =mdl.__call__(x) # Compute a prediction on the variable "x"
plt.plot(x, y)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# Now our model has learned to approximate the function mapping from the input to the output. The capability of neural networks to learn from input-ouput pairs alone and approximate an arbitrary function, see universal approximation theorem, can be very useful if the mapping between the input and output is too complex to be captured with model based approaches. But learning from input-ouput pairs alone implies that the model will only be able to make accurate predictions over input ranges it has seen during training. In order to demonstrate this we will predict on an interval that exeeds the $\left[0,3\right]$ interval the model was trained on, i.e. we will predict on the interval $\left[-2,5\right]$.

# %%
x_generalize = np.linspace(-2.0, 5.0, N_samples, dtype=np.float32)
y_generalize = np.sin(1.0+x_generalize*x_generalize) + noise_sig*np.random.randn(N_samples).astype(np.float32)
y_truey_generalize = np.sin(1.0+x_generalize*x_generalize)
y_pred = mdl(x_generalize)
plt.plot(x_generalize, y_generalize)
plt.plot(x_generalize, y_truey_generalize)
plt.plot(x_generalize, y_pred.numpy())
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# As expected, the model is able to make farely accurate predictions on the interval it was trained on but makes unreliable predictions outside this interval.
#
# ### Regularization
# In this section we will explore the concept of regularization. As there is no theorem that can be used to determine the required size and structure of a neural network given a certain task, one has to find a suitable neural architecture by trial and error. This can result in choosing a architecture with a capacity that is higher than required for solving the given task and hence overfitting might occur. A common way to prevent large neural networks networks from overfitting is to employ some sort of regularization, e.g. weight norm penalty, dropout, early stopping and data augmentation. In this section we will focus on weight norm penalty as a regularization and derive a probabilistic interpretation for some of those.
#
# We start by restating the conditional probability of the output $\mathbf{y}$ given the input $\mathbf{x}$ and the networks parameters $\boldsymbol{\theta}$
#
# $p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})=\dfrac{1}{\sqrt{(2\pi)^{M}\sigma^{2}}}\mathrm{e}^{-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})}\Vert_{2}^{2}}$,
#
# which we used to derive the log likelihood. If we have some prior knowledge about the parameters of the neural network, which is given by a pdf $p(\boldsymbol{\theta})$ over the weights, we can use Bayes theorem to derive a posterior distribution
#
# $p(\boldsymbol{\theta}\vert\mathbf{x},\mathbf{y})=\dfrac{p(\boldsymbol{\theta},\mathbf{y}\vert\mathbf{x})}{p(\mathbf{y})}=\dfrac{p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})p(\boldsymbol{\theta})}{p(\mathbf{y})}$
#
# where $p(\boldsymbol{\theta})$ is the  prior over the networks parameters. Similar to the derivation at the beginning of the exercise, we can use this posterior distribution to derive a cost function for training the neural network. In this case, however, we are not maximizing the log likelihood but the posterior distribution over the weights, hence this approach is called Maximum A Posteori (MAP) estimation of the parameters. Mathematically we can formulate this as
#
# $\boldsymbol{\theta}^{\star}=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[p(\boldsymbol{\theta}\vert\mathbf{x},\mathbf{y})\right]=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[\ln{p(\boldsymbol{\theta}\vert\mathbf{x},\mathbf{y})}\right]=\arg\max_{\boldsymbol{\theta}}\ln{p(\boldsymbol{\theta})}+\mathbb{E}\left[\ln{p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})}\right]$,
#
# where we used the fact that applying a strictly increasing function, e.g. $\ln{}$, does not change the position of the maximum of a cost function, ignored $p(\mathbf{y})$, since it is independent of the network parameters and dropped the expectation operator for $\ln{p(\boldsymbol{\theta})}$, since it is not depending on the random variable $\mathbf{x}$. Comparing the MAP estimate of the parameters with the ML estimate we derived above, shows that the only difference is the addition of $\ln{p(\boldsymbol{\theta})}$. This term is the regularization, i.e. the weight norm penalty. Depending on the distribution over $\boldsymbol{\theta}$ it can have different forms. If we choose a standard normal distribution, i.e. $\boldsymbol{\theta\sim\mathcal{N}(\mathbf{0},\mathbf{I})}$,  we get
#
# $\boldsymbol{\theta}^{\star}=\arg\min_{\boldsymbol{\theta}}\lambda\Vert\boldsymbol{\theta}\Vert_{2}^{2}+\dfrac{1}{N_{D}}\sum_{i=1}^{N_{D}}\Vert\boldsymbol{\mathbf{y}_{i}-g_{\boldsymbol{\theta}}(\mathbf{x}_{i})}\Vert_{2}^{2}$,
#
# where we have made the same simplifications as for the ML estimation and also introduced the parameter $\lambda=\sigma^{2}$, which is used to control the strength of the regularization. This form of regularization is commonly known as $l_{2}$-norm or weight decay regularization. Choosing a prior where the weights follow an i.i.d laplacian distribution, i.e. $p(\boldsymbol{\theta})=\prod_{j}\dfrac{1}{2}\mathrm{e}^{\vert\theta_{j}\vert}$, leads to
#
# $\boldsymbol{\theta}^{\star}=\arg\min_{\boldsymbol{\theta}}\lambda\Vert\boldsymbol{\theta}\Vert_{1}+\dfrac{1}{N_{D}}\sum_{i=1}^{N_{D}}\Vert\boldsymbol{\mathbf{y}_{i}-g_{\boldsymbol{\theta}}(\mathbf{x}_{i})}\Vert_{2}^{2}$,
#
# where the strength of the regularization is again controlled by $\lambda=\sigma^{2}$. This type of regularization is known as  $l_{1}$-norm and it has the property to induce sparsity in the parameters of the network.
#
# With this theoretical background on regularization we can now implement it and observe it's effects on the regression problem covered in this exercise. For this we will define a model with a high capacity and train it for a extended time to provoke overfitting. For this, we will increase the number of hidden neurons in both hidden layers to $100$ and $50$.

# %%
""" Implement a bigger model with again two hidden layers contatining 100 and 50 neurons. As an activation use the tangens hyperbolicus function where it is appropiate. """

class MyBigModel(object):
    def __init__(self):
        # Create model variables
        self.W0 = tf.Variable(name = 'weight_0',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([1, 100])))
        self.b0 = tf.Variable(name = 'bias_0',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([ 100])))
        self.W1 = tf.Variable(name = 'weight_1',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([100, 50])))
        self.b1 = tf.Variable(name = 'bias_1',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([ 50])))
        self.W2 = tf.Variable(name = 'weight_2',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([50, 1])))
        self.b2 = tf.Variable(name = 'bias_2',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([ 1])))
        self.trainable_variables = [self.W0, self.b0, self.W1, self.b1, self.W2, self.b2] 
        self.trainable_variables = [self.W0, self.b0, self.W1, self.b1, self.W2, self.b2]

    def __call__(self, inputs):
        # Compute forward pass
        output = tf.reshape(inputs, [-1, 1])
        output = tf.nn.tanh( tf.add(tf.matmul(output, self.W0), self.b0))
        output =tf.nn.tanh( tf.add(tf.matmul(output, self.W1), self.b1))
        output = tf.nn.tanh(tf.add(tf.matmul(output, self.W2), self.b2)) 
        return output

# %% [markdown]
# After creating one instance of this class we can again train it on our data set. We will also create a new optimizer for training this bigger model, since some optimizers adapt the learning rates for individual parameters during a training process and we do not want to train our bigger model with learning rates adopted from an earlier training run.

# %%
big_mdl = MyBigModel()
big_opt = tf.optimizers.SGD(learning_rate)

# %% [markdown]
# Now we are ready to train this bigger model using the same training step and training loop. In order to provoke overfitting we also reduce the number of samples in the training data set a lot, increase the batch size and train for a more epochs.

# %%
""" Implement the training for the bigger model similar to the training of the small model before. """

N_train_samples_overfit = 30
N_epochs = 1000
batch_size = 30

sel_idx = np.arange(0, N_train_samples)
sel_idx = np.random.choice(sel_idx, N_train_samples_overfit)
x_train_overfit = x_train[sel_idx]
y_train_overfit = y_train[sel_idx]

train_overfit_ds = tf.data.Dataset.from_tensor_slices((x_train_overfit, y_train_overfit)).shuffle(N_train_samples_overfit).batch(batch_size).repeat()

epoch = 0
train_iters = 0
train_loss = 0.0
for x_t, y_t in train_overfit_ds:
    train_loss += train_step(big_mdl, big_opt, x_t, y_t) # Perform a training step with the model "big_mdl" and the optimizer "big_opt" on the inputs "x_t" and the corresponding targets "y_t"
    train_iters += 1
    if train_iters == N_train_samples/batch_size :# An epoch is completed
        for x_v, y_v in validation_ds:
            y_pred = big_mdl.__call__ (x_v)
            y_v = tf.reshape(y_v, [-1,1])# Compute a prediction with "big_mdl" on the input "x_v"
            validation_loss = tf.compat.v1.losses.mean_squared_error(y_v, y_pred) # Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_v"
        print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
        train_iters = 0
        train_loss = 0.0
        epoch += 1
    if (epoch == N_epochs):
        break
# Out:
# Epoch: 0 Train loss: 2.3634 Validation loss: 1.7902
# Epoch: 1 Train loss: 2.0133 Validation loss: 1.7351
# Epoch: 2 Train loss: 1.8192 Validation loss: 1.6975
# Epoch: 3 Train loss: 1.7265 Validation loss: 1.676
# Epoch: 4 Train loss: 1.6839 Validation loss: 1.6518
# Epoch: 5 Train loss: 1.6465 Validation loss: 1.6291
# Epoch: 6 Train loss: 1.6202 Validation loss: 1.6082
# Epoch: 7 Train loss: 1.5911 Validation loss: 1.588
# Epoch: 8 Train loss: 1.558 Validation loss: 1.5736
# Epoch: 9 Train loss: 1.5389 Validation loss: 1.5661
# Epoch: 10 Train loss: 1.5322 Validation loss: 1.5619
# Epoch: 11 Train loss: 1.5292 Validation loss: 1.5591
# Epoch: 12 Train loss: 1.5277 Validation loss: 1.5572
# Epoch: 13 Train loss: 1.5267 Validation loss: 1.5558
# Epoch: 14 Train loss: 1.5261 Validation loss: 1.5547
# Epoch: 15 Train loss: 1.5256 Validation loss: 1.5538
# Epoch: 16 Train loss: 1.5253 Validation loss: 1.5531
# Epoch: 17 Train loss: 1.525 Validation loss: 1.5525
# Epoch: 18 Train loss: 1.5248 Validation loss: 1.5519
# Epoch: 19 Train loss: 1.5246 Validation loss: 1.5515
# Epoch: 20 Train loss: 1.5244 Validation loss: 1.551
# Epoch: 21 Train loss: 1.5243 Validation loss: 1.5507
# Epoch: 22 Train loss: 1.5242 Validation loss: 1.5503
# Epoch: 23 Train loss: 1.5241 Validation loss: 1.55
# Epoch: 24 Train loss: 1.524 Validation loss: 1.5497
# Epoch: 25 Train loss: 1.5239 Validation loss: 1.5495
# Epoch: 26 Train loss: 1.5238 Validation loss: 1.5492
# Epoch: 27 Train loss: 1.5238 Validation loss: 1.549
# Epoch: 28 Train loss: 1.5237 Validation loss: 1.5488
# Epoch: 29 Train loss: 1.5236 Validation loss: 1.5486
# Epoch: 30 Train loss: 1.5236 Validation loss: 1.5484
# Epoch: 31 Train loss: 1.5235 Validation loss: 1.5482
# Epoch: 32 Train loss: 1.5235 Validation loss: 1.548
# Epoch: 33 Train loss: 1.5234 Validation loss: 1.5478
# Epoch: 34 Train loss: 1.5234 Validation loss: 1.5476
# Epoch: 35 Train loss: 1.5233 Validation loss: 1.5475
# Epoch: 36 Train loss: 1.5233 Validation loss: 1.5473
# Epoch: 37 Train loss: 1.5232 Validation loss: 1.5472
# Epoch: 38 Train loss: 1.5232 Validation loss: 1.547
# Epoch: 39 Train loss: 1.5231 Validation loss: 1.5469
# Epoch: 40 Train loss: 1.5231 Validation loss: 1.5467
# Epoch: 41 Train loss: 1.5231 Validation loss: 1.5466
# Epoch: 42 Train loss: 1.523 Validation loss: 1.5464
# Epoch: 43 Train loss: 1.523 Validation loss: 1.5463
# Epoch: 44 Train loss: 1.5229 Validation loss: 1.5461
# Epoch: 45 Train loss: 1.5229 Validation loss: 1.546
# Epoch: 46 Train loss: 1.5229 Validation loss: 1.5459
# Epoch: 47 Train loss: 1.5228 Validation loss: 1.5457
# Epoch: 48 Train loss: 1.5228 Validation loss: 1.5456
# Epoch: 49 Train loss: 1.5228 Validation loss: 1.5455
# Epoch: 50 Train loss: 1.5227 Validation loss: 1.5454
# Epoch: 51 Train loss: 1.5227 Validation loss: 1.5452
# Epoch: 52 Train loss: 1.5226 Validation loss: 1.5451
# Epoch: 53 Train loss: 1.5226 Validation loss: 1.545
# Epoch: 54 Train loss: 1.5226 Validation loss: 1.5449
# Epoch: 55 Train loss: 1.5225 Validation loss: 1.5448
# Epoch: 56 Train loss: 1.5225 Validation loss: 1.5446
# Epoch: 57 Train loss: 1.5225 Validation loss: 1.5445
# Epoch: 58 Train loss: 1.5224 Validation loss: 1.5444
# Epoch: 59 Train loss: 1.5224 Validation loss: 1.5443
# Epoch: 60 Train loss: 1.5224 Validation loss: 1.5442
# Epoch: 61 Train loss: 1.5223 Validation loss: 1.5441
# Epoch: 62 Train loss: 1.5223 Validation loss: 1.5439
# Epoch: 63 Train loss: 1.5223 Validation loss: 1.5438
# Epoch: 64 Train loss: 1.5222 Validation loss: 1.5437
# Epoch: 65 Train loss: 1.5222 Validation loss: 1.5436
# Epoch: 66 Train loss: 1.5222 Validation loss: 1.5435
# Epoch: 67 Train loss: 1.5221 Validation loss: 1.5434
# Epoch: 68 Train loss: 1.5221 Validation loss: 1.5433
# Epoch: 69 Train loss: 1.5221 Validation loss: 1.5432
# Epoch: 70 Train loss: 1.522 Validation loss: 1.5431
# Epoch: 71 Train loss: 1.522 Validation loss: 1.543
# Epoch: 72 Train loss: 1.522 Validation loss: 1.5428
# Epoch: 73 Train loss: 1.5219 Validation loss: 1.5427
# Epoch: 74 Train loss: 1.5219 Validation loss: 1.5426
# Epoch: 75 Train loss: 1.5219 Validation loss: 1.5425
# Epoch: 76 Train loss: 1.5218 Validation loss: 1.5424
# Epoch: 77 Train loss: 1.5218 Validation loss: 1.5423
# Epoch: 78 Train loss: 1.5218 Validation loss: 1.5422
# Epoch: 79 Train loss: 1.5217 Validation loss: 1.5421
# Epoch: 80 Train loss: 1.5217 Validation loss: 1.542
# Epoch: 81 Train loss: 1.5217 Validation loss: 1.5419
# Epoch: 82 Train loss: 1.5216 Validation loss: 1.5418
# Epoch: 83 Train loss: 1.5216 Validation loss: 1.5417
# Epoch: 84 Train loss: 1.5216 Validation loss: 1.5416
# Epoch: 85 Train loss: 1.5215 Validation loss: 1.5415
# Epoch: 86 Train loss: 1.5215 Validation loss: 1.5414
# Epoch: 87 Train loss: 1.5215 Validation loss: 1.5413
# Epoch: 88 Train loss: 1.5214 Validation loss: 1.5412
# Epoch: 89 Train loss: 1.5214 Validation loss: 1.5411
# Epoch: 90 Train loss: 1.5214 Validation loss: 1.541
# Epoch: 91 Train loss: 1.5213 Validation loss: 1.5409
# Epoch: 92 Train loss: 1.5213 Validation loss: 1.5407
# Epoch: 93 Train loss: 1.5213 Validation loss: 1.5406
# Epoch: 94 Train loss: 1.5213 Validation loss: 1.5405
# Epoch: 95 Train loss: 1.5212 Validation loss: 1.5404
# Epoch: 96 Train loss: 1.5212 Validation loss: 1.5403
# Epoch: 97 Train loss: 1.5212 Validation loss: 1.5402
# Epoch: 98 Train loss: 1.5211 Validation loss: 1.5401
# Epoch: 99 Train loss: 1.5211 Validation loss: 1.54
# Epoch: 100 Train loss: 1.5211 Validation loss: 1.5399
# Epoch: 101 Train loss: 1.521 Validation loss: 1.5398
# Epoch: 102 Train loss: 1.521 Validation loss: 1.5397
# Epoch: 103 Train loss: 1.521 Validation loss: 1.5396
# Epoch: 104 Train loss: 1.5209 Validation loss: 1.5395
# Epoch: 105 Train loss: 1.5209 Validation loss: 1.5394
# Epoch: 106 Train loss: 1.5209 Validation loss: 1.5393
# Epoch: 107 Train loss: 1.5209 Validation loss: 1.5392
# Epoch: 108 Train loss: 1.5208 Validation loss: 1.5391
# Epoch: 109 Train loss: 1.5208 Validation loss: 1.539
# Epoch: 110 Train loss: 1.5208 Validation loss: 1.5389
# Epoch: 111 Train loss: 1.5207 Validation loss: 1.5388
# Epoch: 112 Train loss: 1.5207 Validation loss: 1.5387
# Epoch: 113 Train loss: 1.5207 Validation loss: 1.5386
# Epoch: 114 Train loss: 1.5207 Validation loss: 1.5385
# Epoch: 115 Train loss: 1.5206 Validation loss: 1.5384
# Epoch: 116 Train loss: 1.5206 Validation loss: 1.5383
# Epoch: 117 Train loss: 1.5206 Validation loss: 1.5382
# Epoch: 118 Train loss: 1.5205 Validation loss: 1.5381
# Epoch: 119 Train loss: 1.5205 Validation loss: 1.538
# Epoch: 120 Train loss: 1.5205 Validation loss: 1.5379
# Epoch: 121 Train loss: 1.5205 Validation loss: 1.5378
# Epoch: 122 Train loss: 1.5204 Validation loss: 1.5377
# Epoch: 123 Train loss: 1.5204 Validation loss: 1.5376
# Epoch: 124 Train loss: 1.5204 Validation loss: 1.5375
# Epoch: 125 Train loss: 1.5203 Validation loss: 1.5374
# Epoch: 126 Train loss: 1.5203 Validation loss: 1.5373
# Epoch: 127 Train loss: 1.5203 Validation loss: 1.5371
# Epoch: 128 Train loss: 1.5203 Validation loss: 1.537
# Epoch: 129 Train loss: 1.5202 Validation loss: 1.5369
# Epoch: 130 Train loss: 1.5202 Validation loss: 1.5368
# Epoch: 131 Train loss: 1.5202 Validation loss: 1.5367
# Epoch: 132 Train loss: 1.5201 Validation loss: 1.5366
# Epoch: 133 Train loss: 1.5201 Validation loss: 1.5365
# Epoch: 134 Train loss: 1.5201 Validation loss: 1.5364
# Epoch: 135 Train loss: 1.52 Validation loss: 1.5363
# Epoch: 136 Train loss: 1.52 Validation loss: 1.5362
# Epoch: 137 Train loss: 1.52 Validation loss: 1.5361
# Epoch: 138 Train loss: 1.52 Validation loss: 1.536
# Epoch: 139 Train loss: 1.5199 Validation loss: 1.5359
# Epoch: 140 Train loss: 1.5199 Validation loss: 1.5358
# Epoch: 141 Train loss: 1.5199 Validation loss: 1.5357
# Epoch: 142 Train loss: 1.5198 Validation loss: 1.5356
# Epoch: 143 Train loss: 1.5198 Validation loss: 1.5355
# Epoch: 144 Train loss: 1.5198 Validation loss: 1.5353
# Epoch: 145 Train loss: 1.5198 Validation loss: 1.5352
# Epoch: 146 Train loss: 1.5197 Validation loss: 1.5351
# Epoch: 147 Train loss: 1.5197 Validation loss: 1.535
# Epoch: 148 Train loss: 1.5197 Validation loss: 1.5349
# Epoch: 149 Train loss: 1.5196 Validation loss: 1.5348
# Epoch: 150 Train loss: 1.5196 Validation loss: 1.5347
# Epoch: 151 Train loss: 1.5196 Validation loss: 1.5346
# Epoch: 152 Train loss: 1.5196 Validation loss: 1.5345
# Epoch: 153 Train loss: 1.5195 Validation loss: 1.5344
# Epoch: 154 Train loss: 1.5195 Validation loss: 1.5343
# Epoch: 155 Train loss: 1.5195 Validation loss: 1.5342
# Epoch: 156 Train loss: 1.5194 Validation loss: 1.534
# Epoch: 157 Train loss: 1.5194 Validation loss: 1.5339
# Epoch: 158 Train loss: 1.5194 Validation loss: 1.5338
# Epoch: 159 Train loss: 1.5193 Validation loss: 1.5337
# Epoch: 160 Train loss: 1.5193 Validation loss: 1.5336
# Epoch: 161 Train loss: 1.5193 Validation loss: 1.5335
# Epoch: 162 Train loss: 1.5192 Validation loss: 1.5334
# Epoch: 163 Train loss: 1.5192 Validation loss: 1.5333
# Epoch: 164 Train loss: 1.5192 Validation loss: 1.5332
# Epoch: 165 Train loss: 1.5191 Validation loss: 1.5331
# Epoch: 166 Train loss: 1.5191 Validation loss: 1.5329
# Epoch: 167 Train loss: 1.5191 Validation loss: 1.5328
# Epoch: 168 Train loss: 1.519 Validation loss: 1.5327
# Epoch: 169 Train loss: 1.519 Validation loss: 1.5326
# Epoch: 170 Train loss: 1.519 Validation loss: 1.5325
# Epoch: 171 Train loss: 1.5189 Validation loss: 1.5324
# Epoch: 172 Train loss: 1.5189 Validation loss: 1.5323
# Epoch: 173 Train loss: 1.5189 Validation loss: 1.5322
# Epoch: 174 Train loss: 1.5188 Validation loss: 1.532
# Epoch: 175 Train loss: 1.5188 Validation loss: 1.5319
# Epoch: 176 Train loss: 1.5188 Validation loss: 1.5318
# Epoch: 177 Train loss: 1.5187 Validation loss: 1.5317
# Epoch: 178 Train loss: 1.5187 Validation loss: 1.5316
# Epoch: 179 Train loss: 1.5186 Validation loss: 1.5315
# Epoch: 180 Train loss: 1.5186 Validation loss: 1.5314
# Epoch: 181 Train loss: 1.5186 Validation loss: 1.5313
# Epoch: 182 Train loss: 1.5185 Validation loss: 1.5312
# Epoch: 183 Train loss: 1.5185 Validation loss: 1.5311
# Epoch: 184 Train loss: 1.5184 Validation loss: 1.531
# Epoch: 185 Train loss: 1.5184 Validation loss: 1.5309
# Epoch: 186 Train loss: 1.5184 Validation loss: 1.5307
# Epoch: 187 Train loss: 1.5183 Validation loss: 1.5306
# Epoch: 188 Train loss: 1.5183 Validation loss: 1.5305
# Epoch: 189 Train loss: 1.5182 Validation loss: 1.5304
# Epoch: 190 Train loss: 1.5182 Validation loss: 1.5303
# Epoch: 191 Train loss: 1.5181 Validation loss: 1.5302
# Epoch: 192 Train loss: 1.5181 Validation loss: 1.5301
# Epoch: 193 Train loss: 1.5181 Validation loss: 1.53
# Epoch: 194 Train loss: 1.518 Validation loss: 1.53
# Epoch: 195 Train loss: 1.518 Validation loss: 1.5299
# Epoch: 196 Train loss: 1.5179 Validation loss: 1.5298
# Epoch: 197 Train loss: 1.5179 Validation loss: 1.5297
# Epoch: 198 Train loss: 1.5178 Validation loss: 1.5296
# Epoch: 199 Train loss: 1.5178 Validation loss: 1.5295
# Epoch: 200 Train loss: 1.5177 Validation loss: 1.5294
# Epoch: 201 Train loss: 1.5177 Validation loss: 1.5293
# Epoch: 202 Train loss: 1.5176 Validation loss: 1.5293
# Epoch: 203 Train loss: 1.5176 Validation loss: 1.5292
# Epoch: 204 Train loss: 1.5175 Validation loss: 1.5291
# Epoch: 205 Train loss: 1.5175 Validation loss: 1.5291
# Epoch: 206 Train loss: 1.5174 Validation loss: 1.529
# Epoch: 207 Train loss: 1.5174 Validation loss: 1.5289
# Epoch: 208 Train loss: 1.5173 Validation loss: 1.5289
# Epoch: 209 Train loss: 1.5172 Validation loss: 1.5288
# Epoch: 210 Train loss: 1.5172 Validation loss: 1.5288
# Epoch: 211 Train loss: 1.5171 Validation loss: 1.5287
# Epoch: 212 Train loss: 1.5171 Validation loss: 1.5287
# Epoch: 213 Train loss: 1.517 Validation loss: 1.5286
# Epoch: 214 Train loss: 1.517 Validation loss: 1.5286
# Epoch: 215 Train loss: 1.5169 Validation loss: 1.5286
# Epoch: 216 Train loss: 1.5169 Validation loss: 1.5285
# Epoch: 217 Train loss: 1.5168 Validation loss: 1.5285
# Epoch: 218 Train loss: 1.5167 Validation loss: 1.5285
# Epoch: 219 Train loss: 1.5167 Validation loss: 1.5285
# Epoch: 220 Train loss: 1.5166 Validation loss: 1.5285
# Epoch: 221 Train loss: 1.5166 Validation loss: 1.5285
# Epoch: 222 Train loss: 1.5165 Validation loss: 1.5285
# Epoch: 223 Train loss: 1.5165 Validation loss: 1.5285
# Epoch: 224 Train loss: 1.5164 Validation loss: 1.5285
# Epoch: 225 Train loss: 1.5164 Validation loss: 1.5285
# Epoch: 226 Train loss: 1.5163 Validation loss: 1.5285
# Epoch: 227 Train loss: 1.5162 Validation loss: 1.5286
# Epoch: 228 Train loss: 1.5162 Validation loss: 1.5286
# Epoch: 229 Train loss: 1.5161 Validation loss: 1.5286
# Epoch: 230 Train loss: 1.5161 Validation loss: 1.5287
# Epoch: 231 Train loss: 1.516 Validation loss: 1.5287
# Epoch: 232 Train loss: 1.516 Validation loss: 1.5287
# Epoch: 233 Train loss: 1.5159 Validation loss: 1.5288
# Epoch: 234 Train loss: 1.5159 Validation loss: 1.5288
# Epoch: 235 Train loss: 1.5159 Validation loss: 1.5289
# Epoch: 236 Train loss: 1.5158 Validation loss: 1.5289
# Epoch: 237 Train loss: 1.5158 Validation loss: 1.529
# Epoch: 238 Train loss: 1.5157 Validation loss: 1.529
# Epoch: 239 Train loss: 1.5157 Validation loss: 1.5291
# Epoch: 240 Train loss: 1.5157 Validation loss: 1.5291
# Epoch: 241 Train loss: 1.5156 Validation loss: 1.5292
# Epoch: 242 Train loss: 1.5156 Validation loss: 1.5292
# Epoch: 243 Train loss: 1.5155 Validation loss: 1.5293
# Epoch: 244 Train loss: 1.5155 Validation loss: 1.5293
# Epoch: 245 Train loss: 1.5155 Validation loss: 1.5294
# Epoch: 246 Train loss: 1.5155 Validation loss: 1.5294
# Epoch: 247 Train loss: 1.5154 Validation loss: 1.5295
# Epoch: 248 Train loss: 1.5154 Validation loss: 1.5295
# Epoch: 249 Train loss: 1.5154 Validation loss: 1.5295
# Epoch: 250 Train loss: 1.5153 Validation loss: 1.5296
# Epoch: 251 Train loss: 1.5153 Validation loss: 1.5296
# Epoch: 252 Train loss: 1.5153 Validation loss: 1.5297
# Epoch: 253 Train loss: 1.5153 Validation loss: 1.5297
# Epoch: 254 Train loss: 1.5152 Validation loss: 1.5297
# Epoch: 255 Train loss: 1.5152 Validation loss: 1.5298
# Epoch: 256 Train loss: 1.5152 Validation loss: 1.5298
# Epoch: 257 Train loss: 1.5152 Validation loss: 1.5298
# Epoch: 258 Train loss: 1.5152 Validation loss: 1.5299
# Epoch: 259 Train loss: 1.5151 Validation loss: 1.5299
# Epoch: 260 Train loss: 1.5151 Validation loss: 1.5299
# Epoch: 261 Train loss: 1.5151 Validation loss: 1.5299
# Epoch: 262 Train loss: 1.5151 Validation loss: 1.5299
# Epoch: 263 Train loss: 1.5151 Validation loss: 1.53
# Epoch: 264 Train loss: 1.5151 Validation loss: 1.53
# Epoch: 265 Train loss: 1.5151 Validation loss: 1.53
# Epoch: 266 Train loss: 1.515 Validation loss: 1.53
# Epoch: 267 Train loss: 1.515 Validation loss: 1.53
# Epoch: 268 Train loss: 1.515 Validation loss: 1.53
# Epoch: 269 Train loss: 1.515 Validation loss: 1.53
# Epoch: 270 Train loss: 1.515 Validation loss: 1.53
# Epoch: 271 Train loss: 1.515 Validation loss: 1.53
# Epoch: 272 Train loss: 1.515 Validation loss: 1.53
# Epoch: 273 Train loss: 1.515 Validation loss: 1.53
# Epoch: 274 Train loss: 1.5149 Validation loss: 1.53
# Epoch: 275 Train loss: 1.5149 Validation loss: 1.53
# Epoch: 276 Train loss: 1.5149 Validation loss: 1.53
# Epoch: 277 Train loss: 1.5149 Validation loss: 1.53
# Epoch: 278 Train loss: 1.5149 Validation loss: 1.5299
# Epoch: 279 Train loss: 1.5149 Validation loss: 1.5299
# Epoch: 280 Train loss: 1.5149 Validation loss: 1.5299
# Epoch: 281 Train loss: 1.5149 Validation loss: 1.5299
# Epoch: 282 Train loss: 1.5149 Validation loss: 1.5299
# Epoch: 283 Train loss: 1.5149 Validation loss: 1.5299
# Epoch: 284 Train loss: 1.5148 Validation loss: 1.5298
# Epoch: 285 Train loss: 1.5148 Validation loss: 1.5298
# Epoch: 286 Train loss: 1.5148 Validation loss: 1.5298
# Epoch: 287 Train loss: 1.5148 Validation loss: 1.5298
# Epoch: 288 Train loss: 1.5148 Validation loss: 1.5298
# Epoch: 289 Train loss: 1.5148 Validation loss: 1.5297
# Epoch: 290 Train loss: 1.5148 Validation loss: 1.5297
# Epoch: 291 Train loss: 1.5148 Validation loss: 1.5297
# Epoch: 292 Train loss: 1.5148 Validation loss: 1.5297
# Epoch: 293 Train loss: 1.5148 Validation loss: 1.5296
# Epoch: 294 Train loss: 1.5148 Validation loss: 1.5296
# Epoch: 295 Train loss: 1.5148 Validation loss: 1.5296
# Epoch: 296 Train loss: 1.5148 Validation loss: 1.5295
# Epoch: 297 Train loss: 1.5147 Validation loss: 1.5295
# Epoch: 298 Train loss: 1.5147 Validation loss: 1.5295
# Epoch: 299 Train loss: 1.5147 Validation loss: 1.5295
# Epoch: 300 Train loss: 1.5147 Validation loss: 1.5294
# Epoch: 301 Train loss: 1.5147 Validation loss: 1.5294
# Epoch: 302 Train loss: 1.5147 Validation loss: 1.5294
# Epoch: 303 Train loss: 1.5147 Validation loss: 1.5293
# Epoch: 304 Train loss: 1.5147 Validation loss: 1.5293
# Epoch: 305 Train loss: 1.5147 Validation loss: 1.5293
# Epoch: 306 Train loss: 1.5147 Validation loss: 1.5293
# Epoch: 307 Train loss: 1.5147 Validation loss: 1.5292
# Epoch: 308 Train loss: 1.5147 Validation loss: 1.5292
# Epoch: 309 Train loss: 1.5147 Validation loss: 1.5292
# Epoch: 310 Train loss: 1.5147 Validation loss: 1.5291
# Epoch: 311 Train loss: 1.5147 Validation loss: 1.5291
# Epoch: 312 Train loss: 1.5146 Validation loss: 1.5291
# Epoch: 313 Train loss: 1.5146 Validation loss: 1.529
# Epoch: 314 Train loss: 1.5146 Validation loss: 1.529
# Epoch: 315 Train loss: 1.5146 Validation loss: 1.529
# Epoch: 316 Train loss: 1.5146 Validation loss: 1.5289
# Epoch: 317 Train loss: 1.5146 Validation loss: 1.5289
# Epoch: 318 Train loss: 1.5146 Validation loss: 1.5289
# Epoch: 319 Train loss: 1.5146 Validation loss: 1.5288
# Epoch: 320 Train loss: 1.5146 Validation loss: 1.5288
# Epoch: 321 Train loss: 1.5146 Validation loss: 1.5288
# Epoch: 322 Train loss: 1.5146 Validation loss: 1.5288
# Epoch: 323 Train loss: 1.5146 Validation loss: 1.5287
# Epoch: 324 Train loss: 1.5146 Validation loss: 1.5287
# Epoch: 325 Train loss: 1.5146 Validation loss: 1.5287
# Epoch: 326 Train loss: 1.5146 Validation loss: 1.5286
# Epoch: 327 Train loss: 1.5146 Validation loss: 1.5286
# Epoch: 328 Train loss: 1.5146 Validation loss: 1.5286
# Epoch: 329 Train loss: 1.5145 Validation loss: 1.5285
# Epoch: 330 Train loss: 1.5145 Validation loss: 1.5285
# Epoch: 331 Train loss: 1.5145 Validation loss: 1.5285
# Epoch: 332 Train loss: 1.5145 Validation loss: 1.5284
# Epoch: 333 Train loss: 1.5145 Validation loss: 1.5284
# Epoch: 334 Train loss: 1.5145 Validation loss: 1.5284
# Epoch: 335 Train loss: 1.5145 Validation loss: 1.5284
# Epoch: 336 Train loss: 1.5145 Validation loss: 1.5283
# Epoch: 337 Train loss: 1.5145 Validation loss: 1.5283
# Epoch: 338 Train loss: 1.5145 Validation loss: 1.5283
# Epoch: 339 Train loss: 1.5145 Validation loss: 1.5282
# Epoch: 340 Train loss: 1.5145 Validation loss: 1.5282
# Epoch: 341 Train loss: 1.5145 Validation loss: 1.5282
# Epoch: 342 Train loss: 1.5145 Validation loss: 1.5282
# Epoch: 343 Train loss: 1.5145 Validation loss: 1.5281
# Epoch: 344 Train loss: 1.5145 Validation loss: 1.5281
# Epoch: 345 Train loss: 1.5145 Validation loss: 1.5281
# Epoch: 346 Train loss: 1.5145 Validation loss: 1.528
# Epoch: 347 Train loss: 1.5144 Validation loss: 1.528
# Epoch: 348 Train loss: 1.5144 Validation loss: 1.528
# Epoch: 349 Train loss: 1.5144 Validation loss: 1.528
# Epoch: 350 Train loss: 1.5144 Validation loss: 1.5279
# Epoch: 351 Train loss: 1.5144 Validation loss: 1.5279
# Epoch: 352 Train loss: 1.5144 Validation loss: 1.5279
# Epoch: 353 Train loss: 1.5144 Validation loss: 1.5278
# Epoch: 354 Train loss: 1.5144 Validation loss: 1.5278
# Epoch: 355 Train loss: 1.5144 Validation loss: 1.5278
# Epoch: 356 Train loss: 1.5144 Validation loss: 1.5278
# Epoch: 357 Train loss: 1.5144 Validation loss: 1.5277
# Epoch: 358 Train loss: 1.5144 Validation loss: 1.5277
# Epoch: 359 Train loss: 1.5144 Validation loss: 1.5277
# Epoch: 360 Train loss: 1.5144 Validation loss: 1.5277
# Epoch: 361 Train loss: 1.5144 Validation loss: 1.5276
# Epoch: 362 Train loss: 1.5144 Validation loss: 1.5276
# Epoch: 363 Train loss: 1.5144 Validation loss: 1.5276
# Epoch: 364 Train loss: 1.5144 Validation loss: 1.5276
# Epoch: 365 Train loss: 1.5144 Validation loss: 1.5275
# Epoch: 366 Train loss: 1.5144 Validation loss: 1.5275
# Epoch: 367 Train loss: 1.5143 Validation loss: 1.5275
# Epoch: 368 Train loss: 1.5143 Validation loss: 1.5275
# Epoch: 369 Train loss: 1.5143 Validation loss: 1.5274
# Epoch: 370 Train loss: 1.5143 Validation loss: 1.5274
# Epoch: 371 Train loss: 1.5143 Validation loss: 1.5274
# Epoch: 372 Train loss: 1.5143 Validation loss: 1.5274
# Epoch: 373 Train loss: 1.5143 Validation loss: 1.5273
# Epoch: 374 Train loss: 1.5143 Validation loss: 1.5273
# Epoch: 375 Train loss: 1.5143 Validation loss: 1.5273
# Epoch: 376 Train loss: 1.5143 Validation loss: 1.5273
# Epoch: 377 Train loss: 1.5143 Validation loss: 1.5272
# Epoch: 378 Train loss: 1.5143 Validation loss: 1.5272
# Epoch: 379 Train loss: 1.5143 Validation loss: 1.5272
# Epoch: 380 Train loss: 1.5143 Validation loss: 1.5272
# Epoch: 381 Train loss: 1.5143 Validation loss: 1.5271
# Epoch: 382 Train loss: 1.5143 Validation loss: 1.5271
# Epoch: 383 Train loss: 1.5143 Validation loss: 1.5271
# Epoch: 384 Train loss: 1.5143 Validation loss: 1.5271
# Epoch: 385 Train loss: 1.5143 Validation loss: 1.5271
# Epoch: 386 Train loss: 1.5143 Validation loss: 1.527
# Epoch: 387 Train loss: 1.5143 Validation loss: 1.527
# Epoch: 388 Train loss: 1.5143 Validation loss: 1.527
# Epoch: 389 Train loss: 1.5142 Validation loss: 1.527
# Epoch: 390 Train loss: 1.5142 Validation loss: 1.5269
# Epoch: 391 Train loss: 1.5142 Validation loss: 1.5269
# Epoch: 392 Train loss: 1.5142 Validation loss: 1.5269
# Epoch: 393 Train loss: 1.5142 Validation loss: 1.5269
# Epoch: 394 Train loss: 1.5142 Validation loss: 1.5269
# Epoch: 395 Train loss: 1.5142 Validation loss: 1.5268
# Epoch: 396 Train loss: 1.5142 Validation loss: 1.5268
# Epoch: 397 Train loss: 1.5142 Validation loss: 1.5268
# Epoch: 398 Train loss: 1.5142 Validation loss: 1.5268
# Epoch: 399 Train loss: 1.5142 Validation loss: 1.5268
# Epoch: 400 Train loss: 1.5142 Validation loss: 1.5267
# Epoch: 401 Train loss: 1.5142 Validation loss: 1.5267
# Epoch: 402 Train loss: 1.5142 Validation loss: 1.5267
# Epoch: 403 Train loss: 1.5142 Validation loss: 1.5267
# Epoch: 404 Train loss: 1.5142 Validation loss: 1.5267
# Epoch: 405 Train loss: 1.5142 Validation loss: 1.5266
# Epoch: 406 Train loss: 1.5142 Validation loss: 1.5266
# Epoch: 407 Train loss: 1.5142 Validation loss: 1.5266
# Epoch: 408 Train loss: 1.5142 Validation loss: 1.5266
# Epoch: 409 Train loss: 1.5142 Validation loss: 1.5266
# Epoch: 410 Train loss: 1.5142 Validation loss: 1.5265
# Epoch: 411 Train loss: 1.5142 Validation loss: 1.5265
# Epoch: 412 Train loss: 1.5141 Validation loss: 1.5265
# Epoch: 413 Train loss: 1.5141 Validation loss: 1.5265
# Epoch: 414 Train loss: 1.5141 Validation loss: 1.5265
# Epoch: 415 Train loss: 1.5141 Validation loss: 1.5264
# Epoch: 416 Train loss: 1.5141 Validation loss: 1.5264
# Epoch: 417 Train loss: 1.5141 Validation loss: 1.5264
# Epoch: 418 Train loss: 1.5141 Validation loss: 1.5264
# Epoch: 419 Train loss: 1.5141 Validation loss: 1.5264
# Epoch: 420 Train loss: 1.5141 Validation loss: 1.5264
# Epoch: 421 Train loss: 1.5141 Validation loss: 1.5263
# Epoch: 422 Train loss: 1.5141 Validation loss: 1.5263
# Epoch: 423 Train loss: 1.5141 Validation loss: 1.5263
# Epoch: 424 Train loss: 1.5141 Validation loss: 1.5263
# Epoch: 425 Train loss: 1.5141 Validation loss: 1.5263
# Epoch: 426 Train loss: 1.5141 Validation loss: 1.5262
# Epoch: 427 Train loss: 1.5141 Validation loss: 1.5262
# Epoch: 428 Train loss: 1.5141 Validation loss: 1.5262
# Epoch: 429 Train loss: 1.5141 Validation loss: 1.5262
# Epoch: 430 Train loss: 1.5141 Validation loss: 1.5262
# Epoch: 431 Train loss: 1.5141 Validation loss: 1.5262
# Epoch: 432 Train loss: 1.5141 Validation loss: 1.5261
# Epoch: 433 Train loss: 1.5141 Validation loss: 1.5261
# Epoch: 434 Train loss: 1.5141 Validation loss: 1.5261
# Epoch: 435 Train loss: 1.5141 Validation loss: 1.5261
# Epoch: 436 Train loss: 1.514 Validation loss: 1.5261
# Epoch: 437 Train loss: 1.514 Validation loss: 1.5261
# Epoch: 438 Train loss: 1.514 Validation loss: 1.526
# Epoch: 439 Train loss: 1.514 Validation loss: 1.526
# Epoch: 440 Train loss: 1.514 Validation loss: 1.526
# Epoch: 441 Train loss: 1.514 Validation loss: 1.526
# Epoch: 442 Train loss: 1.514 Validation loss: 1.526
# Epoch: 443 Train loss: 1.514 Validation loss: 1.526
# Epoch: 444 Train loss: 1.514 Validation loss: 1.5259
# Epoch: 445 Train loss: 1.514 Validation loss: 1.5259
# Epoch: 446 Train loss: 1.514 Validation loss: 1.5259
# Epoch: 447 Train loss: 1.514 Validation loss: 1.5259
# Epoch: 448 Train loss: 1.514 Validation loss: 1.5259
# Epoch: 449 Train loss: 1.514 Validation loss: 1.5259
# Epoch: 450 Train loss: 1.514 Validation loss: 1.5258
# Epoch: 451 Train loss: 1.514 Validation loss: 1.5258
# Epoch: 452 Train loss: 1.514 Validation loss: 1.5258
# Epoch: 453 Train loss: 1.514 Validation loss: 1.5258
# Epoch: 454 Train loss: 1.514 Validation loss: 1.5258
# Epoch: 455 Train loss: 1.514 Validation loss: 1.5258
# Epoch: 456 Train loss: 1.514 Validation loss: 1.5257
# Epoch: 457 Train loss: 1.514 Validation loss: 1.5257
# Epoch: 458 Train loss: 1.514 Validation loss: 1.5257
# Epoch: 459 Train loss: 1.514 Validation loss: 1.5257
# Epoch: 460 Train loss: 1.514 Validation loss: 1.5257
# Epoch: 461 Train loss: 1.5139 Validation loss: 1.5257
# Epoch: 462 Train loss: 1.5139 Validation loss: 1.5257
# Epoch: 463 Train loss: 1.5139 Validation loss: 1.5256
# Epoch: 464 Train loss: 1.5139 Validation loss: 1.5256
# Epoch: 465 Train loss: 1.5139 Validation loss: 1.5256
# Epoch: 466 Train loss: 1.5139 Validation loss: 1.5256
# Epoch: 467 Train loss: 1.5139 Validation loss: 1.5256
# Epoch: 468 Train loss: 1.5139 Validation loss: 1.5256
# Epoch: 469 Train loss: 1.5139 Validation loss: 1.5256
# Epoch: 470 Train loss: 1.5139 Validation loss: 1.5255
# Epoch: 471 Train loss: 1.5139 Validation loss: 1.5255
# Epoch: 472 Train loss: 1.5139 Validation loss: 1.5255
# Epoch: 473 Train loss: 1.5139 Validation loss: 1.5255
# Epoch: 474 Train loss: 1.5139 Validation loss: 1.5255
# Epoch: 475 Train loss: 1.5139 Validation loss: 1.5255
# Epoch: 476 Train loss: 1.5139 Validation loss: 1.5255
# Epoch: 477 Train loss: 1.5139 Validation loss: 1.5254
# Epoch: 478 Train loss: 1.5139 Validation loss: 1.5254
# Epoch: 479 Train loss: 1.5139 Validation loss: 1.5254
# Epoch: 480 Train loss: 1.5139 Validation loss: 1.5254
# Epoch: 481 Train loss: 1.5139 Validation loss: 1.5254
# Epoch: 482 Train loss: 1.5139 Validation loss: 1.5254
# Epoch: 483 Train loss: 1.5139 Validation loss: 1.5254
# Epoch: 484 Train loss: 1.5139 Validation loss: 1.5253
# Epoch: 485 Train loss: 1.5139 Validation loss: 1.5253
# Epoch: 486 Train loss: 1.5139 Validation loss: 1.5253
# Epoch: 487 Train loss: 1.5138 Validation loss: 1.5253
# Epoch: 488 Train loss: 1.5138 Validation loss: 1.5253
# Epoch: 489 Train loss: 1.5138 Validation loss: 1.5253
# Epoch: 490 Train loss: 1.5138 Validation loss: 1.5253
# Epoch: 491 Train loss: 1.5138 Validation loss: 1.5252
# Epoch: 492 Train loss: 1.5138 Validation loss: 1.5252
# Epoch: 493 Train loss: 1.5138 Validation loss: 1.5252
# Epoch: 494 Train loss: 1.5138 Validation loss: 1.5252
# Epoch: 495 Train loss: 1.5138 Validation loss: 1.5252
# Epoch: 496 Train loss: 1.5138 Validation loss: 1.5252
# Epoch: 497 Train loss: 1.5138 Validation loss: 1.5252
# Epoch: 498 Train loss: 1.5138 Validation loss: 1.5252
# Epoch: 499 Train loss: 1.5138 Validation loss: 1.5251
# Epoch: 500 Train loss: 1.5138 Validation loss: 1.5251
# Epoch: 501 Train loss: 1.5138 Validation loss: 1.5251
# Epoch: 502 Train loss: 1.5138 Validation loss: 1.5251
# Epoch: 503 Train loss: 1.5138 Validation loss: 1.5251
# Epoch: 504 Train loss: 1.5138 Validation loss: 1.5251
# Epoch: 505 Train loss: 1.5138 Validation loss: 1.5251
# Epoch: 506 Train loss: 1.5138 Validation loss: 1.5251
# Epoch: 507 Train loss: 1.5138 Validation loss: 1.525
# Epoch: 508 Train loss: 1.5138 Validation loss: 1.525
# Epoch: 509 Train loss: 1.5138 Validation loss: 1.525
# Epoch: 510 Train loss: 1.5138 Validation loss: 1.525
# Epoch: 511 Train loss: 1.5138 Validation loss: 1.525
# Epoch: 512 Train loss: 1.5138 Validation loss: 1.525
# Epoch: 513 Train loss: 1.5138 Validation loss: 1.525
# Epoch: 514 Train loss: 1.5137 Validation loss: 1.525
# Epoch: 515 Train loss: 1.5137 Validation loss: 1.5249
# Epoch: 516 Train loss: 1.5137 Validation loss: 1.5249
# Epoch: 517 Train loss: 1.5137 Validation loss: 1.5249
# Epoch: 518 Train loss: 1.5137 Validation loss: 1.5249
# Epoch: 519 Train loss: 1.5137 Validation loss: 1.5249
# Epoch: 520 Train loss: 1.5137 Validation loss: 1.5249
# Epoch: 521 Train loss: 1.5137 Validation loss: 1.5249
# Epoch: 522 Train loss: 1.5137 Validation loss: 1.5249
# Epoch: 523 Train loss: 1.5137 Validation loss: 1.5248
# Epoch: 524 Train loss: 1.5137 Validation loss: 1.5248
# Epoch: 525 Train loss: 1.5137 Validation loss: 1.5248
# Epoch: 526 Train loss: 1.5137 Validation loss: 1.5248
# Epoch: 527 Train loss: 1.5137 Validation loss: 1.5248
# Epoch: 528 Train loss: 1.5137 Validation loss: 1.5248
# Epoch: 529 Train loss: 1.5137 Validation loss: 1.5248
# Epoch: 530 Train loss: 1.5137 Validation loss: 1.5248
# Epoch: 531 Train loss: 1.5137 Validation loss: 1.5247
# Epoch: 532 Train loss: 1.5137 Validation loss: 1.5247
# Epoch: 533 Train loss: 1.5137 Validation loss: 1.5247
# Epoch: 534 Train loss: 1.5137 Validation loss: 1.5247
# Epoch: 535 Train loss: 1.5137 Validation loss: 1.5247
# Epoch: 536 Train loss: 1.5137 Validation loss: 1.5247
# Epoch: 537 Train loss: 1.5137 Validation loss: 1.5247
# Epoch: 538 Train loss: 1.5137 Validation loss: 1.5247
# Epoch: 539 Train loss: 1.5137 Validation loss: 1.5247
# Epoch: 540 Train loss: 1.5137 Validation loss: 1.5246
# Epoch: 541 Train loss: 1.5136 Validation loss: 1.5246
# Epoch: 542 Train loss: 1.5136 Validation loss: 1.5246
# Epoch: 543 Train loss: 1.5136 Validation loss: 1.5246
# Epoch: 544 Train loss: 1.5136 Validation loss: 1.5246
# Epoch: 545 Train loss: 1.5136 Validation loss: 1.5246
# Epoch: 546 Train loss: 1.5136 Validation loss: 1.5246
# Epoch: 547 Train loss: 1.5136 Validation loss: 1.5246
# Epoch: 548 Train loss: 1.5136 Validation loss: 1.5245
# Epoch: 549 Train loss: 1.5136 Validation loss: 1.5245
# Epoch: 550 Train loss: 1.5136 Validation loss: 1.5245
# Epoch: 551 Train loss: 1.5136 Validation loss: 1.5245
# Epoch: 552 Train loss: 1.5136 Validation loss: 1.5245
# Epoch: 553 Train loss: 1.5136 Validation loss: 1.5245
# Epoch: 554 Train loss: 1.5136 Validation loss: 1.5245
# Epoch: 555 Train loss: 1.5136 Validation loss: 1.5245
# Epoch: 556 Train loss: 1.5136 Validation loss: 1.5245
# Epoch: 557 Train loss: 1.5136 Validation loss: 1.5244
# Epoch: 558 Train loss: 1.5136 Validation loss: 1.5244
# Epoch: 559 Train loss: 1.5136 Validation loss: 1.5244
# Epoch: 560 Train loss: 1.5136 Validation loss: 1.5244
# Epoch: 561 Train loss: 1.5136 Validation loss: 1.5244
# Epoch: 562 Train loss: 1.5136 Validation loss: 1.5244
# Epoch: 563 Train loss: 1.5136 Validation loss: 1.5244
# Epoch: 564 Train loss: 1.5136 Validation loss: 1.5244
# Epoch: 565 Train loss: 1.5136 Validation loss: 1.5243
# Epoch: 566 Train loss: 1.5136 Validation loss: 1.5243
# Epoch: 567 Train loss: 1.5136 Validation loss: 1.5243
# Epoch: 568 Train loss: 1.5136 Validation loss: 1.5243
# Epoch: 569 Train loss: 1.5135 Validation loss: 1.5243
# Epoch: 570 Train loss: 1.5135 Validation loss: 1.5243
# Epoch: 571 Train loss: 1.5135 Validation loss: 1.5243
# Epoch: 572 Train loss: 1.5135 Validation loss: 1.5243
# Epoch: 573 Train loss: 1.5135 Validation loss: 1.5243
# Epoch: 574 Train loss: 1.5135 Validation loss: 1.5242
# Epoch: 575 Train loss: 1.5135 Validation loss: 1.5242
# Epoch: 576 Train loss: 1.5135 Validation loss: 1.5242
# Epoch: 577 Train loss: 1.5135 Validation loss: 1.5242
# Epoch: 578 Train loss: 1.5135 Validation loss: 1.5242
# Epoch: 579 Train loss: 1.5135 Validation loss: 1.5242
# Epoch: 580 Train loss: 1.5135 Validation loss: 1.5242
# Epoch: 581 Train loss: 1.5135 Validation loss: 1.5242
# Epoch: 582 Train loss: 1.5135 Validation loss: 1.5242
# Epoch: 583 Train loss: 1.5135 Validation loss: 1.5241
# Epoch: 584 Train loss: 1.5135 Validation loss: 1.5241
# Epoch: 585 Train loss: 1.5135 Validation loss: 1.5241
# Epoch: 586 Train loss: 1.5135 Validation loss: 1.5241
# Epoch: 587 Train loss: 1.5135 Validation loss: 1.5241
# Epoch: 588 Train loss: 1.5135 Validation loss: 1.5241
# Epoch: 589 Train loss: 1.5135 Validation loss: 1.5241
# Epoch: 590 Train loss: 1.5135 Validation loss: 1.5241
# Epoch: 591 Train loss: 1.5135 Validation loss: 1.5241
# Epoch: 592 Train loss: 1.5135 Validation loss: 1.524
# Epoch: 593 Train loss: 1.5135 Validation loss: 1.524
# Epoch: 594 Train loss: 1.5135 Validation loss: 1.524
# Epoch: 595 Train loss: 1.5135 Validation loss: 1.524
# Epoch: 596 Train loss: 1.5135 Validation loss: 1.524
# Epoch: 597 Train loss: 1.5135 Validation loss: 1.524
# Epoch: 598 Train loss: 1.5134 Validation loss: 1.524
# Epoch: 599 Train loss: 1.5134 Validation loss: 1.524
# Epoch: 600 Train loss: 1.5134 Validation loss: 1.524
# Epoch: 601 Train loss: 1.5134 Validation loss: 1.5239
# Epoch: 602 Train loss: 1.5134 Validation loss: 1.5239
# Epoch: 603 Train loss: 1.5134 Validation loss: 1.5239
# Epoch: 604 Train loss: 1.5134 Validation loss: 1.5239
# Epoch: 605 Train loss: 1.5134 Validation loss: 1.5239
# Epoch: 606 Train loss: 1.5134 Validation loss: 1.5239
# Epoch: 607 Train loss: 1.5134 Validation loss: 1.5239
# Epoch: 608 Train loss: 1.5134 Validation loss: 1.5239
# Epoch: 609 Train loss: 1.5134 Validation loss: 1.5239
# Epoch: 610 Train loss: 1.5134 Validation loss: 1.5238
# Epoch: 611 Train loss: 1.5134 Validation loss: 1.5238
# Epoch: 612 Train loss: 1.5134 Validation loss: 1.5238
# Epoch: 613 Train loss: 1.5134 Validation loss: 1.5238
# Epoch: 614 Train loss: 1.5134 Validation loss: 1.5238
# Epoch: 615 Train loss: 1.5134 Validation loss: 1.5238
# Epoch: 616 Train loss: 1.5134 Validation loss: 1.5238
# Epoch: 617 Train loss: 1.5134 Validation loss: 1.5238
# Epoch: 618 Train loss: 1.5134 Validation loss: 1.5238
# Epoch: 619 Train loss: 1.5134 Validation loss: 1.5237
# Epoch: 620 Train loss: 1.5134 Validation loss: 1.5237
# Epoch: 621 Train loss: 1.5134 Validation loss: 1.5237
# Epoch: 622 Train loss: 1.5134 Validation loss: 1.5237
# Epoch: 623 Train loss: 1.5134 Validation loss: 1.5237
# Epoch: 624 Train loss: 1.5134 Validation loss: 1.5237
# Epoch: 625 Train loss: 1.5134 Validation loss: 1.5237
# Epoch: 626 Train loss: 1.5134 Validation loss: 1.5237
# Epoch: 627 Train loss: 1.5133 Validation loss: 1.5236
# Epoch: 628 Train loss: 1.5133 Validation loss: 1.5236
# Epoch: 629 Train loss: 1.5133 Validation loss: 1.5236
# Epoch: 630 Train loss: 1.5133 Validation loss: 1.5236
# Epoch: 631 Train loss: 1.5133 Validation loss: 1.5236
# Epoch: 632 Train loss: 1.5133 Validation loss: 1.5236
# Epoch: 633 Train loss: 1.5133 Validation loss: 1.5236
# Epoch: 634 Train loss: 1.5133 Validation loss: 1.5236
# Epoch: 635 Train loss: 1.5133 Validation loss: 1.5236
# Epoch: 636 Train loss: 1.5133 Validation loss: 1.5235
# Epoch: 637 Train loss: 1.5133 Validation loss: 1.5235
# Epoch: 638 Train loss: 1.5133 Validation loss: 1.5235
# Epoch: 639 Train loss: 1.5133 Validation loss: 1.5235
# Epoch: 640 Train loss: 1.5133 Validation loss: 1.5235
# Epoch: 641 Train loss: 1.5133 Validation loss: 1.5235
# Epoch: 642 Train loss: 1.5133 Validation loss: 1.5235
# Epoch: 643 Train loss: 1.5133 Validation loss: 1.5235
# Epoch: 644 Train loss: 1.5133 Validation loss: 1.5235
# Epoch: 645 Train loss: 1.5133 Validation loss: 1.5234
# Epoch: 646 Train loss: 1.5133 Validation loss: 1.5234
# Epoch: 647 Train loss: 1.5133 Validation loss: 1.5234
# Epoch: 648 Train loss: 1.5133 Validation loss: 1.5234
# Epoch: 649 Train loss: 1.5133 Validation loss: 1.5234
# Epoch: 650 Train loss: 1.5133 Validation loss: 1.5234
# Epoch: 651 Train loss: 1.5133 Validation loss: 1.5234
# Epoch: 652 Train loss: 1.5133 Validation loss: 1.5234
# Epoch: 653 Train loss: 1.5133 Validation loss: 1.5233
# Epoch: 654 Train loss: 1.5133 Validation loss: 1.5233
# Epoch: 655 Train loss: 1.5133 Validation loss: 1.5233
# Epoch: 656 Train loss: 1.5132 Validation loss: 1.5233
# Epoch: 657 Train loss: 1.5132 Validation loss: 1.5233
# Epoch: 658 Train loss: 1.5132 Validation loss: 1.5233
# Epoch: 659 Train loss: 1.5132 Validation loss: 1.5233
# Epoch: 660 Train loss: 1.5132 Validation loss: 1.5233
# Epoch: 661 Train loss: 1.5132 Validation loss: 1.5233
# Epoch: 662 Train loss: 1.5132 Validation loss: 1.5232
# Epoch: 663 Train loss: 1.5132 Validation loss: 1.5232
# Epoch: 664 Train loss: 1.5132 Validation loss: 1.5232
# Epoch: 665 Train loss: 1.5132 Validation loss: 1.5232
# Epoch: 666 Train loss: 1.5132 Validation loss: 1.5232
# Epoch: 667 Train loss: 1.5132 Validation loss: 1.5232
# Epoch: 668 Train loss: 1.5132 Validation loss: 1.5232
# Epoch: 669 Train loss: 1.5132 Validation loss: 1.5232
# Epoch: 670 Train loss: 1.5132 Validation loss: 1.5231
# Epoch: 671 Train loss: 1.5132 Validation loss: 1.5231
# Epoch: 672 Train loss: 1.5132 Validation loss: 1.5231
# Epoch: 673 Train loss: 1.5132 Validation loss: 1.5231
# Epoch: 674 Train loss: 1.5132 Validation loss: 1.5231
# Epoch: 675 Train loss: 1.5132 Validation loss: 1.5231
# Epoch: 676 Train loss: 1.5132 Validation loss: 1.5231
# Epoch: 677 Train loss: 1.5132 Validation loss: 1.5231
# Epoch: 678 Train loss: 1.5132 Validation loss: 1.523
# Epoch: 679 Train loss: 1.5132 Validation loss: 1.523
# Epoch: 680 Train loss: 1.5132 Validation loss: 1.523
# Epoch: 681 Train loss: 1.5132 Validation loss: 1.523
# Epoch: 682 Train loss: 1.5132 Validation loss: 1.523
# Epoch: 683 Train loss: 1.5132 Validation loss: 1.523
# Epoch: 684 Train loss: 1.5132 Validation loss: 1.523
# Epoch: 685 Train loss: 1.5131 Validation loss: 1.523
# Epoch: 686 Train loss: 1.5131 Validation loss: 1.5229
# Epoch: 687 Train loss: 1.5131 Validation loss: 1.5229
# Epoch: 688 Train loss: 1.5131 Validation loss: 1.5229
# Epoch: 689 Train loss: 1.5131 Validation loss: 1.5229
# Epoch: 690 Train loss: 1.5131 Validation loss: 1.5229
# Epoch: 691 Train loss: 1.5131 Validation loss: 1.5229
# Epoch: 692 Train loss: 1.5131 Validation loss: 1.5229
# Epoch: 693 Train loss: 1.5131 Validation loss: 1.5229
# Epoch: 694 Train loss: 1.5131 Validation loss: 1.5228
# Epoch: 695 Train loss: 1.5131 Validation loss: 1.5228
# Epoch: 696 Train loss: 1.5131 Validation loss: 1.5228
# Epoch: 697 Train loss: 1.5131 Validation loss: 1.5228
# Epoch: 698 Train loss: 1.5131 Validation loss: 1.5228
# Epoch: 699 Train loss: 1.5131 Validation loss: 1.5228
# Epoch: 700 Train loss: 1.5131 Validation loss: 1.5228
# Epoch: 701 Train loss: 1.5131 Validation loss: 1.5228
# Epoch: 702 Train loss: 1.5131 Validation loss: 1.5227
# Epoch: 703 Train loss: 1.5131 Validation loss: 1.5227
# Epoch: 704 Train loss: 1.5131 Validation loss: 1.5227
# Epoch: 705 Train loss: 1.5131 Validation loss: 1.5227
# Epoch: 706 Train loss: 1.5131 Validation loss: 1.5227
# Epoch: 707 Train loss: 1.5131 Validation loss: 1.5227
# Epoch: 708 Train loss: 1.5131 Validation loss: 1.5227
# Epoch: 709 Train loss: 1.5131 Validation loss: 1.5226
# Epoch: 710 Train loss: 1.5131 Validation loss: 1.5226
# Epoch: 711 Train loss: 1.5131 Validation loss: 1.5226
# Epoch: 712 Train loss: 1.5131 Validation loss: 1.5226
# Epoch: 713 Train loss: 1.5131 Validation loss: 1.5226
# Epoch: 714 Train loss: 1.5131 Validation loss: 1.5226
# Epoch: 715 Train loss: 1.513 Validation loss: 1.5226
# Epoch: 716 Train loss: 1.513 Validation loss: 1.5226
# Epoch: 717 Train loss: 1.513 Validation loss: 1.5225
# Epoch: 718 Train loss: 1.513 Validation loss: 1.5225
# Epoch: 719 Train loss: 1.513 Validation loss: 1.5225
# Epoch: 720 Train loss: 1.513 Validation loss: 1.5225
# Epoch: 721 Train loss: 1.513 Validation loss: 1.5225
# Epoch: 722 Train loss: 1.513 Validation loss: 1.5225
# Epoch: 723 Train loss: 1.513 Validation loss: 1.5225
# Epoch: 724 Train loss: 1.513 Validation loss: 1.5224
# Epoch: 725 Train loss: 1.513 Validation loss: 1.5224
# Epoch: 726 Train loss: 1.513 Validation loss: 1.5224
# Epoch: 727 Train loss: 1.513 Validation loss: 1.5224
# Epoch: 728 Train loss: 1.513 Validation loss: 1.5224
# Epoch: 729 Train loss: 1.513 Validation loss: 1.5224
# Epoch: 730 Train loss: 1.513 Validation loss: 1.5224
# Epoch: 731 Train loss: 1.513 Validation loss: 1.5223
# Epoch: 732 Train loss: 1.513 Validation loss: 1.5223
# Epoch: 733 Train loss: 1.513 Validation loss: 1.5223
# Epoch: 734 Train loss: 1.513 Validation loss: 1.5223
# Epoch: 735 Train loss: 1.513 Validation loss: 1.5223
# Epoch: 736 Train loss: 1.513 Validation loss: 1.5223
# Epoch: 737 Train loss: 1.513 Validation loss: 1.5223
# Epoch: 738 Train loss: 1.513 Validation loss: 1.5223
# Epoch: 739 Train loss: 1.513 Validation loss: 1.5222
# Epoch: 740 Train loss: 1.513 Validation loss: 1.5222
# Epoch: 741 Train loss: 1.513 Validation loss: 1.5222
# Epoch: 742 Train loss: 1.513 Validation loss: 1.5222
# Epoch: 743 Train loss: 1.513 Validation loss: 1.5222
# Epoch: 744 Train loss: 1.5129 Validation loss: 1.5222
# Epoch: 745 Train loss: 1.5129 Validation loss: 1.5221
# Epoch: 746 Train loss: 1.5129 Validation loss: 1.5221
# Epoch: 747 Train loss: 1.5129 Validation loss: 1.5221
# Epoch: 748 Train loss: 1.5129 Validation loss: 1.5221
# Epoch: 749 Train loss: 1.5129 Validation loss: 1.5221
# Epoch: 750 Train loss: 1.5129 Validation loss: 1.5221
# Epoch: 751 Train loss: 1.5129 Validation loss: 1.5221
# Epoch: 752 Train loss: 1.5129 Validation loss: 1.522
# Epoch: 753 Train loss: 1.5129 Validation loss: 1.522
# Epoch: 754 Train loss: 1.5129 Validation loss: 1.522
# Epoch: 755 Train loss: 1.5129 Validation loss: 1.522
# Epoch: 756 Train loss: 1.5129 Validation loss: 1.522
# Epoch: 757 Train loss: 1.5129 Validation loss: 1.522
# Epoch: 758 Train loss: 1.5129 Validation loss: 1.522
# Epoch: 759 Train loss: 1.5129 Validation loss: 1.5219
# Epoch: 760 Train loss: 1.5129 Validation loss: 1.5219
# Epoch: 761 Train loss: 1.5129 Validation loss: 1.5219
# Epoch: 762 Train loss: 1.5129 Validation loss: 1.5219
# Epoch: 763 Train loss: 1.5129 Validation loss: 1.5219
# Epoch: 764 Train loss: 1.5129 Validation loss: 1.5219
# Epoch: 765 Train loss: 1.5129 Validation loss: 1.5218
# Epoch: 766 Train loss: 1.5129 Validation loss: 1.5218
# Epoch: 767 Train loss: 1.5129 Validation loss: 1.5218
# Epoch: 768 Train loss: 1.5129 Validation loss: 1.5218
# Epoch: 769 Train loss: 1.5129 Validation loss: 1.5218
# Epoch: 770 Train loss: 1.5129 Validation loss: 1.5218
# Epoch: 771 Train loss: 1.5129 Validation loss: 1.5218
# Epoch: 772 Train loss: 1.5129 Validation loss: 1.5217
# Epoch: 773 Train loss: 1.5129 Validation loss: 1.5217
# Epoch: 774 Train loss: 1.5128 Validation loss: 1.5217
# Epoch: 775 Train loss: 1.5128 Validation loss: 1.5217
# Epoch: 776 Train loss: 1.5128 Validation loss: 1.5217
# Epoch: 777 Train loss: 1.5128 Validation loss: 1.5217
# Epoch: 778 Train loss: 1.5128 Validation loss: 1.5216
# Epoch: 779 Train loss: 1.5128 Validation loss: 1.5216
# Epoch: 780 Train loss: 1.5128 Validation loss: 1.5216
# Epoch: 781 Train loss: 1.5128 Validation loss: 1.5216
# Epoch: 782 Train loss: 1.5128 Validation loss: 1.5216
# Epoch: 783 Train loss: 1.5128 Validation loss: 1.5216
# Epoch: 784 Train loss: 1.5128 Validation loss: 1.5215
# Epoch: 785 Train loss: 1.5128 Validation loss: 1.5215
# Epoch: 786 Train loss: 1.5128 Validation loss: 1.5215
# Epoch: 787 Train loss: 1.5128 Validation loss: 1.5215
# Epoch: 788 Train loss: 1.5128 Validation loss: 1.5215
# Epoch: 789 Train loss: 1.5128 Validation loss: 1.5215
# Epoch: 790 Train loss: 1.5128 Validation loss: 1.5214
# Epoch: 791 Train loss: 1.5128 Validation loss: 1.5214
# Epoch: 792 Train loss: 1.5128 Validation loss: 1.5214
# Epoch: 793 Train loss: 1.5128 Validation loss: 1.5214
# Epoch: 794 Train loss: 1.5128 Validation loss: 1.5214
# Epoch: 795 Train loss: 1.5128 Validation loss: 1.5214
# Epoch: 796 Train loss: 1.5128 Validation loss: 1.5213
# Epoch: 797 Train loss: 1.5128 Validation loss: 1.5213
# Epoch: 798 Train loss: 1.5128 Validation loss: 1.5213
# Epoch: 799 Train loss: 1.5128 Validation loss: 1.5213
# Epoch: 800 Train loss: 1.5128 Validation loss: 1.5213
# Epoch: 801 Train loss: 1.5128 Validation loss: 1.5213
# Epoch: 802 Train loss: 1.5128 Validation loss: 1.5212
# Epoch: 803 Train loss: 1.5128 Validation loss: 1.5212
# Epoch: 804 Train loss: 1.5127 Validation loss: 1.5212
# Epoch: 805 Train loss: 1.5127 Validation loss: 1.5212
# Epoch: 806 Train loss: 1.5127 Validation loss: 1.5212
# Epoch: 807 Train loss: 1.5127 Validation loss: 1.5212
# Epoch: 808 Train loss: 1.5127 Validation loss: 1.5211
# Epoch: 809 Train loss: 1.5127 Validation loss: 1.5211
# Epoch: 810 Train loss: 1.5127 Validation loss: 1.5211
# Epoch: 811 Train loss: 1.5127 Validation loss: 1.5211
# Epoch: 812 Train loss: 1.5127 Validation loss: 1.5211
# Epoch: 813 Train loss: 1.5127 Validation loss: 1.5211
# Epoch: 814 Train loss: 1.5127 Validation loss: 1.521
# Epoch: 815 Train loss: 1.5127 Validation loss: 1.521
# Epoch: 816 Train loss: 1.5127 Validation loss: 1.521
# Epoch: 817 Train loss: 1.5127 Validation loss: 1.521
# Epoch: 818 Train loss: 1.5127 Validation loss: 1.521
# Epoch: 819 Train loss: 1.5127 Validation loss: 1.5209
# Epoch: 820 Train loss: 1.5127 Validation loss: 1.5209
# Epoch: 821 Train loss: 1.5127 Validation loss: 1.5209
# Epoch: 822 Train loss: 1.5127 Validation loss: 1.5209
# Epoch: 823 Train loss: 1.5127 Validation loss: 1.5209
# Epoch: 824 Train loss: 1.5127 Validation loss: 1.5209
# Epoch: 825 Train loss: 1.5127 Validation loss: 1.5208
# Epoch: 826 Train loss: 1.5127 Validation loss: 1.5208
# Epoch: 827 Train loss: 1.5127 Validation loss: 1.5208
# Epoch: 828 Train loss: 1.5127 Validation loss: 1.5208
# Epoch: 829 Train loss: 1.5127 Validation loss: 1.5208
# Epoch: 830 Train loss: 1.5127 Validation loss: 1.5207
# Epoch: 831 Train loss: 1.5127 Validation loss: 1.5207
# Epoch: 832 Train loss: 1.5127 Validation loss: 1.5207
# Epoch: 833 Train loss: 1.5127 Validation loss: 1.5207
# Epoch: 834 Train loss: 1.5126 Validation loss: 1.5207
# Epoch: 835 Train loss: 1.5126 Validation loss: 1.5206
# Epoch: 836 Train loss: 1.5126 Validation loss: 1.5206
# Epoch: 837 Train loss: 1.5126 Validation loss: 1.5206
# Epoch: 838 Train loss: 1.5126 Validation loss: 1.5206
# Epoch: 839 Train loss: 1.5126 Validation loss: 1.5206
# Epoch: 840 Train loss: 1.5126 Validation loss: 1.5206
# Epoch: 841 Train loss: 1.5126 Validation loss: 1.5205
# Epoch: 842 Train loss: 1.5126 Validation loss: 1.5205
# Epoch: 843 Train loss: 1.5126 Validation loss: 1.5205
# Epoch: 844 Train loss: 1.5126 Validation loss: 1.5205
# Epoch: 845 Train loss: 1.5126 Validation loss: 1.5205
# Epoch: 846 Train loss: 1.5126 Validation loss: 1.5204
# Epoch: 847 Train loss: 1.5126 Validation loss: 1.5204
# Epoch: 848 Train loss: 1.5126 Validation loss: 1.5204
# Epoch: 849 Train loss: 1.5126 Validation loss: 1.5204
# Epoch: 850 Train loss: 1.5126 Validation loss: 1.5204
# Epoch: 851 Train loss: 1.5126 Validation loss: 1.5203
# Epoch: 852 Train loss: 1.5126 Validation loss: 1.5203
# Epoch: 853 Train loss: 1.5126 Validation loss: 1.5203
# Epoch: 854 Train loss: 1.5126 Validation loss: 1.5203
# Epoch: 855 Train loss: 1.5126 Validation loss: 1.5203
# Epoch: 856 Train loss: 1.5126 Validation loss: 1.5202
# Epoch: 857 Train loss: 1.5126 Validation loss: 1.5202
# Epoch: 858 Train loss: 1.5126 Validation loss: 1.5202
# Epoch: 859 Train loss: 1.5126 Validation loss: 1.5202
# Epoch: 860 Train loss: 1.5126 Validation loss: 1.5202
# Epoch: 861 Train loss: 1.5126 Validation loss: 1.5201
# Epoch: 862 Train loss: 1.5126 Validation loss: 1.5201
# Epoch: 863 Train loss: 1.5125 Validation loss: 1.5201
# Epoch: 864 Train loss: 1.5125 Validation loss: 1.5201
# Epoch: 865 Train loss: 1.5125 Validation loss: 1.52
# Epoch: 866 Train loss: 1.5125 Validation loss: 1.52
# Epoch: 867 Train loss: 1.5125 Validation loss: 1.52
# Epoch: 868 Train loss: 1.5125 Validation loss: 1.52
# Epoch: 869 Train loss: 1.5125 Validation loss: 1.52
# Epoch: 870 Train loss: 1.5125 Validation loss: 1.5199
# Epoch: 871 Train loss: 1.5125 Validation loss: 1.5199
# Epoch: 872 Train loss: 1.5125 Validation loss: 1.5199
# Epoch: 873 Train loss: 1.5125 Validation loss: 1.5199
# Epoch: 874 Train loss: 1.5125 Validation loss: 1.5199
# Epoch: 875 Train loss: 1.5125 Validation loss: 1.5198
# Epoch: 876 Train loss: 1.5125 Validation loss: 1.5198
# Epoch: 877 Train loss: 1.5125 Validation loss: 1.5198
# Epoch: 878 Train loss: 1.5125 Validation loss: 1.5198
# Epoch: 879 Train loss: 1.5125 Validation loss: 1.5198
# Epoch: 880 Train loss: 1.5125 Validation loss: 1.5197
# Epoch: 881 Train loss: 1.5125 Validation loss: 1.5197
# Epoch: 882 Train loss: 1.5125 Validation loss: 1.5197
# Epoch: 883 Train loss: 1.5125 Validation loss: 1.5197
# Epoch: 884 Train loss: 1.5125 Validation loss: 1.5196
# Epoch: 885 Train loss: 1.5125 Validation loss: 1.5196
# Epoch: 886 Train loss: 1.5125 Validation loss: 1.5196
# Epoch: 887 Train loss: 1.5125 Validation loss: 1.5196
# Epoch: 888 Train loss: 1.5125 Validation loss: 1.5196
# Epoch: 889 Train loss: 1.5125 Validation loss: 1.5195
# Epoch: 890 Train loss: 1.5125 Validation loss: 1.5195
# Epoch: 891 Train loss: 1.5125 Validation loss: 1.5195
# Epoch: 892 Train loss: 1.5125 Validation loss: 1.5195
# Epoch: 893 Train loss: 1.5125 Validation loss: 1.5194
# Epoch: 894 Train loss: 1.5124 Validation loss: 1.5194
# Epoch: 895 Train loss: 1.5124 Validation loss: 1.5194
# Epoch: 896 Train loss: 1.5124 Validation loss: 1.5194
# Epoch: 897 Train loss: 1.5124 Validation loss: 1.5193
# Epoch: 898 Train loss: 1.5124 Validation loss: 1.5193
# Epoch: 899 Train loss: 1.5124 Validation loss: 1.5193
# Epoch: 900 Train loss: 1.5124 Validation loss: 1.5193
# Epoch: 901 Train loss: 1.5124 Validation loss: 1.5193
# Epoch: 902 Train loss: 1.5124 Validation loss: 1.5192
# Epoch: 903 Train loss: 1.5124 Validation loss: 1.5192
# Epoch: 904 Train loss: 1.5124 Validation loss: 1.5192
# Epoch: 905 Train loss: 1.5124 Validation loss: 1.5192
# Epoch: 906 Train loss: 1.5124 Validation loss: 1.5191
# Epoch: 907 Train loss: 1.5124 Validation loss: 1.5191
# Epoch: 908 Train loss: 1.5124 Validation loss: 1.5191
# Epoch: 909 Train loss: 1.5124 Validation loss: 1.5191
# Epoch: 910 Train loss: 1.5124 Validation loss: 1.519
# Epoch: 911 Train loss: 1.5124 Validation loss: 1.519
# Epoch: 912 Train loss: 1.5124 Validation loss: 1.519
# Epoch: 913 Train loss: 1.5124 Validation loss: 1.519
# Epoch: 914 Train loss: 1.5124 Validation loss: 1.519
# Epoch: 915 Train loss: 1.5124 Validation loss: 1.5189
# Epoch: 916 Train loss: 1.5124 Validation loss: 1.5189
# Epoch: 917 Train loss: 1.5124 Validation loss: 1.5189
# Epoch: 918 Train loss: 1.5124 Validation loss: 1.5189
# Epoch: 919 Train loss: 1.5124 Validation loss: 1.5188
# Epoch: 920 Train loss: 1.5124 Validation loss: 1.5188
# Epoch: 921 Train loss: 1.5124 Validation loss: 1.5188
# Epoch: 922 Train loss: 1.5124 Validation loss: 1.5188
# Epoch: 923 Train loss: 1.5124 Validation loss: 1.5187
# Epoch: 924 Train loss: 1.5123 Validation loss: 1.5187
# Epoch: 925 Train loss: 1.5123 Validation loss: 1.5187
# Epoch: 926 Train loss: 1.5123 Validation loss: 1.5187
# Epoch: 927 Train loss: 1.5123 Validation loss: 1.5186
# Epoch: 928 Train loss: 1.5123 Validation loss: 1.5186
# Epoch: 929 Train loss: 1.5123 Validation loss: 1.5186
# Epoch: 930 Train loss: 1.5123 Validation loss: 1.5186
# Epoch: 931 Train loss: 1.5123 Validation loss: 1.5185
# Epoch: 932 Train loss: 1.5123 Validation loss: 1.5185
# Epoch: 933 Train loss: 1.5123 Validation loss: 1.5185
# Epoch: 934 Train loss: 1.5123 Validation loss: 1.5185
# Epoch: 935 Train loss: 1.5123 Validation loss: 1.5184
# Epoch: 936 Train loss: 1.5123 Validation loss: 1.5184
# Epoch: 937 Train loss: 1.5123 Validation loss: 1.5184
# Epoch: 938 Train loss: 1.5123 Validation loss: 1.5184
# Epoch: 939 Train loss: 1.5123 Validation loss: 1.5183
# Epoch: 940 Train loss: 1.5123 Validation loss: 1.5183
# Epoch: 941 Train loss: 1.5123 Validation loss: 1.5183
# Epoch: 942 Train loss: 1.5123 Validation loss: 1.5183
# Epoch: 943 Train loss: 1.5123 Validation loss: 1.5182
# Epoch: 944 Train loss: 1.5123 Validation loss: 1.5182
# Epoch: 945 Train loss: 1.5123 Validation loss: 1.5182
# Epoch: 946 Train loss: 1.5123 Validation loss: 1.5181
# Epoch: 947 Train loss: 1.5123 Validation loss: 1.5181
# Epoch: 948 Train loss: 1.5123 Validation loss: 1.5181
# Epoch: 949 Train loss: 1.5123 Validation loss: 1.5181
# Epoch: 950 Train loss: 1.5123 Validation loss: 1.518
# Epoch: 951 Train loss: 1.5123 Validation loss: 1.518
# Epoch: 952 Train loss: 1.5123 Validation loss: 1.518
# Epoch: 953 Train loss: 1.5123 Validation loss: 1.518
# Epoch: 954 Train loss: 1.5122 Validation loss: 1.5179
# Epoch: 955 Train loss: 1.5122 Validation loss: 1.5179
# Epoch: 956 Train loss: 1.5122 Validation loss: 1.5179
# Epoch: 957 Train loss: 1.5122 Validation loss: 1.5179
# Epoch: 958 Train loss: 1.5122 Validation loss: 1.5178
# Epoch: 959 Train loss: 1.5122 Validation loss: 1.5178
# Epoch: 960 Train loss: 1.5122 Validation loss: 1.5178
# Epoch: 961 Train loss: 1.5122 Validation loss: 1.5177
# Epoch: 962 Train loss: 1.5122 Validation loss: 1.5177
# Epoch: 963 Train loss: 1.5122 Validation loss: 1.5177
# Epoch: 964 Train loss: 1.5122 Validation loss: 1.5177
# Epoch: 965 Train loss: 1.5122 Validation loss: 1.5176
# Epoch: 966 Train loss: 1.5122 Validation loss: 1.5176
# Epoch: 967 Train loss: 1.5122 Validation loss: 1.5176
# Epoch: 968 Train loss: 1.5122 Validation loss: 1.5176
# Epoch: 969 Train loss: 1.5122 Validation loss: 1.5175
# Epoch: 970 Train loss: 1.5122 Validation loss: 1.5175
# Epoch: 971 Train loss: 1.5122 Validation loss: 1.5175
# Epoch: 972 Train loss: 1.5122 Validation loss: 1.5174
# Epoch: 973 Train loss: 1.5122 Validation loss: 1.5174
# Epoch: 974 Train loss: 1.5122 Validation loss: 1.5174
# Epoch: 975 Train loss: 1.5122 Validation loss: 1.5174
# Epoch: 976 Train loss: 1.5122 Validation loss: 1.5173
# Epoch: 977 Train loss: 1.5122 Validation loss: 1.5173
# Epoch: 978 Train loss: 1.5122 Validation loss: 1.5173
# Epoch: 979 Train loss: 1.5122 Validation loss: 1.5172
# Epoch: 980 Train loss: 1.5122 Validation loss: 1.5172
# Epoch: 981 Train loss: 1.5122 Validation loss: 1.5172
# Epoch: 982 Train loss: 1.5122 Validation loss: 1.5172
# Epoch: 983 Train loss: 1.5122 Validation loss: 1.5171
# Epoch: 984 Train loss: 1.5122 Validation loss: 1.5171
# Epoch: 985 Train loss: 1.5121 Validation loss: 1.5171
# Epoch: 986 Train loss: 1.5121 Validation loss: 1.517
# Epoch: 987 Train loss: 1.5121 Validation loss: 1.517
# Epoch: 988 Train loss: 1.5121 Validation loss: 1.517
# Epoch: 989 Train loss: 1.5121 Validation loss: 1.517
# Epoch: 990 Train loss: 1.5121 Validation loss: 1.5169
# Epoch: 991 Train loss: 1.5121 Validation loss: 1.5169
# Epoch: 992 Train loss: 1.5121 Validation loss: 1.5169
# Epoch: 993 Train loss: 1.5121 Validation loss: 1.5168
# Epoch: 994 Train loss: 1.5121 Validation loss: 1.5168
# Epoch: 995 Train loss: 1.5121 Validation loss: 1.5168
# Epoch: 996 Train loss: 1.5121 Validation loss: 1.5168
# Epoch: 997 Train loss: 1.5121 Validation loss: 1.5167
# Epoch: 998 Train loss: 1.5121 Validation loss: 1.5167
# Epoch: 999 Train loss: 1.5121 Validation loss: 1.5167

# %% [markdown]
# Predicting with this model shows overfitting. For recognizing overfitting a comparison of the validation and training loss is very useful. If the training loss decreases during training while the validation loss consistently increases, the model you are training is probably overfitting. Plotting the models prediction and the target also shows that there is a significant discrepancy between the target and the prediction of the model.

# %%
y_pred = big_mdl.__call__(x)# Predict on x with "big_mdl"
plt.scatter(x_train_overfit, y_train_overfit)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Target", "Prediction", "Training samples"])
plt.show()

# %% [markdown]
# In order to implement a regularization we need to modify the loss function. Since the loss function in this exercise is computed during the training step, we define a new training step with a regularization.

# %%
""" In order to avoid overfitting we implement a training step that also includes a regularization on the weights of our big model. For this we use the Frobenius/squared l2-norm of each weight matrix/vector. 
Hint: Use the tf.reduce_sum() function on a list of individual regularization terms for each matrix/vector of the network."""

def regularized_train_step(model, optimizer, x, y, lmbd):
    with tf.GradientTape() as tape:
        tape.watch(model.trainable_variables)
        y_pred = model.__call__ (x)# Compute a prediction with "model" on the input "x"
        y = tf.reshape(y, [-1,1])
        loss_val = tf.compat.v1.losses.mean_squared_error(y, y_pred) # Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y"
        regul_list = []
        for index in range(len(model.trainable_variables)):
            train_var =model.trainable_variables [index]
            #print(train_var)
            if index % 2 == 0:
                append_val = tf.norm(train_var)
            else:
                append_val = tf.pow(tf.norm(train_var, ord = 2),2)
            regul_list.append(append_val)
                #tf.pow(tf.linalg.norm(train_var, ord= 'fro', axis = [-2,-1]),2))
        regul_val = tf.reduce_sum(regul_list) # Compute the regularization based on the list "model.trainable_variables"
        total_loss = loss_val + lmbd * regul_val# Add the loss with a the regularization term weighted by "lmbd"
    grads = tape.gradient(total_loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    return loss_val
# regul_list = []
# for train_var in big_reg_mdl.trainable_variables:
#     #print(train_var)
#     regul_list.append(2*tf.nn.l2_loss(train_var))
#         #tf.pow(tf.linalg.norm(train_var, ord= 'fro', axis = [-2,-1]),2))
# regul_val = tf.reduce_sum(regul_list) # Compute the regularization based on the list "model.trainable_variables"
# print(regul_val)
# print(regul_list)
# total_loss = 0 + lmbd * regul_val

# %% [markdown]
# We can now set the strength of the regularization and retrain the big model with a regularization. We create another instance of the big model in order to compare the big model with and without regularization.

# %%
""" Implement the training for the bigger model with the regularized_train_step function. Note: We are plotting the MSE loss without the regularization in order to compare it with the unregularized model. """

lmbd = 0.005

big_reg_mdl = MyBigModel()
big_opt = tf.optimizers.SGD(learning_rate)

epoch = 0
train_iters = 0
train_loss = 0.0
for x_t, y_t in train_overfit_ds:
    train_loss += regularized_train_step(big_reg_mdl, big_opt, x_t, y_t, lmbd) # Perform a regularized training step with the model "big_mdl" and the optimizer "big_opt" on the inputs "x_t" and the corresponding targets "y_t" with the regularization parameter being "lmbd"
    train_iters += 1
    if train_iters == batch_size:# An epoch is completed
        for x_v, y_v in validation_ds:
            y_pred =big_reg_mdl.__call__(x_v) # Compute a prediction with "big_mdl" on the input "x_v"
            y_v = tf.reshape(y_v, [-1,1])
            validation_loss = tf.compat.v1.losses.mean_squared_error(y_v, y_pred)# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_v"
        print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
        train_iters = 0
        train_loss = 0.0
        train_reg = 0.0
        epoch += 1
    if (epoch == N_epochs):
        break

# %% [markdown]
# During the training of the regularized model we can already notice, that, although there is still a difference between training and validation loss, the validation loss decreases as the training loss dreases. The effect of the regularization becomes even more evident if we plot the predictions of the regularized model and the overfitting model.

# %%
""" We now want to plot the prediction of the regularized and unregularized big model. """

y_pred = big_reg_mdl.__call__(x)# Predict with "big_reg_mdl" on "x"
y_pred_overfit = big_mdl.__call__(x)# Predict with "reg_mdl" on "x"
plt.scatter(x_train_overfit, y_train_overfit)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.plot(x, y_pred_overfit.numpy())
plt.legend(["Target", "Regularization", "No regularization", "Training samples"])
plt.show()

# %% [markdown]
# The model with regularization seems to follow the overall trend of the data, while the model without any regularization very precisely fits the training samples. This is espacilly evident in the interval $\left[0,0.5\right]$, where the prediction of the unregularized model shows an oscillating behavior. Such oscillations are however not present in the ground truth and therefore undesirable. The regularized model on the other hand is not as flexible as the unregularized model and therefore does not fit the target function well in the interval $\left[2.25, 3.0\right]$.
#
# ## Conclusion
# In this exercise we revisited the mathematical background for a simple regression task and covered it's practical implementation in Tensorflow 2. We also explored the phenomenon of overfitting and derived different regularizations from a probabilistic perspective. This exercise covers a very simple task with a very basic neural architecture and is intended as a primer for the second part of the regression exercise, which is dealing with a bigger and more realistic problem. In this second part we will consider the problem of estimating the age of a person from a potrait picture.
