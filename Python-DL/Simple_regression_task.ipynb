# %% [markdown]
# # Deep learning programming I-A: Regression
# Felix Wiewel, Institute of Signal Processing and System Theory, University of Stuttgart, 24.04.2020
#
# ## Introduction
# This programming exercise is the first of a series of exercises, which are intended as a supplement to the theoretical part of the Deep Learning course offered by the ISS. The goal is to introduce you to basic tasks and applications of methods you have encountered in the lecture. After completing the exercise you should be familiar with the basic ideas and one, possibly simple, way of solving the respective task. It is worth mentioning that most of the tasks can be solved in many different, not necessarily deep learning based, ways and the solution presented here is just one of them.
#
# ## Regression
#
# In this exercise we consider the problem of regression, where we are interested in modeling a functional dependence between different variables with, possibly noisy, observations of input-output pairs. Mathematically such a dependence can be formulated as
#
# $\mathbf{y}=f(\mathbf{x})+\boldsymbol{\epsilon}$,
#
# where $\mathbf{y}\in\mathbb{R}^{M}$ and $\mathbf{x}\in\mathbb{R}^{N}$ are the input and output observations, $f:\mathbb{R}^{N}\rightarrow\mathbb{R}^{M}$ is the function mapping inputs to outputs and $\boldsymbol{\epsilon}\in\mathbb{R}^{M}$ is a random vector, which models noise in our observations. Note that this assumes additive noise that only acts on the output and not on the input variable, which might not be true in all practical applications but is a reasonable approximation. For regression we are now interested in estimating the functional relationship $f$ between the inputs and outputs. This can be done in many different ways, not just with neural networks, but for this exercise we focus on approximating this relationship with a neural network $g_{\boldsymbol{\theta}}:\mathbb{R}^{N}\rightarrow\mathbb{R}^{M}$ with parameter vector $\boldsymbol{\theta}$. The task is now to choose the parameters of the neural network in a way that results in a "good" approximation of $f$ with $g_{\boldsymbol{\theta}}$.
#
# In order to quantify how "good" our neural network can approximate $f$, we adopt a probabilistic view. For this we make the assumption that the noise $\boldsymbol{\epsilon}$ is a random vector drawn from a known dustribution, which enables us to derive a suitable cost function for training our neural network and also for quantifying a "good" approximation.
#
# ### Mathematical formulation
# If we assume that the noise $\boldsymbol{\epsilon}$ is drawn from a gaussian distribution, e.g. $\boldsymbol{\epsilon}\sim\mathcal{N}(\mathbf{0},\sigma^{2}\mathbf{I})$, we can use
#
# $\mathbf{y}=g_{\boldsymbol{\theta}}(\mathbf{x})+\boldsymbol{\epsilon}\Rightarrow \mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})=\boldsymbol{\epsilon}$
#
# to derive a log likelihood. Since the probability density function (pdf) of a multivariate normal distribution is given by
#
# $p(\mathbf{x})=\dfrac{1}{\sqrt{(2\pi)^{D}\vert\mathbf{C}\vert}}\mathrm{e}^{-\dfrac{1}{2}(\mathbf{x}-\boldsymbol{\mu})\mathbf{C}^{-1}(\mathbf{x}-\boldsymbol{\mu})^{T}}$,
#
# we get
#
# $\ln{p(\boldsymbol{\epsilon})}=\ln{\dfrac{1}{\sqrt{(2\pi)^{M}\sigma^{2}}}\mathrm{e}^{-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\epsilon}\Vert_{2}^{2}}}=-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\epsilon}\Vert_{2}^{2}-\dfrac{1}{2}\ln{(2\pi)^{M}\sigma^{2}}$.
#
# Replacing $\boldsymbol{\epsilon}$ by $\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})$ yields the log likelihood for one particular input-output pair:
#
# $\mathcal{L}(\mathbf{x},\mathbf{y},\boldsymbol{\theta})=\ln {p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})}=-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})}\Vert_{2}^{2}-\dfrac{1}{2}\ln{(2\pi)^{M}\sigma^{2}}$
#
# This log likelihood measures how likely the input-output pair is and we can use it to train our neural network. For this we maximize the expected log likelihood over all input-output pairs under the assumption that the noise is idependent and identically distributed (i.i.d.) over all input-output pairs. This corresponds to finding the parameters $\boldsymbol{\theta}^{\star}$ of our neural network, which maximize the the expected probability for observing the corresponding input-output pairs. Mathematically the optimal parameters for our neural network are given by
#
# $\boldsymbol{\theta}^{\star}=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[\mathcal{L}(\mathbf{x},\mathbf{y},\boldsymbol{\theta})\right]=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[-\Vert\boldsymbol{\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})}\Vert_{2}^{2}\right]\approx\arg\min_{\boldsymbol{\theta}}\dfrac{1}{N_{D}}\sum_{i=1}^{N_{D}}\Vert\boldsymbol{\mathbf{y}_{i}-g_{\boldsymbol{\theta}}(\mathbf{x}_{i})}\Vert_{2}^{2}$,
#
# where all terms, which are independent of $\boldsymbol{\theta}$, are ignored and the expectation operator is approximated by the mean over all $N_{D}$ input-output pairs. In other words we are maximizing the log likelihood by minimizing the mean squared error loss over all input-output pairs in our dataset, hence this approach is called Maximum Likelihood (ML) estimation. For solving this optimization problem and obtaining the optimal network parameters, stochastic gradient descent (SGD) or one of it's many variants is typically used.
#
# It is worth noting, that choosing different distributions for the noise $\boldsymbol{\epsilon}$ leads to different log likelihoods and therefore different cost functions for training the neural network. Another commonly used distribution for modelling the noise in regression tasks is the laplace distribution. Deriving the log likelihood and the corresponding costfunction leads to the mean absolute error, which is given by the $l_{1}$-norm of the difference between observations predictions of the neural network. This cost function is considered more robust against outliers since these have less influence on the averall loss compared to the mean squared error.
#
# ###  Implementation
#
# In the following we consider a simple regression task, implement a neural network and train it based on the mathematical fomrulation above. For this we first need to create a set of input-output pairs, which then needs to be partitioned into a training, validation and test set. We also define some constants to be used for partitioning the data and the hyperparameters for our neural network.
#
# But before we can start, we need to import the necessary packages tensorflow, numpy and matplotlib.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
config = tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# Next we define our constants and set the random seeds of tensorflow and numpy in order to get reproducable results.

# %%
N_train_samples = 600
N_validation_samples = 100
N_test_samples = 100
N_samples = N_train_samples + N_validation_samples + N_test_samples
noise_sig = 0.1
N_epochs = 500
batch_size = 8
learning_rate = 0.01

tf.random.set_seed(0)
np.random.seed(0)

# %% [markdown]
# We create $600$ training samples, $100$ validation samples to optimize our hyperparameters and $100$ test samples, which are used to check if our model can generalize to unseen data. Furthermore we set the level of noise added to the observations. For training the model we plan to train it for $150$ epochs with a batch size of $8$ and a learning rate of $0.01$. Next we create the actual input-output pairs $\mathbf{x},\mathbf{y}$ for which we want to learn the regression model and plot them. In this simple example we choose scalar inputs as well as output but in general $\mathbf{x}$ and $\mathbf{y}$ can be vectors.

# %%
x = np.linspace(0.0, 3.0, N_samples, dtype=np.float32)
y = np.expand_dims(np.sin(1.0+x*x) + noise_sig*np.random.randn(N_samples).astype(np.float32), axis=-1)
y_true = np.sin(1.0+x*x)

plt.plot(x, y)
plt.plot(x, y_true)
plt.legend(["Observation", "Ground truth"])
plt.show()

# %% [markdown]
# With the input-output pairs created, your first task is now to partition the data in the training, validation and test sets. Keep in mind that we have created the data in a structured way, i.e. the input-output pairs are ordered. This means you need to shuffle the data before partitioning it.

# %%
""" Shuffle and partition the data set accordingly. you can use the predefined constants "N_train_samples", "N_validation_samples" and "N_test_samples". Use the variable names that are already in the below code 
to store the final shuffled and partitioned data. Hint: Shuffle the data and the labels in such a way that the pairing between an image and it's label is preserved."""
# Shuffle the data
y_reshaped = y.reshape(1,800)
y_full = np.vstack((y_reshaped[0], y_true))
full_array  = np.vstack((y_full, x)).T
# full_array.dtype
# full_array.shape
np.random.shuffle(full_array)
""" full array[0] is y  , full array[1] is y_true , full array[2] is all shuffled the same way  , without the transpose operator an array of tuples is returned"""
full_array = full_array.T
""" when other packages are allowed another solution would be
from sklearn.utils import shuffle
y_reshaped = y.reshape(1,800)
y_shuffeled, x_shuffled = shuffle(y_reshaped[0], x)"""
# Partition the data
x_train = full_array[2, 0:N_train_samples] 
y_train = full_array[0, 0:N_train_samples]
x_validation = full_array[2, N_train_samples:N_train_samples+ N_validation_samples]
y_validation = full_array[0, N_train_samples:N_train_samples+ N_validation_samples]
x_test = full_array[2, N_train_samples+ N_validation_samples:N_train_samples+ N_validation_samples +N_test_samples]
y_test = full_array[0, N_train_samples+ N_validation_samples:N_train_samples+ N_validation_samples +N_test_samples]
# len(x_train)
# len(x_validation)
# len(x_test)

# %% [markdown]
# In order to feed the data to our model, we will use the Dataset class provided by Tensorflow. This class is simple to use and provides all the functionality we need for shuffling, batching and feeding the data to our model. It is also tightly integrated into the Tensorflow framework, which makes it very performant. Performance is not an aspect we need to worry about in this exercise, but it is important in more demanding applications.
#
# In this exercise we instantiate a separate Dataset object for the training, validation and test data sets, where we shuffle and repeat just the training data set. Shuffling the validation and test data sets is not necessary, since we only evaluate the loss on those data sets and do not perform SGD on it. Please fill in the missing part of the code.

# %%
""" Create three tensorflow Dataset objects that can be used to feed the training test and validation data to a neural network. Hint: For the training data set use shuffling, batching with the size according to
the predefined constant "batch_size" and repeat the data set indefinetly. For the validation and test data sets no shuffling or batching is needed."""

train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_ds = train_ds.repeat(20)
train_ds = train_ds.shuffle(12000)
train_ds =train_ds.batch(batch_size=batch_size)
""" Implementation from the second part produces worse results than shuffling after repeating"""
#train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(N_train_samples).batch(batch_size).repeat()
validation_ds = tf.data.Dataset.from_tensor_slices([(x_validation, y_validation)])
test_ds = tf.data.Dataset.from_tensor_slices([(x_test, y_test)])

# %% [markdown]
# In this exercise we will create a a simple neural network with two hidden layers containing $10$ neurons. For creating a model and keeping track of its weights a class called MyModel is used. When initializing an instance of this class the necessary variables are created and stored in a list called "trainable_variables". This makes it easy to get all trainable variables of the model. We also override the \__call__ method of this class in order to implement the forward pass of the neural network. This method should accept the inputs to the neural network and should return the result of the forward pass as an output. Please fill in the missing part of the code and select suitable activation functions for the different layers.

# %%
""" Implement a neural network with two hidden dense layers containing 10 neurons each. As an activation function use the tangens hyperbolicus (tf.nn.tanh()). Since we are not using Keras, we need to create and 
manage all the variables that we need ourselves. The varaibles are created in the constructor of our model class. Since we want to be able to just call the class with some inputs in order to make a prediction, 
we implement a __call__ method which computes the forward pass and returns the output of the network."""
initializer = tf.initializers.glorot_uniform()
# use tanh to activate
#initializer(10)
class MyModel(object):
    def __init__(self):
        # Create model variables
        self.W0 = tf.Variable(name = 'weight_0',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([1, 10])))
        self.b0 = tf.Variable(name = 'bias_0',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([ 10])))
        self.W1 = tf.Variable(name = 'weight_1',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([10, 10])))
        self.b1 = tf.Variable(name = 'bias_1',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([ 10])))
        self.W2 = tf.Variable(name = 'weight_2',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([10, 1])))
        self.b2 = tf.Variable(name = 'bias_2',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([ 1])))
        self.trainable_variables = [self.W0, self.b0, self.W1, self.b1, self.W2, self.b2]

    def __call__(self, inputs):
        # Compute forward pass
        output = tf.reshape(inputs, [-1, 1])
        output = tf.nn.tanh( tf.add(tf.matmul(output, self.W0), self.b0))
        output =tf.nn.tanh( tf.add(tf.matmul(output, self.W1), self.b1))
        output = tf.add(tf.matmul(output, self.W2), self.b2)
        return output

# %% [markdown]
# Now after the model class is defined we can instantiate a MyModel object by running

# %%
mdl = MyModel()

# %% [markdown]
# We can now use the model to make predictions by calling it. In the following we predict on the inputs an plot the result.

# %%
""" We want to plot a prediction on the complete data set with a model before training. For this make a prediction on the variable "x". """

y_pred = mdl.__call__(x)
plt.plot(x, y)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# Since we have initialized the variables of the neural network randomly, it's prediction is also random. In order to fit the model we need to minimize the expected mean squared error over all input-ouput pairs in our training data set. For this we need to create a function, that performs a training step when provided with the model, an optimizer and a batch of input-ouput pairs.

# %%
""" For training we need to implement a function that executes one training step. Fill in the missing code pieces for this function."""

def train_step(model, optimizer, x, y):
    with tf.GradientTape() as tape:
        tape.watch(model.trainable_variables)
        y_pred = model.__call__(x)# Compute a prediction with "model" on the input "x"
        y = tf.reshape(y, [-1,1])
        loss_val = tf.compat.v1.losses.mean_squared_error(y, y_pred) # Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y"
    grads = tape.gradient(loss_val, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    return loss_val

# %% [markdown]
# This function uses the GradientTape to record the operations for which gradients have to be calculated. In our case this is the forward pass through our model and the computation of the loss function. After these operations are recoded we can get their gradients and apply these through the use of an optimizer. Finally we return the loss value in order to print it.
#
# With the training step function defined we now need to choose a suitable optimizer. Tensorflow offers a wide variety of optimizers but in this exercise we will use the RMSprop optimizer.

# %%
opt = tf.optimizers.RMSprop(learning_rate)

# %% [markdown]
# We now have everything we need to start training the model. For this we repeatedly sample a batch of input-output pairs from our training data set and use the train_step function to minimize the loss function over this batch. We repeat this until we have iterated over the complete training data set once. After this we compute the loss on the validation data set, print it and repeat with another epoch until we have reached $N\_epochs$ epochs.

# %%
""" We can now use the train_step function to perform the training. Fill in the missing code parts."""

epoch = 0
train_iters = 0
train_loss = 0.0
for x_t, y_t in train_ds:
    train_loss += train_step(mdl, opt, x_t,y_t) # Perform a training step with the model "mdl" and the optimizer "opt" on the inputs "x_t" and the corresponding targets "y_t"
    train_iters += 1
    if train_iters == N_train_samples/batch_size :  # An epoch is completed
        for x_v, y_v in validation_ds:
            y_pred = mdl.__call__(x_v)# Compute a prediction with "mdl" on the input "x_v"
            y_v =tf.reshape(y_v, [-1,1])
            validation_loss =tf.compat.v1.losses.mean_squared_error(y_v, y_pred) # Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_v"
        print('epoch' +str(epoch))
        print('train_loss' + str(train_loss))
        print('train_iters' + str(train_iters))
        print('val_loss' + str(validation_loss))
        #print('val_iters' + str(val_iters))    
        print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
        train_iters = 0
        train_loss = 0.0
        epoch += 1
    if (epoch == N_epochs):
        break
# Out:
# epoch0
# train_losstf.Tensor(19.85639, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.14753537, shape=(), dtype=float32)
# Epoch: 0 Train loss: 0.26475 Validation loss: 0.14754
# epoch1
# train_losstf.Tensor(11.446978, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.07083461, shape=(), dtype=float32)
# Epoch: 1 Train loss: 0.15263 Validation loss: 0.070835
# epoch2
# train_losstf.Tensor(8.373209, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.07214807, shape=(), dtype=float32)
# Epoch: 2 Train loss: 0.11164 Validation loss: 0.072148
# epoch3
# train_losstf.Tensor(7.177331, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.052069668, shape=(), dtype=float32)
# Epoch: 3 Train loss: 0.095698 Validation loss: 0.05207
# epoch4
# train_losstf.Tensor(6.481388, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.048526045, shape=(), dtype=float32)
# Epoch: 4 Train loss: 0.086419 Validation loss: 0.048526
# epoch5
# train_losstf.Tensor(8.39853, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.049535956, shape=(), dtype=float32)
# Epoch: 5 Train loss: 0.11198 Validation loss: 0.049536
# epoch6
# train_losstf.Tensor(6.989224, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.030340418, shape=(), dtype=float32)
# Epoch: 6 Train loss: 0.09319 Validation loss: 0.03034
# epoch7
# train_losstf.Tensor(7.2791653, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.030868204, shape=(), dtype=float32)
# Epoch: 7 Train loss: 0.097056 Validation loss: 0.030868
# epoch8
# train_losstf.Tensor(5.9125395, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.076744415, shape=(), dtype=float32)
# Epoch: 8 Train loss: 0.078834 Validation loss: 0.076744
# epoch9
# train_losstf.Tensor(5.8584585, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.03227505, shape=(), dtype=float32)
# Epoch: 9 Train loss: 0.078113 Validation loss: 0.032275
# epoch10
# train_losstf.Tensor(4.846879, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.030269718, shape=(), dtype=float32)
# Epoch: 10 Train loss: 0.064625 Validation loss: 0.03027
# epoch11
# train_losstf.Tensor(5.761345, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.02325383, shape=(), dtype=float32)
# Epoch: 11 Train loss: 0.076818 Validation loss: 0.023254
# epoch12
# train_losstf.Tensor(4.5734963, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.025190743, shape=(), dtype=float32)
# Epoch: 12 Train loss: 0.06098 Validation loss: 0.025191
# epoch13
# train_losstf.Tensor(3.7843204, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.019832784, shape=(), dtype=float32)
# Epoch: 13 Train loss: 0.050458 Validation loss: 0.019833
# epoch14
# train_losstf.Tensor(3.838884, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.024048377, shape=(), dtype=float32)
# Epoch: 14 Train loss: 0.051185 Validation loss: 0.024048
# epoch15
# train_losstf.Tensor(3.8727214, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.03493544, shape=(), dtype=float32)
# Epoch: 15 Train loss: 0.051636 Validation loss: 0.034935
# epoch16
# train_losstf.Tensor(3.3245115, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.020688483, shape=(), dtype=float32)
# Epoch: 16 Train loss: 0.044327 Validation loss: 0.020688
# epoch17
# train_losstf.Tensor(2.9687212, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.022568181, shape=(), dtype=float32)
# Epoch: 17 Train loss: 0.039583 Validation loss: 0.022568
# epoch18
# train_losstf.Tensor(2.818028, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.02273507, shape=(), dtype=float32)
# Epoch: 18 Train loss: 0.037574 Validation loss: 0.022735
# epoch19
# train_losstf.Tensor(2.8783073, shape=(), dtype=float32)
# train_iters75
# val_losstf.Tensor(0.02020273, shape=(), dtype=float32)
# Epoch: 19 Train loss: 0.038377 Validation loss: 0.020203

# %% [markdown]
# After completion of the training process we use the test data set to test the models generalization to unseen data.

# %%
for x_t, y_t in test_ds:
    y_pred = mdl.__call__(x_t)
    y_t =tf.reshape(y_t, [-1,1]) # Compute a prediction with "mdl" on the input "x_t"
    test_loss = tf.compat.v1.losses.mean_squared_error(y_t, y_pred)# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_t"
print("Test loss: {:.5}".format(test_loss))
# Out:
# Test loss: 0.024473

# %% [markdown]
# After we have verified that our model achieves a similar loss on the test as on the validation and training data set, we can conclude that our model is not overfitting or underfitting and generalizes to unseen data. We can now predict on the inputs again and plot the results.

# %%
""" Now we want to plot the prediction after training. Predict on the variable "x" again. """

y_pred =mdl.__call__(x) # Compute a prediction on the variable "x"
plt.plot(x, y)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# Now our model has learned to approximate the function mapping from the input to the output. The capability of neural networks to learn from input-ouput pairs alone and approximate an arbitrary function, see universal approximation theorem, can be very useful if the mapping between the input and output is too complex to be captured with model based approaches. But learning from input-ouput pairs alone implies that the model will only be able to make accurate predictions over input ranges it has seen during training. In order to demonstrate this we will predict on an interval that exeeds the $\left[0,3\right]$ interval the model was trained on, i.e. we will predict on the interval $\left[-2,5\right]$.

# %%
x_generalize = np.linspace(-2.0, 5.0, N_samples, dtype=np.float32)
y_generalize = np.sin(1.0+x_generalize*x_generalize) + noise_sig*np.random.randn(N_samples).astype(np.float32)
y_truey_generalize = np.sin(1.0+x_generalize*x_generalize)
y_pred = mdl(x_generalize)
plt.plot(x_generalize, y_generalize)
plt.plot(x_generalize, y_truey_generalize)
plt.plot(x_generalize, y_pred.numpy())
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# As expected, the model is able to make farely accurate predictions on the interval it was trained on but makes unreliable predictions outside this interval.
#
# ### Regularization
# In this section we will explore the concept of regularization. As there is no theorem that can be used to determine the required size and structure of a neural network given a certain task, one has to find a suitable neural architecture by trial and error. This can result in choosing a architecture with a capacity that is higher than required for solving the given task and hence overfitting might occur. A common way to prevent large neural networks networks from overfitting is to employ some sort of regularization, e.g. weight norm penalty, dropout, early stopping and data augmentation. In this section we will focus on weight norm penalty as a regularization and derive a probabilistic interpretation for some of those.
#
# We start by restating the conditional probability of the output $\mathbf{y}$ given the input $\mathbf{x}$ and the networks parameters $\boldsymbol{\theta}$
#
# $p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})=\dfrac{1}{\sqrt{(2\pi)^{M}\sigma^{2}}}\mathrm{e}^{-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})}\Vert_{2}^{2}}$,
#
# which we used to derive the log likelihood. If we have some prior knowledge about the parameters of the neural network, which is given by a pdf $p(\boldsymbol{\theta})$ over the weights, we can use Bayes theorem to derive a posterior distribution
#
# $p(\boldsymbol{\theta}\vert\mathbf{x},\mathbf{y})=\dfrac{p(\boldsymbol{\theta},\mathbf{y}\vert\mathbf{x})}{p(\mathbf{y})}=\dfrac{p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})p(\boldsymbol{\theta})}{p(\mathbf{y})}$
#
# where $p(\boldsymbol{\theta})$ is the  prior over the networks parameters. Similar to the derivation at the beginning of the exercise, we can use this posterior distribution to derive a cost function for training the neural network. In this case, however, we are not maximizing the log likelihood but the posterior distribution over the weights, hence this approach is called Maximum A Posteori (MAP) estimation of the parameters. Mathematically we can formulate this as
#
# $\boldsymbol{\theta}^{\star}=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[p(\boldsymbol{\theta}\vert\mathbf{x},\mathbf{y})\right]=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[\ln{p(\boldsymbol{\theta}\vert\mathbf{x},\mathbf{y})}\right]=\arg\max_{\boldsymbol{\theta}}\ln{p(\boldsymbol{\theta})}+\mathbb{E}\left[\ln{p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})}\right]$,
#
# where we used the fact that applying a strictly increasing function, e.g. $\ln{}$, does not change the position of the maximum of a cost function, ignored $p(\mathbf{y})$, since it is independent of the network parameters and dropped the expectation operator for $\ln{p(\boldsymbol{\theta})}$, since it is not depending on the random variable $\mathbf{x}$. Comparing the MAP estimate of the parameters with the ML estimate we derived above, shows that the only difference is the addition of $\ln{p(\boldsymbol{\theta})}$. This term is the regularization, i.e. the weight norm penalty. Depending on the distribution over $\boldsymbol{\theta}$ it can have different forms. If we choose a standard normal distribution, i.e. $\boldsymbol{\theta\sim\mathcal{N}(\mathbf{0},\mathbf{I})}$,  we get
#
# $\boldsymbol{\theta}^{\star}=\arg\min_{\boldsymbol{\theta}}\lambda\Vert\boldsymbol{\theta}\Vert_{2}^{2}+\dfrac{1}{N_{D}}\sum_{i=1}^{N_{D}}\Vert\boldsymbol{\mathbf{y}_{i}-g_{\boldsymbol{\theta}}(\mathbf{x}_{i})}\Vert_{2}^{2}$,
#
# where we have made the same simplifications as for the ML estimation and also introduced the parameter $\lambda=\sigma^{2}$, which is used to control the strength of the regularization. This form of regularization is commonly known as $l_{2}$-norm or weight decay regularization. Choosing a prior where the weights follow an i.i.d laplacian distribution, i.e. $p(\boldsymbol{\theta})=\prod_{j}\dfrac{1}{2}\mathrm{e}^{\vert\theta_{j}\vert}$, leads to
#
# $\boldsymbol{\theta}^{\star}=\arg\min_{\boldsymbol{\theta}}\lambda\Vert\boldsymbol{\theta}\Vert_{1}+\dfrac{1}{N_{D}}\sum_{i=1}^{N_{D}}\Vert\boldsymbol{\mathbf{y}_{i}-g_{\boldsymbol{\theta}}(\mathbf{x}_{i})}\Vert_{2}^{2}$,
#
# where the strength of the regularization is again controlled by $\lambda=\sigma^{2}$. This type of regularization is known as  $l_{1}$-norm and it has the property to induce sparsity in the parameters of the network.
#
# With this theoretical background on regularization we can now implement it and observe it's effects on the regression problem covered in this exercise. For this we will define a model with a high capacity and train it for a extended time to provoke overfitting. For this, we will increase the number of hidden neurons in both hidden layers to $100$ and $50$.

# %%
""" Implement a bigger model with again two hidden layers contatining 100 and 50 neurons. As an activation use the tangens hyperbolicus function where it is appropiate. """

class MyBigModel(object):
    def __init__(self):
        # Create model variables
        self.W0 = tf.Variable(name = 'weight_0',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([1, 100])))
        self.b0 = tf.Variable(name = 'bias_0',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([ 100])))
        self.W1 = tf.Variable(name = 'weight_1',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([100, 50])))
        self.b1 = tf.Variable(name = 'bias_1',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([ 50])))
        self.W2 = tf.Variable(name = 'weight_2',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([50, 1])))
        self.b2 = tf.Variable(name = 'bias_2',trainable = True, dtype = tf.float32, initial_value = tf.Variable(tf.random.truncated_normal([ 1])))
        self.trainable_variables = [self.W0, self.b0, self.W1, self.b1, self.W2, self.b2] 
        self.trainable_variables = [self.W0, self.b0, self.W1, self.b1, self.W2, self.b2]

    def __call__(self, inputs):
        # Compute forward pass
        output = tf.reshape(inputs, [-1, 1])
        output = tf.nn.tanh( tf.add(tf.matmul(output, self.W0), self.b0))
        output =tf.nn.tanh( tf.add(tf.matmul(output, self.W1), self.b1))
        output = tf.nn.tanh(tf.add(tf.matmul(output, self.W2), self.b2)) 
        return output

# %% [markdown]
# After creating one instance of this class we can again train it on our data set. We will also create a new optimizer for training this bigger model, since some optimizers adapt the learning rates for individual parameters during a training process and we do not want to train our bigger model with learning rates adopted from an earlier training run.

# %%
big_mdl = MyBigModel()
big_opt = tf.optimizers.SGD(learning_rate)

# %% [markdown]
# Now we are ready to train this bigger model using the same training step and training loop. In order to provoke overfitting we also reduce the number of samples in the training data set a lot, increase the batch size and train for a more epochs.

# %%
""" Implement the training for the bigger model similar to the training of the small model before. """

N_train_samples_overfit = 30
N_epochs = 1000
batch_size = 30

sel_idx = np.arange(0, N_train_samples)
sel_idx = np.random.choice(sel_idx, N_train_samples_overfit)
x_train_overfit = x_train[sel_idx]
y_train_overfit = y_train[sel_idx]

train_overfit_ds = tf.data.Dataset.from_tensor_slices((x_train_overfit, y_train_overfit)).shuffle(N_train_samples_overfit).batch(batch_size).repeat()

epoch = 0
train_iters = 0
train_loss = 0.0
for x_t, y_t in train_overfit_ds:
    train_loss += train_step(big_mdl, big_opt, x_t, y_t) # Perform a training step with the model "big_mdl" and the optimizer "big_opt" on the inputs "x_t" and the corresponding targets "y_t"
    train_iters += 1
    if train_iters == N_train_samples/batch_size :# An epoch is completed
        for x_v, y_v in validation_ds:
            y_pred = big_mdl.__call__ (x_v)
            y_v = tf.reshape(y_v, [-1,1])# Compute a prediction with "big_mdl" on the input "x_v"
            validation_loss = tf.compat.v1.losses.mean_squared_error(y_v, y_pred) # Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_v"
        print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
        train_iters = 0
        train_loss = 0.0
        epoch += 1
    if (epoch == N_epochs):
        break
# Out:
# Epoch: 0 Train loss: 1.5841 Validation loss: 1.3829
# Epoch: 1 Train loss: 0.90439 Validation loss: 0.9466
# Epoch: 2 Train loss: 0.53741 Validation loss: 0.91873
# Epoch: 3 Train loss: 0.53525 Validation loss: 0.90709
# Epoch: 4 Train loss: 0.53426 Validation loss: 0.8985
# Epoch: 5 Train loss: 0.53356 Validation loss: 0.89051
# Epoch: 6 Train loss: 0.53297 Validation loss: 0.88179
# Epoch: 7 Train loss: 0.53237 Validation loss: 0.87067
# Epoch: 8 Train loss: 0.53161 Validation loss: 0.85312
# Epoch: 9 Train loss: 0.52977 Validation loss: 0.80903
# Epoch: 10 Train loss: 0.46884 Validation loss: 0.53859
# Epoch: 11 Train loss: 0.38902 Validation loss: 0.45762
# Epoch: 12 Train loss: 0.31386 Validation loss: 0.19633
# Epoch: 13 Train loss: 0.27612 Validation loss: 0.16886
# Epoch: 14 Train loss: 0.27546 Validation loss: 0.1569
# Epoch: 15 Train loss: 0.27512 Validation loss: 0.14918
# Epoch: 16 Train loss: 0.27485 Validation loss: 0.1432
# Epoch: 17 Train loss: 0.2746 Validation loss: 0.13797
# Epoch: 18 Train loss: 0.27437 Validation loss: 0.13294
# Epoch: 19 Train loss: 0.27413 Validation loss: 0.1277
# Epoch: 20 Train loss: 0.27387 Validation loss: 0.12184
# Epoch: 21 Train loss: 0.27355 Validation loss: 0.11484
# Epoch: 22 Train loss: 0.27306 Validation loss: 0.10608
# Epoch: 23 Train loss: 0.2715 Validation loss: 0.095408
# Epoch: 24 Train loss: 0.14457 Validation loss: 0.038601
# Epoch: 25 Train loss: 0.017225 Validation loss: 0.037772
# Epoch: 26 Train loss: 0.016587 Validation loss: 0.037219
# Epoch: 27 Train loss: 0.016301 Validation loss: 0.036763
# Epoch: 28 Train loss: 0.016085 Validation loss: 0.03636
# Epoch: 29 Train loss: 0.015895 Validation loss: 0.035987
# Epoch: 30 Train loss: 0.015719 Validation loss: 0.035632
# Epoch: 31 Train loss: 0.015553 Validation loss: 0.035292
# Epoch: 32 Train loss: 0.015394 Validation loss: 0.034962
# Epoch: 33 Train loss: 0.015243 Validation loss: 0.034643
# Epoch: 34 Train loss: 0.015098 Validation loss: 0.034335
# Epoch: 35 Train loss: 0.01496 Validation loss: 0.034035
# Epoch: 36 Train loss: 0.014827 Validation loss: 0.033746
# Epoch: 37 Train loss: 0.0147 Validation loss: 0.033465
# Epoch: 38 Train loss: 0.014578 Validation loss: 0.033194
# Epoch: 39 Train loss: 0.014461 Validation loss: 0.03293
# Epoch: 40 Train loss: 0.014349 Validation loss: 0.032674
# Epoch: 41 Train loss: 0.01424 Validation loss: 0.032426
# Epoch: 42 Train loss: 0.014135 Validation loss: 0.032185
# Epoch: 43 Train loss: 0.014034 Validation loss: 0.03195
# Epoch: 44 Train loss: 0.013936 Validation loss: 0.031721
# Epoch: 45 Train loss: 0.013841 Validation loss: 0.031497
# Epoch: 46 Train loss: 0.013749 Validation loss: 0.031279
# Epoch: 47 Train loss: 0.013659 Validation loss: 0.031066
# Epoch: 48 Train loss: 0.013572 Validation loss: 0.030858
# Epoch: 49 Train loss: 0.013487 Validation loss: 0.030654
# Epoch: 50 Train loss: 0.013404 Validation loss: 0.030454
# Epoch: 51 Train loss: 0.013324 Validation loss: 0.030257
# Epoch: 52 Train loss: 0.013245 Validation loss: 0.030065
# Epoch: 53 Train loss: 0.013167 Validation loss: 0.029876
# Epoch: 54 Train loss: 0.013092 Validation loss: 0.02969
# Epoch: 55 Train loss: 0.013018 Validation loss: 0.029507
# Epoch: 56 Train loss: 0.012946 Validation loss: 0.029327
# Epoch: 57 Train loss: 0.012875 Validation loss: 0.02915
# Epoch: 58 Train loss: 0.012805 Validation loss: 0.028975
# Epoch: 59 Train loss: 0.012737 Validation loss: 0.028803
# Epoch: 60 Train loss: 0.01267 Validation loss: 0.028634
# Epoch: 61 Train loss: 0.012604 Validation loss: 0.028467
# Epoch: 62 Train loss: 0.012539 Validation loss: 0.028303
# Epoch: 63 Train loss: 0.012476 Validation loss: 0.02814
# Epoch: 64 Train loss: 0.012413 Validation loss: 0.027981
# Epoch: 65 Train loss: 0.012351 Validation loss: 0.027823
# Epoch: 66 Train loss: 0.012291 Validation loss: 0.027667
# Epoch: 67 Train loss: 0.012231 Validation loss: 0.027514
# Epoch: 68 Train loss: 0.012173 Validation loss: 0.027363
# Epoch: 69 Train loss: 0.012115 Validation loss: 0.027214
# Epoch: 70 Train loss: 0.012057 Validation loss: 0.027068
# Epoch: 71 Train loss: 0.012001 Validation loss: 0.026923
# Epoch: 72 Train loss: 0.011946 Validation loss: 0.026781
# Epoch: 73 Train loss: 0.011891 Validation loss: 0.026641
# Epoch: 74 Train loss: 0.011837 Validation loss: 0.026503
# Epoch: 75 Train loss: 0.011783 Validation loss: 0.026368
# Epoch: 76 Train loss: 0.01173 Validation loss: 0.026235
# Epoch: 77 Train loss: 0.011678 Validation loss: 0.026105
# Epoch: 78 Train loss: 0.011626 Validation loss: 0.025977
# Epoch: 79 Train loss: 0.011575 Validation loss: 0.025851
# Epoch: 80 Train loss: 0.011524 Validation loss: 0.025729
# Epoch: 81 Train loss: 0.011473 Validation loss: 0.025609
# Epoch: 82 Train loss: 0.011424 Validation loss: 0.025492
# Epoch: 83 Train loss: 0.011374 Validation loss: 0.025378
# Epoch: 84 Train loss: 0.011325 Validation loss: 0.025267
# Epoch: 85 Train loss: 0.011277 Validation loss: 0.02516
# Epoch: 86 Train loss: 0.011228 Validation loss: 0.025055
# Epoch: 87 Train loss: 0.011181 Validation loss: 0.024954
# Epoch: 88 Train loss: 0.011133 Validation loss: 0.024857
# Epoch: 89 Train loss: 0.011086 Validation loss: 0.024763
# Epoch: 90 Train loss: 0.01104 Validation loss: 0.024673
# Epoch: 91 Train loss: 0.010994 Validation loss: 0.024586
# Epoch: 92 Train loss: 0.010948 Validation loss: 0.024504
# Epoch: 93 Train loss: 0.010903 Validation loss: 0.024425
# Epoch: 94 Train loss: 0.010858 Validation loss: 0.024351
# Epoch: 95 Train loss: 0.010815 Validation loss: 0.02428
# Epoch: 96 Train loss: 0.010771 Validation loss: 0.024214
# Epoch: 97 Train loss: 0.010729 Validation loss: 0.024151
# Epoch: 98 Train loss: 0.010687 Validation loss: 0.024093
# Epoch: 99 Train loss: 0.010647 Validation loss: 0.024038
# Epoch: 100 Train loss: 0.010607 Validation loss: 0.023987
# Epoch: 101 Train loss: 0.010568 Validation loss: 0.02394
# Epoch: 102 Train loss: 0.010531 Validation loss: 0.023896
# Epoch: 103 Train loss: 0.010494 Validation loss: 0.023855
# Epoch: 104 Train loss: 0.010459 Validation loss: 0.023817
# Epoch: 105 Train loss: 0.010425 Validation loss: 0.023783
# Epoch: 106 Train loss: 0.010392 Validation loss: 0.023751
# Epoch: 107 Train loss: 0.010361 Validation loss: 0.023721
# Epoch: 108 Train loss: 0.010331 Validation loss: 0.023694
# Epoch: 109 Train loss: 0.010302 Validation loss: 0.023668
# Epoch: 110 Train loss: 0.010274 Validation loss: 0.023645
# Epoch: 111 Train loss: 0.010247 Validation loss: 0.023623
# Epoch: 112 Train loss: 0.010222 Validation loss: 0.023603
# Epoch: 113 Train loss: 0.010197 Validation loss: 0.023584
# Epoch: 114 Train loss: 0.010174 Validation loss: 0.023567
# Epoch: 115 Train loss: 0.010151 Validation loss: 0.02355
# Epoch: 116 Train loss: 0.01013 Validation loss: 0.023534
# Epoch: 117 Train loss: 0.010109 Validation loss: 0.023519
# Epoch: 118 Train loss: 0.010089 Validation loss: 0.023505
# Epoch: 119 Train loss: 0.01007 Validation loss: 0.023492
# Epoch: 120 Train loss: 0.010051 Validation loss: 0.023479
# Epoch: 121 Train loss: 0.010033 Validation loss: 0.023466
# Epoch: 122 Train loss: 0.010016 Validation loss: 0.023454
# Epoch: 123 Train loss: 0.0099991 Validation loss: 0.023443
# Epoch: 124 Train loss: 0.0099828 Validation loss: 0.023431
# Epoch: 125 Train loss: 0.0099668 Validation loss: 0.02342
# Epoch: 126 Train loss: 0.0099513 Validation loss: 0.02341
# Epoch: 127 Train loss: 0.0099362 Validation loss: 0.0234
# Epoch: 128 Train loss: 0.0099213 Validation loss: 0.02339
# Epoch: 129 Train loss: 0.0099069 Validation loss: 0.02338
# Epoch: 130 Train loss: 0.0098927 Validation loss: 0.02337
# Epoch: 131 Train loss: 0.0098787 Validation loss: 0.023361
# Epoch: 132 Train loss: 0.0098651 Validation loss: 0.023352
# Epoch: 133 Train loss: 0.0098517 Validation loss: 0.023343
# Epoch: 134 Train loss: 0.0098385 Validation loss: 0.023335
# Epoch: 135 Train loss: 0.0098255 Validation loss: 0.023326
# Epoch: 136 Train loss: 0.0098127 Validation loss: 0.023318
# Epoch: 137 Train loss: 0.0098001 Validation loss: 0.02331
# Epoch: 138 Train loss: 0.0097876 Validation loss: 0.023302
# Epoch: 139 Train loss: 0.0097754 Validation loss: 0.023294
# Epoch: 140 Train loss: 0.0097633 Validation loss: 0.023286
# Epoch: 141 Train loss: 0.0097513 Validation loss: 0.023279
# Epoch: 142 Train loss: 0.0097395 Validation loss: 0.023272
# Epoch: 143 Train loss: 0.0097278 Validation loss: 0.023264
# Epoch: 144 Train loss: 0.0097162 Validation loss: 0.023257
# Epoch: 145 Train loss: 0.0097048 Validation loss: 0.023251
# Epoch: 146 Train loss: 0.0096935 Validation loss: 0.023244
# Epoch: 147 Train loss: 0.0096823 Validation loss: 0.023237
# Epoch: 148 Train loss: 0.0096712 Validation loss: 0.02323
# Epoch: 149 Train loss: 0.0096602 Validation loss: 0.023224
# Epoch: 150 Train loss: 0.0096493 Validation loss: 0.023217
# Epoch: 151 Train loss: 0.0096385 Validation loss: 0.023211
# Epoch: 152 Train loss: 0.0096279 Validation loss: 0.023205
# Epoch: 153 Train loss: 0.0096173 Validation loss: 0.023199
# Epoch: 154 Train loss: 0.0096068 Validation loss: 0.023193
# Epoch: 155 Train loss: 0.0095964 Validation loss: 0.023187
# Epoch: 156 Train loss: 0.0095861 Validation loss: 0.023181
# Epoch: 157 Train loss: 0.0095758 Validation loss: 0.023176
# Epoch: 158 Train loss: 0.0095657 Validation loss: 0.02317
# Epoch: 159 Train loss: 0.0095556 Validation loss: 0.023164
# Epoch: 160 Train loss: 0.0095457 Validation loss: 0.023159
# Epoch: 161 Train loss: 0.0095358 Validation loss: 0.023153
# Epoch: 162 Train loss: 0.0095259 Validation loss: 0.023148
# Epoch: 163 Train loss: 0.0095162 Validation loss: 0.023143
# Epoch: 164 Train loss: 0.0095065 Validation loss: 0.023137
# Epoch: 165 Train loss: 0.0094969 Validation loss: 0.023132
# Epoch: 166 Train loss: 0.0094873 Validation loss: 0.023127
# Epoch: 167 Train loss: 0.0094779 Validation loss: 0.023122
# Epoch: 168 Train loss: 0.0094685 Validation loss: 0.023117
# Epoch: 169 Train loss: 0.0094591 Validation loss: 0.023111
# Epoch: 170 Train loss: 0.0094499 Validation loss: 0.023106
# Epoch: 171 Train loss: 0.0094406 Validation loss: 0.023101
# Epoch: 172 Train loss: 0.0094315 Validation loss: 0.023096
# Epoch: 173 Train loss: 0.0094224 Validation loss: 0.023091
# Epoch: 174 Train loss: 0.0094134 Validation loss: 0.023086
# Epoch: 175 Train loss: 0.0094044 Validation loss: 0.023082
# Epoch: 176 Train loss: 0.0093955 Validation loss: 0.023077
# Epoch: 177 Train loss: 0.0093866 Validation loss: 0.023072
# Epoch: 178 Train loss: 0.0093778 Validation loss: 0.023067
# Epoch: 179 Train loss: 0.0093691 Validation loss: 0.023062
# Epoch: 180 Train loss: 0.0093604 Validation loss: 0.023057
# Epoch: 181 Train loss: 0.0093518 Validation loss: 0.023052
# Epoch: 182 Train loss: 0.0093432 Validation loss: 0.023047
# Epoch: 183 Train loss: 0.0093347 Validation loss: 0.023043
# Epoch: 184 Train loss: 0.0093262 Validation loss: 0.023038
# Epoch: 185 Train loss: 0.0093177 Validation loss: 0.023033
# Epoch: 186 Train loss: 0.0093094 Validation loss: 0.023028
# Epoch: 187 Train loss: 0.009301 Validation loss: 0.023023
# Epoch: 188 Train loss: 0.0092928 Validation loss: 0.023019
# Epoch: 189 Train loss: 0.0092845 Validation loss: 0.023014
# Epoch: 190 Train loss: 0.0092763 Validation loss: 0.023009
# Epoch: 191 Train loss: 0.0092682 Validation loss: 0.023004
# Epoch: 192 Train loss: 0.0092601 Validation loss: 0.022999
# Epoch: 193 Train loss: 0.0092521 Validation loss: 0.022994
# Epoch: 194 Train loss: 0.0092441 Validation loss: 0.02299
# Epoch: 195 Train loss: 0.0092361 Validation loss: 0.022985
# Epoch: 196 Train loss: 0.0092282 Validation loss: 0.02298
# Epoch: 197 Train loss: 0.0092203 Validation loss: 0.022975
# Epoch: 198 Train loss: 0.0092125 Validation loss: 0.02297
# Epoch: 199 Train loss: 0.0092047 Validation loss: 0.022965
# Epoch: 200 Train loss: 0.009197 Validation loss: 0.022961
# Epoch: 201 Train loss: 0.0091893 Validation loss: 0.022956
# Epoch: 202 Train loss: 0.0091816 Validation loss: 0.022951
# Epoch: 203 Train loss: 0.009174 Validation loss: 0.022946
# Epoch: 204 Train loss: 0.0091664 Validation loss: 0.022941
# Epoch: 205 Train loss: 0.0091589 Validation loss: 0.022936
# Epoch: 206 Train loss: 0.0091514 Validation loss: 0.022931
# Epoch: 207 Train loss: 0.0091439 Validation loss: 0.022926
# Epoch: 208 Train loss: 0.0091365 Validation loss: 0.022921
# Epoch: 209 Train loss: 0.0091291 Validation loss: 0.022916
# Epoch: 210 Train loss: 0.0091218 Validation loss: 0.022911
# Epoch: 211 Train loss: 0.0091145 Validation loss: 0.022906
# Epoch: 212 Train loss: 0.0091072 Validation loss: 0.022902
# Epoch: 213 Train loss: 0.0091 Validation loss: 0.022897
# Epoch: 214 Train loss: 0.0090928 Validation loss: 0.022892
# Epoch: 215 Train loss: 0.0090856 Validation loss: 0.022887
# Epoch: 216 Train loss: 0.0090785 Validation loss: 0.022882
# Epoch: 217 Train loss: 0.0090714 Validation loss: 0.022877
# Epoch: 218 Train loss: 0.0090643 Validation loss: 0.022872
# Epoch: 219 Train loss: 0.0090573 Validation loss: 0.022867
# Epoch: 220 Train loss: 0.0090503 Validation loss: 0.022862
# Epoch: 221 Train loss: 0.0090433 Validation loss: 0.022857
# Epoch: 222 Train loss: 0.0090364 Validation loss: 0.022852
# Epoch: 223 Train loss: 0.0090295 Validation loss: 0.022847
# Epoch: 224 Train loss: 0.0090227 Validation loss: 0.022842
# Epoch: 225 Train loss: 0.0090158 Validation loss: 0.022837
# Epoch: 226 Train loss: 0.009009 Validation loss: 0.022832
# Epoch: 227 Train loss: 0.0090023 Validation loss: 0.022827
# Epoch: 228 Train loss: 0.0089955 Validation loss: 0.022822
# Epoch: 229 Train loss: 0.0089889 Validation loss: 0.022817
# Epoch: 230 Train loss: 0.0089822 Validation loss: 0.022812
# Epoch: 231 Train loss: 0.0089756 Validation loss: 0.022807
# Epoch: 232 Train loss: 0.008969 Validation loss: 0.022802
# Epoch: 233 Train loss: 0.0089624 Validation loss: 0.022797
# Epoch: 234 Train loss: 0.0089558 Validation loss: 0.022792
# Epoch: 235 Train loss: 0.0089493 Validation loss: 0.022787
# Epoch: 236 Train loss: 0.0089428 Validation loss: 0.022782
# Epoch: 237 Train loss: 0.0089364 Validation loss: 0.022777
# Epoch: 238 Train loss: 0.00893 Validation loss: 0.022772
# Epoch: 239 Train loss: 0.0089236 Validation loss: 0.022767
# Epoch: 240 Train loss: 0.0089172 Validation loss: 0.022762
# Epoch: 241 Train loss: 0.0089108 Validation loss: 0.022757
# Epoch: 242 Train loss: 0.0089045 Validation loss: 0.022752
# Epoch: 243 Train loss: 0.0088983 Validation loss: 0.022747
# Epoch: 244 Train loss: 0.008892 Validation loss: 0.022742
# Epoch: 245 Train loss: 0.0088858 Validation loss: 0.022737
# Epoch: 246 Train loss: 0.0088796 Validation loss: 0.022732
# Epoch: 247 Train loss: 0.0088734 Validation loss: 0.022727
# Epoch: 248 Train loss: 0.0088673 Validation loss: 0.022722
# Epoch: 249 Train loss: 0.0088612 Validation loss: 0.022717
# Epoch: 250 Train loss: 0.0088551 Validation loss: 0.022712
# Epoch: 251 Train loss: 0.008849 Validation loss: 0.022707
# Epoch: 252 Train loss: 0.0088429 Validation loss: 0.022702
# Epoch: 253 Train loss: 0.0088369 Validation loss: 0.022697
# Epoch: 254 Train loss: 0.0088309 Validation loss: 0.022692
# Epoch: 255 Train loss: 0.008825 Validation loss: 0.022687
# Epoch: 256 Train loss: 0.008819 Validation loss: 0.022682
# Epoch: 257 Train loss: 0.0088131 Validation loss: 0.022677
# Epoch: 258 Train loss: 0.0088072 Validation loss: 0.022673
# Epoch: 259 Train loss: 0.0088013 Validation loss: 0.022668
# Epoch: 260 Train loss: 0.0087955 Validation loss: 0.022663
# Epoch: 261 Train loss: 0.0087897 Validation loss: 0.022658
# Epoch: 262 Train loss: 0.0087839 Validation loss: 0.022653
# Epoch: 263 Train loss: 0.0087781 Validation loss: 0.022648
# Epoch: 264 Train loss: 0.0087723 Validation loss: 0.022643
# Epoch: 265 Train loss: 0.0087666 Validation loss: 0.022638
# Epoch: 266 Train loss: 0.0087609 Validation loss: 0.022634
# Epoch: 267 Train loss: 0.0087552 Validation loss: 0.022629
# Epoch: 268 Train loss: 0.0087496 Validation loss: 0.022624
# Epoch: 269 Train loss: 0.0087439 Validation loss: 0.022619
# Epoch: 270 Train loss: 0.0087383 Validation loss: 0.022614
# Epoch: 271 Train loss: 0.0087327 Validation loss: 0.02261
# Epoch: 272 Train loss: 0.0087272 Validation loss: 0.022605
# Epoch: 273 Train loss: 0.0087216 Validation loss: 0.0226
# Epoch: 274 Train loss: 0.0087161 Validation loss: 0.022595
# Epoch: 275 Train loss: 0.0087106 Validation loss: 0.02259
# Epoch: 276 Train loss: 0.0087051 Validation loss: 0.022586
# Epoch: 277 Train loss: 0.0086996 Validation loss: 0.022581
# Epoch: 278 Train loss: 0.0086942 Validation loss: 0.022576
# Epoch: 279 Train loss: 0.0086888 Validation loss: 0.022572
# Epoch: 280 Train loss: 0.0086834 Validation loss: 0.022567
# Epoch: 281 Train loss: 0.008678 Validation loss: 0.022562
# Epoch: 282 Train loss: 0.0086726 Validation loss: 0.022558
# Epoch: 283 Train loss: 0.0086673 Validation loss: 0.022553
# Epoch: 284 Train loss: 0.008662 Validation loss: 0.022548
# Epoch: 285 Train loss: 0.0086567 Validation loss: 0.022544
# Epoch: 286 Train loss: 0.0086514 Validation loss: 0.022539
# Epoch: 287 Train loss: 0.0086462 Validation loss: 0.022534
# Epoch: 288 Train loss: 0.0086409 Validation loss: 0.02253
# Epoch: 289 Train loss: 0.0086357 Validation loss: 0.022525
# Epoch: 290 Train loss: 0.0086305 Validation loss: 0.022521
# Epoch: 291 Train loss: 0.0086253 Validation loss: 0.022516
# Epoch: 292 Train loss: 0.0086202 Validation loss: 0.022511
# Epoch: 293 Train loss: 0.008615 Validation loss: 0.022507
# Epoch: 294 Train loss: 0.0086099 Validation loss: 0.022502
# Epoch: 295 Train loss: 0.0086048 Validation loss: 0.022498
# Epoch: 296 Train loss: 0.0085997 Validation loss: 0.022493
# Epoch: 297 Train loss: 0.0085947 Validation loss: 0.022489
# Epoch: 298 Train loss: 0.0085896 Validation loss: 0.022484
# Epoch: 299 Train loss: 0.0085846 Validation loss: 0.02248
# Epoch: 300 Train loss: 0.0085796 Validation loss: 0.022475
# Epoch: 301 Train loss: 0.0085746 Validation loss: 0.022471
# Epoch: 302 Train loss: 0.0085696 Validation loss: 0.022467
# Epoch: 303 Train loss: 0.0085646 Validation loss: 0.022462
# Epoch: 304 Train loss: 0.0085597 Validation loss: 0.022458
# Epoch: 305 Train loss: 0.0085548 Validation loss: 0.022453
# Epoch: 306 Train loss: 0.0085499 Validation loss: 0.022449
# Epoch: 307 Train loss: 0.008545 Validation loss: 0.022445
# Epoch: 308 Train loss: 0.0085401 Validation loss: 0.02244
# Epoch: 309 Train loss: 0.0085353 Validation loss: 0.022436
# Epoch: 310 Train loss: 0.0085304 Validation loss: 0.022431
# Epoch: 311 Train loss: 0.0085256 Validation loss: 0.022427
# Epoch: 312 Train loss: 0.0085208 Validation loss: 0.022423
# Epoch: 313 Train loss: 0.008516 Validation loss: 0.022419
# Epoch: 314 Train loss: 0.0085112 Validation loss: 0.022414
# Epoch: 315 Train loss: 0.0085065 Validation loss: 0.02241
# Epoch: 316 Train loss: 0.0085017 Validation loss: 0.022406
# Epoch: 317 Train loss: 0.008497 Validation loss: 0.022401
# Epoch: 318 Train loss: 0.0084923 Validation loss: 0.022397
# Epoch: 319 Train loss: 0.0084876 Validation loss: 0.022393
# Epoch: 320 Train loss: 0.0084829 Validation loss: 0.022389
# Epoch: 321 Train loss: 0.0084783 Validation loss: 0.022385
# Epoch: 322 Train loss: 0.0084736 Validation loss: 0.02238
# Epoch: 323 Train loss: 0.008469 Validation loss: 0.022376
# Epoch: 324 Train loss: 0.0084644 Validation loss: 0.022372
# Epoch: 325 Train loss: 0.0084598 Validation loss: 0.022368
# Epoch: 326 Train loss: 0.0084552 Validation loss: 0.022364
# Epoch: 327 Train loss: 0.0084506 Validation loss: 0.02236
# Epoch: 328 Train loss: 0.0084461 Validation loss: 0.022355
# Epoch: 329 Train loss: 0.0084415 Validation loss: 0.022351
# Epoch: 330 Train loss: 0.008437 Validation loss: 0.022347
# Epoch: 331 Train loss: 0.0084325 Validation loss: 0.022343
# Epoch: 332 Train loss: 0.008428 Validation loss: 0.022339
# Epoch: 333 Train loss: 0.0084235 Validation loss: 0.022335
# Epoch: 334 Train loss: 0.008419 Validation loss: 0.022331
# Epoch: 335 Train loss: 0.0084146 Validation loss: 0.022327
# Epoch: 336 Train loss: 0.0084101 Validation loss: 0.022323
# Epoch: 337 Train loss: 0.0084057 Validation loss: 0.022319
# Epoch: 338 Train loss: 0.0084013 Validation loss: 0.022315
# Epoch: 339 Train loss: 0.0083969 Validation loss: 0.022311
# Epoch: 340 Train loss: 0.0083925 Validation loss: 0.022307
# Epoch: 341 Train loss: 0.0083881 Validation loss: 0.022303
# Epoch: 342 Train loss: 0.0083837 Validation loss: 0.022299
# Epoch: 343 Train loss: 0.0083794 Validation loss: 0.022295
# Epoch: 344 Train loss: 0.0083751 Validation loss: 0.022291
# Epoch: 345 Train loss: 0.0083707 Validation loss: 0.022287
# Epoch: 346 Train loss: 0.0083664 Validation loss: 0.022283
# Epoch: 347 Train loss: 0.0083621 Validation loss: 0.02228
# Epoch: 348 Train loss: 0.0083579 Validation loss: 0.022276
# Epoch: 349 Train loss: 0.0083536 Validation loss: 0.022272
# Epoch: 350 Train loss: 0.0083493 Validation loss: 0.022268
# Epoch: 351 Train loss: 0.0083451 Validation loss: 0.022264
# Epoch: 352 Train loss: 0.0083409 Validation loss: 0.02226
# Epoch: 353 Train loss: 0.0083367 Validation loss: 0.022256
# Epoch: 354 Train loss: 0.0083325 Validation loss: 0.022253
# Epoch: 355 Train loss: 0.0083283 Validation loss: 0.022249
# Epoch: 356 Train loss: 0.0083241 Validation loss: 0.022245
# Epoch: 357 Train loss: 0.0083199 Validation loss: 0.022241
# Epoch: 358 Train loss: 0.0083158 Validation loss: 0.022238
# Epoch: 359 Train loss: 0.0083116 Validation loss: 0.022234
# Epoch: 360 Train loss: 0.0083075 Validation loss: 0.02223
# Epoch: 361 Train loss: 0.0083034 Validation loss: 0.022226
# Epoch: 362 Train loss: 0.0082992 Validation loss: 0.022223
# Epoch: 363 Train loss: 0.0082952 Validation loss: 0.022219
# Epoch: 364 Train loss: 0.0082911 Validation loss: 0.022215
# Epoch: 365 Train loss: 0.008287 Validation loss: 0.022212
# Epoch: 366 Train loss: 0.0082829 Validation loss: 0.022208
# Epoch: 367 Train loss: 0.0082789 Validation loss: 0.022204
# Epoch: 368 Train loss: 0.0082748 Validation loss: 0.022201
# Epoch: 369 Train loss: 0.0082708 Validation loss: 0.022197
# Epoch: 370 Train loss: 0.0082668 Validation loss: 0.022193
# Epoch: 371 Train loss: 0.0082628 Validation loss: 0.02219
# Epoch: 372 Train loss: 0.0082588 Validation loss: 0.022186
# Epoch: 373 Train loss: 0.0082548 Validation loss: 0.022183
# Epoch: 374 Train loss: 0.0082508 Validation loss: 0.022179
# Epoch: 375 Train loss: 0.0082468 Validation loss: 0.022175
# Epoch: 376 Train loss: 0.0082429 Validation loss: 0.022172
# Epoch: 377 Train loss: 0.008239 Validation loss: 0.022168
# Epoch: 378 Train loss: 0.008235 Validation loss: 0.022165
# Epoch: 379 Train loss: 0.0082311 Validation loss: 0.022161
# Epoch: 380 Train loss: 0.0082272 Validation loss: 0.022158
# Epoch: 381 Train loss: 0.0082233 Validation loss: 0.022154
# Epoch: 382 Train loss: 0.0082194 Validation loss: 0.022151
# Epoch: 383 Train loss: 0.0082155 Validation loss: 0.022147
# Epoch: 384 Train loss: 0.0082117 Validation loss: 0.022144
# Epoch: 385 Train loss: 0.0082078 Validation loss: 0.02214
# Epoch: 386 Train loss: 0.008204 Validation loss: 0.022137
# Epoch: 387 Train loss: 0.0082001 Validation loss: 0.022133
# Epoch: 388 Train loss: 0.0081963 Validation loss: 0.02213
# Epoch: 389 Train loss: 0.0081925 Validation loss: 0.022127
# Epoch: 390 Train loss: 0.0081887 Validation loss: 0.022123
# Epoch: 391 Train loss: 0.0081849 Validation loss: 0.02212
# Epoch: 392 Train loss: 0.0081811 Validation loss: 0.022116
# Epoch: 393 Train loss: 0.0081773 Validation loss: 0.022113
# Epoch: 394 Train loss: 0.0081736 Validation loss: 0.02211
# Epoch: 395 Train loss: 0.0081698 Validation loss: 0.022106
# Epoch: 396 Train loss: 0.008166 Validation loss: 0.022103
# Epoch: 397 Train loss: 0.0081623 Validation loss: 0.0221
# Epoch: 398 Train loss: 0.0081586 Validation loss: 0.022096
# Epoch: 399 Train loss: 0.0081548 Validation loss: 0.022093
# Epoch: 400 Train loss: 0.0081511 Validation loss: 0.02209
# Epoch: 401 Train loss: 0.0081474 Validation loss: 0.022086
# Epoch: 402 Train loss: 0.0081437 Validation loss: 0.022083
# Epoch: 403 Train loss: 0.0081401 Validation loss: 0.02208
# Epoch: 404 Train loss: 0.0081364 Validation loss: 0.022077
# Epoch: 405 Train loss: 0.0081327 Validation loss: 0.022073
# Epoch: 406 Train loss: 0.0081291 Validation loss: 0.02207
# Epoch: 407 Train loss: 0.0081254 Validation loss: 0.022067
# Epoch: 408 Train loss: 0.0081218 Validation loss: 0.022064
# Epoch: 409 Train loss: 0.0081182 Validation loss: 0.02206
# Epoch: 410 Train loss: 0.0081145 Validation loss: 0.022057
# Epoch: 411 Train loss: 0.0081109 Validation loss: 0.022054
# Epoch: 412 Train loss: 0.0081073 Validation loss: 0.022051
# Epoch: 413 Train loss: 0.0081037 Validation loss: 0.022048
# Epoch: 414 Train loss: 0.0081001 Validation loss: 0.022044
# Epoch: 415 Train loss: 0.0080965 Validation loss: 0.022041
# Epoch: 416 Train loss: 0.008093 Validation loss: 0.022038
# Epoch: 417 Train loss: 0.0080894 Validation loss: 0.022035
# Epoch: 418 Train loss: 0.0080859 Validation loss: 0.022032
# Epoch: 419 Train loss: 0.0080823 Validation loss: 0.022029
# Epoch: 420 Train loss: 0.0080788 Validation loss: 0.022025
# Epoch: 421 Train loss: 0.0080753 Validation loss: 0.022022
# Epoch: 422 Train loss: 0.0080717 Validation loss: 0.022019
# Epoch: 423 Train loss: 0.0080682 Validation loss: 0.022016
# Epoch: 424 Train loss: 0.0080647 Validation loss: 0.022013
# Epoch: 425 Train loss: 0.0080612 Validation loss: 0.02201
# Epoch: 426 Train loss: 0.0080577 Validation loss: 0.022007
# Epoch: 427 Train loss: 0.0080542 Validation loss: 0.022004
# Epoch: 428 Train loss: 0.0080508 Validation loss: 0.022001
# Epoch: 429 Train loss: 0.0080473 Validation loss: 0.021998
# Epoch: 430 Train loss: 0.0080439 Validation loss: 0.021995
# Epoch: 431 Train loss: 0.0080404 Validation loss: 0.021992
# Epoch: 432 Train loss: 0.008037 Validation loss: 0.021989
# Epoch: 433 Train loss: 0.0080335 Validation loss: 0.021986
# Epoch: 434 Train loss: 0.0080301 Validation loss: 0.021983
# Epoch: 435 Train loss: 0.0080267 Validation loss: 0.02198
# Epoch: 436 Train loss: 0.0080233 Validation loss: 0.021977
# Epoch: 437 Train loss: 0.0080199 Validation loss: 0.021974
# Epoch: 438 Train loss: 0.0080165 Validation loss: 0.021971
# Epoch: 439 Train loss: 0.0080131 Validation loss: 0.021968
# Epoch: 440 Train loss: 0.0080097 Validation loss: 0.021965
# Epoch: 441 Train loss: 0.0080064 Validation loss: 0.021962
# Epoch: 442 Train loss: 0.008003 Validation loss: 0.021959
# Epoch: 443 Train loss: 0.0079996 Validation loss: 0.021956
# Epoch: 444 Train loss: 0.0079963 Validation loss: 0.021953
# Epoch: 445 Train loss: 0.0079929 Validation loss: 0.02195
# Epoch: 446 Train loss: 0.0079896 Validation loss: 0.021947
# Epoch: 447 Train loss: 0.0079863 Validation loss: 0.021944
# Epoch: 448 Train loss: 0.007983 Validation loss: 0.021941
# Epoch: 449 Train loss: 0.0079796 Validation loss: 0.021938
# Epoch: 450 Train loss: 0.0079763 Validation loss: 0.021936
# Epoch: 451 Train loss: 0.007973 Validation loss: 0.021933
# Epoch: 452 Train loss: 0.0079697 Validation loss: 0.02193
# Epoch: 453 Train loss: 0.0079664 Validation loss: 0.021927
# Epoch: 454 Train loss: 0.0079632 Validation loss: 0.021924
# Epoch: 455 Train loss: 0.0079599 Validation loss: 0.021921
# Epoch: 456 Train loss: 0.0079566 Validation loss: 0.021918
# Epoch: 457 Train loss: 0.0079534 Validation loss: 0.021916
# Epoch: 458 Train loss: 0.0079501 Validation loss: 0.021913
# Epoch: 459 Train loss: 0.0079469 Validation loss: 0.02191
# Epoch: 460 Train loss: 0.0079437 Validation loss: 0.021907
# Epoch: 461 Train loss: 0.0079404 Validation loss: 0.021904
# Epoch: 462 Train loss: 0.0079372 Validation loss: 0.021902
# Epoch: 463 Train loss: 0.007934 Validation loss: 0.021899
# Epoch: 464 Train loss: 0.0079308 Validation loss: 0.021896
# Epoch: 465 Train loss: 0.0079276 Validation loss: 0.021893
# Epoch: 466 Train loss: 0.0079244 Validation loss: 0.021891
# Epoch: 467 Train loss: 0.0079212 Validation loss: 0.021888
# Epoch: 468 Train loss: 0.007918 Validation loss: 0.021885
# Epoch: 469 Train loss: 0.0079148 Validation loss: 0.021882
# Epoch: 470 Train loss: 0.0079116 Validation loss: 0.02188
# Epoch: 471 Train loss: 0.0079085 Validation loss: 0.021877
# Epoch: 472 Train loss: 0.0079053 Validation loss: 0.021874
# Epoch: 473 Train loss: 0.0079022 Validation loss: 0.021872
# Epoch: 474 Train loss: 0.007899 Validation loss: 0.021869
# Epoch: 475 Train loss: 0.0078959 Validation loss: 0.021866
# Epoch: 476 Train loss: 0.0078927 Validation loss: 0.021864
# Epoch: 477 Train loss: 0.0078896 Validation loss: 0.021861
# Epoch: 478 Train loss: 0.0078865 Validation loss: 0.021858
# Epoch: 479 Train loss: 0.0078834 Validation loss: 0.021856
# Epoch: 480 Train loss: 0.0078803 Validation loss: 0.021853
# Epoch: 481 Train loss: 0.0078772 Validation loss: 0.02185
# Epoch: 482 Train loss: 0.0078741 Validation loss: 0.021848
# Epoch: 483 Train loss: 0.007871 Validation loss: 0.021845
# Epoch: 484 Train loss: 0.0078679 Validation loss: 0.021842
# Epoch: 485 Train loss: 0.0078648 Validation loss: 0.02184
# Epoch: 486 Train loss: 0.0078617 Validation loss: 0.021837
# Epoch: 487 Train loss: 0.0078587 Validation loss: 0.021835
# Epoch: 488 Train loss: 0.0078556 Validation loss: 0.021832
# Epoch: 489 Train loss: 0.0078526 Validation loss: 0.021829
# Epoch: 490 Train loss: 0.0078495 Validation loss: 0.021827
# Epoch: 491 Train loss: 0.0078465 Validation loss: 0.021824
# Epoch: 492 Train loss: 0.0078434 Validation loss: 0.021822
# Epoch: 493 Train loss: 0.0078404 Validation loss: 0.021819
# Epoch: 494 Train loss: 0.0078374 Validation loss: 0.021816
# Epoch: 495 Train loss: 0.0078344 Validation loss: 0.021814
# Epoch: 496 Train loss: 0.0078314 Validation loss: 0.021811
# Epoch: 497 Train loss: 0.0078284 Validation loss: 0.021809
# Epoch: 498 Train loss: 0.0078254 Validation loss: 0.021806
# Epoch: 499 Train loss: 0.0078224 Validation loss: 0.021804
# Epoch: 500 Train loss: 0.0078194 Validation loss: 0.021801
# Epoch: 501 Train loss: 0.0078164 Validation loss: 0.021799
# Epoch: 502 Train loss: 0.0078134 Validation loss: 0.021796
# Epoch: 503 Train loss: 0.0078104 Validation loss: 0.021794
# Epoch: 504 Train loss: 0.0078075 Validation loss: 0.021791
# Epoch: 505 Train loss: 0.0078045 Validation loss: 0.021789
# Epoch: 506 Train loss: 0.0078015 Validation loss: 0.021786
# Epoch: 507 Train loss: 0.0077986 Validation loss: 0.021784
# Epoch: 508 Train loss: 0.0077956 Validation loss: 0.021781
# Epoch: 509 Train loss: 0.0077927 Validation loss: 0.021779
# Epoch: 510 Train loss: 0.0077898 Validation loss: 0.021776
# Epoch: 511 Train loss: 0.0077868 Validation loss: 0.021774
# Epoch: 512 Train loss: 0.0077839 Validation loss: 0.021771
# Epoch: 513 Train loss: 0.007781 Validation loss: 0.021769
# Epoch: 514 Train loss: 0.0077781 Validation loss: 0.021767
# Epoch: 515 Train loss: 0.0077752 Validation loss: 0.021764
# Epoch: 516 Train loss: 0.0077722 Validation loss: 0.021762
# Epoch: 517 Train loss: 0.0077693 Validation loss: 0.021759
# Epoch: 518 Train loss: 0.0077664 Validation loss: 0.021757
# Epoch: 519 Train loss: 0.0077636 Validation loss: 0.021754
# Epoch: 520 Train loss: 0.0077607 Validation loss: 0.021752
# Epoch: 521 Train loss: 0.0077578 Validation loss: 0.02175
# Epoch: 522 Train loss: 0.0077549 Validation loss: 0.021747
# Epoch: 523 Train loss: 0.0077521 Validation loss: 0.021745
# Epoch: 524 Train loss: 0.0077492 Validation loss: 0.021742
# Epoch: 525 Train loss: 0.0077463 Validation loss: 0.02174
# Epoch: 526 Train loss: 0.0077435 Validation loss: 0.021738
# Epoch: 527 Train loss: 0.0077406 Validation loss: 0.021735
# Epoch: 528 Train loss: 0.0077378 Validation loss: 0.021733
# Epoch: 529 Train loss: 0.0077349 Validation loss: 0.021731
# Epoch: 530 Train loss: 0.0077321 Validation loss: 0.021728
# Epoch: 531 Train loss: 0.0077293 Validation loss: 0.021726
# Epoch: 532 Train loss: 0.0077264 Validation loss: 0.021724
# Epoch: 533 Train loss: 0.0077236 Validation loss: 0.021721
# Epoch: 534 Train loss: 0.0077208 Validation loss: 0.021719
# Epoch: 535 Train loss: 0.007718 Validation loss: 0.021717
# Epoch: 536 Train loss: 0.0077152 Validation loss: 0.021714
# Epoch: 537 Train loss: 0.0077124 Validation loss: 0.021712
# Epoch: 538 Train loss: 0.0077096 Validation loss: 0.02171
# Epoch: 539 Train loss: 0.0077068 Validation loss: 0.021707
# Epoch: 540 Train loss: 0.007704 Validation loss: 0.021705
# Epoch: 541 Train loss: 0.0077012 Validation loss: 0.021703
# Epoch: 542 Train loss: 0.0076985 Validation loss: 0.0217
# Epoch: 543 Train loss: 0.0076957 Validation loss: 0.021698
# Epoch: 544 Train loss: 0.0076929 Validation loss: 0.021696
# Epoch: 545 Train loss: 0.0076902 Validation loss: 0.021694
# Epoch: 546 Train loss: 0.0076874 Validation loss: 0.021691
# Epoch: 547 Train loss: 0.0076846 Validation loss: 0.021689
# Epoch: 548 Train loss: 0.0076819 Validation loss: 0.021687
# Epoch: 549 Train loss: 0.0076792 Validation loss: 0.021685
# Epoch: 550 Train loss: 0.0076764 Validation loss: 0.021682
# Epoch: 551 Train loss: 0.0076737 Validation loss: 0.02168
# Epoch: 552 Train loss: 0.0076709 Validation loss: 0.021678
# Epoch: 553 Train loss: 0.0076682 Validation loss: 0.021676
# Epoch: 554 Train loss: 0.0076655 Validation loss: 0.021673
# Epoch: 555 Train loss: 0.0076628 Validation loss: 0.021671
# Epoch: 556 Train loss: 0.0076601 Validation loss: 0.021669
# Epoch: 557 Train loss: 0.0076573 Validation loss: 0.021667
# Epoch: 558 Train loss: 0.0076547 Validation loss: 0.021664
# Epoch: 559 Train loss: 0.0076519 Validation loss: 0.021662
# Epoch: 560 Train loss: 0.0076493 Validation loss: 0.02166
# Epoch: 561 Train loss: 0.0076466 Validation loss: 0.021658
# Epoch: 562 Train loss: 0.0076439 Validation loss: 0.021656
# Epoch: 563 Train loss: 0.0076412 Validation loss: 0.021654
# Epoch: 564 Train loss: 0.0076385 Validation loss: 0.021651
# Epoch: 565 Train loss: 0.0076359 Validation loss: 0.021649
# Epoch: 566 Train loss: 0.0076332 Validation loss: 0.021647
# Epoch: 567 Train loss: 0.0076305 Validation loss: 0.021645
# Epoch: 568 Train loss: 0.0076279 Validation loss: 0.021643
# Epoch: 569 Train loss: 0.0076252 Validation loss: 0.02164
# Epoch: 570 Train loss: 0.0076226 Validation loss: 0.021638
# Epoch: 571 Train loss: 0.0076199 Validation loss: 0.021636
# Epoch: 572 Train loss: 0.0076173 Validation loss: 0.021634
# Epoch: 573 Train loss: 0.0076147 Validation loss: 0.021632
# Epoch: 574 Train loss: 0.007612 Validation loss: 0.02163
# Epoch: 575 Train loss: 0.0076094 Validation loss: 0.021628
# Epoch: 576 Train loss: 0.0076068 Validation loss: 0.021625
# Epoch: 577 Train loss: 0.0076042 Validation loss: 0.021623
# Epoch: 578 Train loss: 0.0076015 Validation loss: 0.021621
# Epoch: 579 Train loss: 0.0075989 Validation loss: 0.021619
# Epoch: 580 Train loss: 0.0075963 Validation loss: 0.021617
# Epoch: 581 Train loss: 0.0075937 Validation loss: 0.021615
# Epoch: 582 Train loss: 0.0075911 Validation loss: 0.021613
# Epoch: 583 Train loss: 0.0075885 Validation loss: 0.021611
# Epoch: 584 Train loss: 0.007586 Validation loss: 0.021608
# Epoch: 585 Train loss: 0.0075834 Validation loss: 0.021606
# Epoch: 586 Train loss: 0.0075808 Validation loss: 0.021604
# Epoch: 587 Train loss: 0.0075782 Validation loss: 0.021602
# Epoch: 588 Train loss: 0.0075756 Validation loss: 0.0216
# Epoch: 589 Train loss: 0.0075731 Validation loss: 0.021598
# Epoch: 590 Train loss: 0.0075705 Validation loss: 0.021596
# Epoch: 591 Train loss: 0.007568 Validation loss: 0.021594
# Epoch: 592 Train loss: 0.0075654 Validation loss: 0.021592
# Epoch: 593 Train loss: 0.0075628 Validation loss: 0.02159
# Epoch: 594 Train loss: 0.0075603 Validation loss: 0.021588
# Epoch: 595 Train loss: 0.0075577 Validation loss: 0.021585
# Epoch: 596 Train loss: 0.0075552 Validation loss: 0.021583
# Epoch: 597 Train loss: 0.0075527 Validation loss: 0.021581
# Epoch: 598 Train loss: 0.0075501 Validation loss: 0.021579
# Epoch: 599 Train loss: 0.0075476 Validation loss: 0.021577
# Epoch: 600 Train loss: 0.0075451 Validation loss: 0.021575
# Epoch: 601 Train loss: 0.0075426 Validation loss: 0.021573
# Epoch: 602 Train loss: 0.0075401 Validation loss: 0.021571
# Epoch: 603 Train loss: 0.0075375 Validation loss: 0.021569
# Epoch: 604 Train loss: 0.007535 Validation loss: 0.021567
# Epoch: 605 Train loss: 0.0075325 Validation loss: 0.021565
# Epoch: 606 Train loss: 0.00753 Validation loss: 0.021563
# Epoch: 607 Train loss: 0.0075275 Validation loss: 0.021561
# Epoch: 608 Train loss: 0.007525 Validation loss: 0.021559
# Epoch: 609 Train loss: 0.0075225 Validation loss: 0.021557
# Epoch: 610 Train loss: 0.0075201 Validation loss: 0.021555
# Epoch: 611 Train loss: 0.0075176 Validation loss: 0.021553
# Epoch: 612 Train loss: 0.0075151 Validation loss: 0.021551
# Epoch: 613 Train loss: 0.0075126 Validation loss: 0.021549
# Epoch: 614 Train loss: 0.0075102 Validation loss: 0.021547
# Epoch: 615 Train loss: 0.0075077 Validation loss: 0.021545
# Epoch: 616 Train loss: 0.0075052 Validation loss: 0.021543
# Epoch: 617 Train loss: 0.0075028 Validation loss: 0.021541
# Epoch: 618 Train loss: 0.0075003 Validation loss: 0.021539
# Epoch: 619 Train loss: 0.0074979 Validation loss: 0.021537
# Epoch: 620 Train loss: 0.0074954 Validation loss: 0.021535
# Epoch: 621 Train loss: 0.007493 Validation loss: 0.021533
# Epoch: 622 Train loss: 0.0074905 Validation loss: 0.021531
# Epoch: 623 Train loss: 0.0074881 Validation loss: 0.021529
# Epoch: 624 Train loss: 0.0074857 Validation loss: 0.021527
# Epoch: 625 Train loss: 0.0074832 Validation loss: 0.021525
# Epoch: 626 Train loss: 0.0074808 Validation loss: 0.021523
# Epoch: 627 Train loss: 0.0074784 Validation loss: 0.021521
# Epoch: 628 Train loss: 0.007476 Validation loss: 0.02152
# Epoch: 629 Train loss: 0.0074736 Validation loss: 0.021518
# Epoch: 630 Train loss: 0.0074712 Validation loss: 0.021516
# Epoch: 631 Train loss: 0.0074687 Validation loss: 0.021514
# Epoch: 632 Train loss: 0.0074663 Validation loss: 0.021512
# Epoch: 633 Train loss: 0.007464 Validation loss: 0.02151
# Epoch: 634 Train loss: 0.0074616 Validation loss: 0.021508
# Epoch: 635 Train loss: 0.0074592 Validation loss: 0.021506
# Epoch: 636 Train loss: 0.0074568 Validation loss: 0.021504
# Epoch: 637 Train loss: 0.0074544 Validation loss: 0.021502
# Epoch: 638 Train loss: 0.007452 Validation loss: 0.0215
# Epoch: 639 Train loss: 0.0074496 Validation loss: 0.021498
# Epoch: 640 Train loss: 0.0074473 Validation loss: 0.021497
# Epoch: 641 Train loss: 0.0074449 Validation loss: 0.021495
# Epoch: 642 Train loss: 0.0074425 Validation loss: 0.021493
# Epoch: 643 Train loss: 0.0074402 Validation loss: 0.021491
# Epoch: 644 Train loss: 0.0074378 Validation loss: 0.021489
# Epoch: 645 Train loss: 0.0074355 Validation loss: 0.021487
# Epoch: 646 Train loss: 0.0074331 Validation loss: 0.021485
# Epoch: 647 Train loss: 0.0074308 Validation loss: 0.021483
# Epoch: 648 Train loss: 0.0074285 Validation loss: 0.021481
# Epoch: 649 Train loss: 0.0074261 Validation loss: 0.02148
# Epoch: 650 Train loss: 0.0074238 Validation loss: 0.021478
# Epoch: 651 Train loss: 0.0074214 Validation loss: 0.021476
# Epoch: 652 Train loss: 0.0074191 Validation loss: 0.021474
# Epoch: 653 Train loss: 0.0074168 Validation loss: 0.021472
# Epoch: 654 Train loss: 0.0074145 Validation loss: 0.02147
# Epoch: 655 Train loss: 0.0074122 Validation loss: 0.021468
# Epoch: 656 Train loss: 0.0074099 Validation loss: 0.021467
# Epoch: 657 Train loss: 0.0074075 Validation loss: 0.021465
# Epoch: 658 Train loss: 0.0074052 Validation loss: 0.021463
# Epoch: 659 Train loss: 0.0074029 Validation loss: 0.021461
# Epoch: 660 Train loss: 0.0074006 Validation loss: 0.021459
# Epoch: 661 Train loss: 0.0073984 Validation loss: 0.021457
# Epoch: 662 Train loss: 0.0073961 Validation loss: 0.021456
# Epoch: 663 Train loss: 0.0073938 Validation loss: 0.021454
# Epoch: 664 Train loss: 0.0073915 Validation loss: 0.021452
# Epoch: 665 Train loss: 0.0073892 Validation loss: 0.02145
# Epoch: 666 Train loss: 0.007387 Validation loss: 0.021448
# Epoch: 667 Train loss: 0.0073847 Validation loss: 0.021446
# Epoch: 668 Train loss: 0.0073824 Validation loss: 0.021445
# Epoch: 669 Train loss: 0.0073802 Validation loss: 0.021443
# Epoch: 670 Train loss: 0.0073779 Validation loss: 0.021441
# Epoch: 671 Train loss: 0.0073756 Validation loss: 0.021439
# Epoch: 672 Train loss: 0.0073734 Validation loss: 0.021437
# Epoch: 673 Train loss: 0.0073711 Validation loss: 0.021436
# Epoch: 674 Train loss: 0.0073689 Validation loss: 0.021434
# Epoch: 675 Train loss: 0.0073667 Validation loss: 0.021432
# Epoch: 676 Train loss: 0.0073644 Validation loss: 0.02143
# Epoch: 677 Train loss: 0.0073622 Validation loss: 0.021428
# Epoch: 678 Train loss: 0.0073599 Validation loss: 0.021427
# Epoch: 679 Train loss: 0.0073577 Validation loss: 0.021425
# Epoch: 680 Train loss: 0.0073555 Validation loss: 0.021423
# Epoch: 681 Train loss: 0.0073533 Validation loss: 0.021421
# Epoch: 682 Train loss: 0.0073511 Validation loss: 0.021419
# Epoch: 683 Train loss: 0.0073488 Validation loss: 0.021418
# Epoch: 684 Train loss: 0.0073466 Validation loss: 0.021416
# Epoch: 685 Train loss: 0.0073444 Validation loss: 0.021414
# Epoch: 686 Train loss: 0.0073422 Validation loss: 0.021412
# Epoch: 687 Train loss: 0.00734 Validation loss: 0.021411
# Epoch: 688 Train loss: 0.0073378 Validation loss: 0.021409
# Epoch: 689 Train loss: 0.0073356 Validation loss: 0.021407
# Epoch: 690 Train loss: 0.0073334 Validation loss: 0.021405
# Epoch: 691 Train loss: 0.0073312 Validation loss: 0.021404
# Epoch: 692 Train loss: 0.0073291 Validation loss: 0.021402
# Epoch: 693 Train loss: 0.0073269 Validation loss: 0.0214
# Epoch: 694 Train loss: 0.0073247 Validation loss: 0.021398
# Epoch: 695 Train loss: 0.0073225 Validation loss: 0.021397
# Epoch: 696 Train loss: 0.0073204 Validation loss: 0.021395
# Epoch: 697 Train loss: 0.0073182 Validation loss: 0.021393
# Epoch: 698 Train loss: 0.007316 Validation loss: 0.021391
# Epoch: 699 Train loss: 0.0073139 Validation loss: 0.02139
# Epoch: 700 Train loss: 0.0073117 Validation loss: 0.021388
# Epoch: 701 Train loss: 0.0073096 Validation loss: 0.021386
# Epoch: 702 Train loss: 0.0073074 Validation loss: 0.021384
# Epoch: 703 Train loss: 0.0073053 Validation loss: 0.021383
# Epoch: 704 Train loss: 0.0073031 Validation loss: 0.021381
# Epoch: 705 Train loss: 0.007301 Validation loss: 0.021379
# Epoch: 706 Train loss: 0.0072989 Validation loss: 0.021378
# Epoch: 707 Train loss: 0.0072967 Validation loss: 0.021376
# Epoch: 708 Train loss: 0.0072946 Validation loss: 0.021374
# Epoch: 709 Train loss: 0.0072925 Validation loss: 0.021372
# Epoch: 710 Train loss: 0.0072903 Validation loss: 0.021371
# Epoch: 711 Train loss: 0.0072882 Validation loss: 0.021369
# Epoch: 712 Train loss: 0.0072861 Validation loss: 0.021367
# Epoch: 713 Train loss: 0.007284 Validation loss: 0.021366
# Epoch: 714 Train loss: 0.0072819 Validation loss: 0.021364
# Epoch: 715 Train loss: 0.0072798 Validation loss: 0.021362
# Epoch: 716 Train loss: 0.0072777 Validation loss: 0.02136
# Epoch: 717 Train loss: 0.0072756 Validation loss: 0.021359
# Epoch: 718 Train loss: 0.0072735 Validation loss: 0.021357
# Epoch: 719 Train loss: 0.0072714 Validation loss: 0.021355
# Epoch: 720 Train loss: 0.0072693 Validation loss: 0.021354
# Epoch: 721 Train loss: 0.0072673 Validation loss: 0.021352
# Epoch: 722 Train loss: 0.0072652 Validation loss: 0.02135
# Epoch: 723 Train loss: 0.0072631 Validation loss: 0.021349
# Epoch: 724 Train loss: 0.007261 Validation loss: 0.021347
# Epoch: 725 Train loss: 0.0072589 Validation loss: 0.021345
# Epoch: 726 Train loss: 0.0072569 Validation loss: 0.021344
# Epoch: 727 Train loss: 0.0072548 Validation loss: 0.021342
# Epoch: 728 Train loss: 0.0072528 Validation loss: 0.02134
# Epoch: 729 Train loss: 0.0072507 Validation loss: 0.021339
# Epoch: 730 Train loss: 0.0072486 Validation loss: 0.021337
# Epoch: 731 Train loss: 0.0072466 Validation loss: 0.021335
# Epoch: 732 Train loss: 0.0072446 Validation loss: 0.021334
# Epoch: 733 Train loss: 0.0072425 Validation loss: 0.021332
# Epoch: 734 Train loss: 0.0072405 Validation loss: 0.02133
# Epoch: 735 Train loss: 0.0072384 Validation loss: 0.021329
# Epoch: 736 Train loss: 0.0072364 Validation loss: 0.021327
# Epoch: 737 Train loss: 0.0072344 Validation loss: 0.021325
# Epoch: 738 Train loss: 0.0072323 Validation loss: 0.021324
# Epoch: 739 Train loss: 0.0072303 Validation loss: 0.021322
# Epoch: 740 Train loss: 0.0072283 Validation loss: 0.02132
# Epoch: 741 Train loss: 0.0072263 Validation loss: 0.021319
# Epoch: 742 Train loss: 0.0072243 Validation loss: 0.021317
# Epoch: 743 Train loss: 0.0072222 Validation loss: 0.021315
# Epoch: 744 Train loss: 0.0072202 Validation loss: 0.021314
# Epoch: 745 Train loss: 0.0072182 Validation loss: 0.021312
# Epoch: 746 Train loss: 0.0072162 Validation loss: 0.021311
# Epoch: 747 Train loss: 0.0072142 Validation loss: 0.021309
# Epoch: 748 Train loss: 0.0072122 Validation loss: 0.021307
# Epoch: 749 Train loss: 0.0072103 Validation loss: 0.021306
# Epoch: 750 Train loss: 0.0072083 Validation loss: 0.021304
# Epoch: 751 Train loss: 0.0072063 Validation loss: 0.021302
# Epoch: 752 Train loss: 0.0072043 Validation loss: 0.021301
# Epoch: 753 Train loss: 0.0072023 Validation loss: 0.021299
# Epoch: 754 Train loss: 0.0072003 Validation loss: 0.021297
# Epoch: 755 Train loss: 0.0071984 Validation loss: 0.021296
# Epoch: 756 Train loss: 0.0071964 Validation loss: 0.021294
# Epoch: 757 Train loss: 0.0071944 Validation loss: 0.021293
# Epoch: 758 Train loss: 0.0071925 Validation loss: 0.021291
# Epoch: 759 Train loss: 0.0071905 Validation loss: 0.021289
# Epoch: 760 Train loss: 0.0071885 Validation loss: 0.021288
# Epoch: 761 Train loss: 0.0071866 Validation loss: 0.021286
# Epoch: 762 Train loss: 0.0071846 Validation loss: 0.021284
# Epoch: 763 Train loss: 0.0071827 Validation loss: 0.021283
# Epoch: 764 Train loss: 0.0071807 Validation loss: 0.021281
# Epoch: 765 Train loss: 0.0071788 Validation loss: 0.02128
# Epoch: 766 Train loss: 0.0071769 Validation loss: 0.021278
# Epoch: 767 Train loss: 0.0071749 Validation loss: 0.021276
# Epoch: 768 Train loss: 0.007173 Validation loss: 0.021275
# Epoch: 769 Train loss: 0.0071711 Validation loss: 0.021273
# Epoch: 770 Train loss: 0.0071691 Validation loss: 0.021272
# Epoch: 771 Train loss: 0.0071672 Validation loss: 0.02127
# Epoch: 772 Train loss: 0.0071653 Validation loss: 0.021268
# Epoch: 773 Train loss: 0.0071634 Validation loss: 0.021267
# Epoch: 774 Train loss: 0.0071615 Validation loss: 0.021265
# Epoch: 775 Train loss: 0.0071596 Validation loss: 0.021264
# Epoch: 776 Train loss: 0.0071577 Validation loss: 0.021262
# Epoch: 777 Train loss: 0.0071558 Validation loss: 0.02126
# Epoch: 778 Train loss: 0.0071539 Validation loss: 0.021259
# Epoch: 779 Train loss: 0.007152 Validation loss: 0.021257
# Epoch: 780 Train loss: 0.0071501 Validation loss: 0.021256
# Epoch: 781 Train loss: 0.0071482 Validation loss: 0.021254
# Epoch: 782 Train loss: 0.0071463 Validation loss: 0.021252
# Epoch: 783 Train loss: 0.0071444 Validation loss: 0.021251
# Epoch: 784 Train loss: 0.0071425 Validation loss: 0.021249
# Epoch: 785 Train loss: 0.0071407 Validation loss: 0.021248
# Epoch: 786 Train loss: 0.0071388 Validation loss: 0.021246
# Epoch: 787 Train loss: 0.0071369 Validation loss: 0.021245
# Epoch: 788 Train loss: 0.0071351 Validation loss: 0.021243
# Epoch: 789 Train loss: 0.0071332 Validation loss: 0.021241
# Epoch: 790 Train loss: 0.0071313 Validation loss: 0.02124
# Epoch: 791 Train loss: 0.0071295 Validation loss: 0.021238
# Epoch: 792 Train loss: 0.0071276 Validation loss: 0.021237
# Epoch: 793 Train loss: 0.0071258 Validation loss: 0.021235
# Epoch: 794 Train loss: 0.0071239 Validation loss: 0.021234
# Epoch: 795 Train loss: 0.0071221 Validation loss: 0.021232
# Epoch: 796 Train loss: 0.0071203 Validation loss: 0.021231
# Epoch: 797 Train loss: 0.0071184 Validation loss: 0.021229
# Epoch: 798 Train loss: 0.0071166 Validation loss: 0.021227
# Epoch: 799 Train loss: 0.0071148 Validation loss: 0.021226
# Epoch: 800 Train loss: 0.0071129 Validation loss: 0.021224
# Epoch: 801 Train loss: 0.0071111 Validation loss: 0.021223
# Epoch: 802 Train loss: 0.0071093 Validation loss: 0.021221
# Epoch: 803 Train loss: 0.0071075 Validation loss: 0.02122
# Epoch: 804 Train loss: 0.0071056 Validation loss: 0.021218
# Epoch: 805 Train loss: 0.0071038 Validation loss: 0.021217
# Epoch: 806 Train loss: 0.007102 Validation loss: 0.021215
# Epoch: 807 Train loss: 0.0071002 Validation loss: 0.021213
# Epoch: 808 Train loss: 0.0070984 Validation loss: 0.021212
# Epoch: 809 Train loss: 0.0070966 Validation loss: 0.02121
# Epoch: 810 Train loss: 0.0070948 Validation loss: 0.021209
# Epoch: 811 Train loss: 0.007093 Validation loss: 0.021207
# Epoch: 812 Train loss: 0.0070912 Validation loss: 0.021206
# Epoch: 813 Train loss: 0.0070894 Validation loss: 0.021204
# Epoch: 814 Train loss: 0.0070877 Validation loss: 0.021203
# Epoch: 815 Train loss: 0.0070859 Validation loss: 0.021201
# Epoch: 816 Train loss: 0.0070841 Validation loss: 0.0212
# Epoch: 817 Train loss: 0.0070823 Validation loss: 0.021198
# Epoch: 818 Train loss: 0.0070806 Validation loss: 0.021197
# Epoch: 819 Train loss: 0.0070788 Validation loss: 0.021195
# Epoch: 820 Train loss: 0.007077 Validation loss: 0.021194
# Epoch: 821 Train loss: 0.0070753 Validation loss: 0.021192
# Epoch: 822 Train loss: 0.0070735 Validation loss: 0.021191
# Epoch: 823 Train loss: 0.0070717 Validation loss: 0.021189
# Epoch: 824 Train loss: 0.00707 Validation loss: 0.021187
# Epoch: 825 Train loss: 0.0070682 Validation loss: 0.021186
# Epoch: 826 Train loss: 0.0070665 Validation loss: 0.021184
# Epoch: 827 Train loss: 0.0070647 Validation loss: 0.021183
# Epoch: 828 Train loss: 0.007063 Validation loss: 0.021181
# Epoch: 829 Train loss: 0.0070613 Validation loss: 0.02118
# Epoch: 830 Train loss: 0.0070595 Validation loss: 0.021178
# Epoch: 831 Train loss: 0.0070578 Validation loss: 0.021177
# Epoch: 832 Train loss: 0.0070561 Validation loss: 0.021175
# Epoch: 833 Train loss: 0.0070543 Validation loss: 0.021174
# Epoch: 834 Train loss: 0.0070526 Validation loss: 0.021172
# Epoch: 835 Train loss: 0.0070509 Validation loss: 0.021171
# Epoch: 836 Train loss: 0.0070492 Validation loss: 0.021169
# Epoch: 837 Train loss: 0.0070475 Validation loss: 0.021168
# Epoch: 838 Train loss: 0.0070458 Validation loss: 0.021166
# Epoch: 839 Train loss: 0.0070441 Validation loss: 0.021165
# Epoch: 840 Train loss: 0.0070423 Validation loss: 0.021163
# Epoch: 841 Train loss: 0.0070406 Validation loss: 0.021162
# Epoch: 842 Train loss: 0.0070389 Validation loss: 0.02116
# Epoch: 843 Train loss: 0.0070373 Validation loss: 0.021158
# Epoch: 844 Train loss: 0.0070356 Validation loss: 0.021157
# Epoch: 845 Train loss: 0.0070339 Validation loss: 0.021155
# Epoch: 846 Train loss: 0.0070322 Validation loss: 0.021154
# Epoch: 847 Train loss: 0.0070305 Validation loss: 0.021152
# Epoch: 848 Train loss: 0.0070288 Validation loss: 0.021151
# Epoch: 849 Train loss: 0.0070271 Validation loss: 0.021149
# Epoch: 850 Train loss: 0.0070255 Validation loss: 0.021148
# Epoch: 851 Train loss: 0.0070238 Validation loss: 0.021146
# Epoch: 852 Train loss: 0.0070221 Validation loss: 0.021145
# Epoch: 853 Train loss: 0.0070205 Validation loss: 0.021143
# Epoch: 854 Train loss: 0.0070188 Validation loss: 0.021142
# Epoch: 855 Train loss: 0.0070171 Validation loss: 0.02114
# Epoch: 856 Train loss: 0.0070155 Validation loss: 0.021139
# Epoch: 857 Train loss: 0.0070138 Validation loss: 0.021137
# Epoch: 858 Train loss: 0.0070122 Validation loss: 0.021136
# Epoch: 859 Train loss: 0.0070105 Validation loss: 0.021134
# Epoch: 860 Train loss: 0.0070089 Validation loss: 0.021133
# Epoch: 861 Train loss: 0.0070072 Validation loss: 0.021131
# Epoch: 862 Train loss: 0.0070056 Validation loss: 0.02113
# Epoch: 863 Train loss: 0.007004 Validation loss: 0.021128
# Epoch: 864 Train loss: 0.0070023 Validation loss: 0.021127
# Epoch: 865 Train loss: 0.0070007 Validation loss: 0.021125
# Epoch: 866 Train loss: 0.0069991 Validation loss: 0.021124
# Epoch: 867 Train loss: 0.0069975 Validation loss: 0.021122
# Epoch: 868 Train loss: 0.0069958 Validation loss: 0.021121
# Epoch: 869 Train loss: 0.0069942 Validation loss: 0.021119
# Epoch: 870 Train loss: 0.0069926 Validation loss: 0.021118
# Epoch: 871 Train loss: 0.006991 Validation loss: 0.021116
# Epoch: 872 Train loss: 0.0069894 Validation loss: 0.021115
# Epoch: 873 Train loss: 0.0069878 Validation loss: 0.021114
# Epoch: 874 Train loss: 0.0069862 Validation loss: 0.021112
# Epoch: 875 Train loss: 0.0069846 Validation loss: 0.021111
# Epoch: 876 Train loss: 0.006983 Validation loss: 0.021109
# Epoch: 877 Train loss: 0.0069814 Validation loss: 0.021108
# Epoch: 878 Train loss: 0.0069798 Validation loss: 0.021106
# Epoch: 879 Train loss: 0.0069782 Validation loss: 0.021105
# Epoch: 880 Train loss: 0.0069766 Validation loss: 0.021103
# Epoch: 881 Train loss: 0.006975 Validation loss: 0.021102
# Epoch: 882 Train loss: 0.0069734 Validation loss: 0.0211
# Epoch: 883 Train loss: 0.0069718 Validation loss: 0.021099
# Epoch: 884 Train loss: 0.0069703 Validation loss: 0.021097
# Epoch: 885 Train loss: 0.0069687 Validation loss: 0.021096
# Epoch: 886 Train loss: 0.0069671 Validation loss: 0.021094
# Epoch: 887 Train loss: 0.0069656 Validation loss: 0.021093
# Epoch: 888 Train loss: 0.006964 Validation loss: 0.021091
# Epoch: 889 Train loss: 0.0069624 Validation loss: 0.02109
# Epoch: 890 Train loss: 0.0069609 Validation loss: 0.021088
# Epoch: 891 Train loss: 0.0069593 Validation loss: 0.021087
# Epoch: 892 Train loss: 0.0069578 Validation loss: 0.021085
# Epoch: 893 Train loss: 0.0069562 Validation loss: 0.021084
# Epoch: 894 Train loss: 0.0069547 Validation loss: 0.021082
# Epoch: 895 Train loss: 0.0069531 Validation loss: 0.021081
# Epoch: 896 Train loss: 0.0069516 Validation loss: 0.02108
# Epoch: 897 Train loss: 0.00695 Validation loss: 0.021078
# Epoch: 898 Train loss: 0.0069485 Validation loss: 0.021077
# Epoch: 899 Train loss: 0.006947 Validation loss: 0.021075
# Epoch: 900 Train loss: 0.0069454 Validation loss: 0.021074
# Epoch: 901 Train loss: 0.0069439 Validation loss: 0.021072
# Epoch: 902 Train loss: 0.0069424 Validation loss: 0.021071
# Epoch: 903 Train loss: 0.0069409 Validation loss: 0.021069
# Epoch: 904 Train loss: 0.0069393 Validation loss: 0.021068
# Epoch: 905 Train loss: 0.0069378 Validation loss: 0.021066
# Epoch: 906 Train loss: 0.0069363 Validation loss: 0.021065
# Epoch: 907 Train loss: 0.0069348 Validation loss: 0.021063
# Epoch: 908 Train loss: 0.0069333 Validation loss: 0.021062
# Epoch: 909 Train loss: 0.0069318 Validation loss: 0.02106
# Epoch: 910 Train loss: 0.0069303 Validation loss: 0.021059
# Epoch: 911 Train loss: 0.0069288 Validation loss: 0.021058
# Epoch: 912 Train loss: 0.0069273 Validation loss: 0.021056
# Epoch: 913 Train loss: 0.0069258 Validation loss: 0.021055
# Epoch: 914 Train loss: 0.0069243 Validation loss: 0.021053
# Epoch: 915 Train loss: 0.0069228 Validation loss: 0.021052
# Epoch: 916 Train loss: 0.0069213 Validation loss: 0.02105
# Epoch: 917 Train loss: 0.0069199 Validation loss: 0.021049
# Epoch: 918 Train loss: 0.0069184 Validation loss: 0.021047
# Epoch: 919 Train loss: 0.0069169 Validation loss: 0.021046
# Epoch: 920 Train loss: 0.0069154 Validation loss: 0.021045
# Epoch: 921 Train loss: 0.0069139 Validation loss: 0.021043
# Epoch: 922 Train loss: 0.0069125 Validation loss: 0.021042
# Epoch: 923 Train loss: 0.006911 Validation loss: 0.02104
# Epoch: 924 Train loss: 0.0069095 Validation loss: 0.021039
# Epoch: 925 Train loss: 0.0069081 Validation loss: 0.021037
# Epoch: 926 Train loss: 0.0069066 Validation loss: 0.021036
# Epoch: 927 Train loss: 0.0069052 Validation loss: 0.021034
# Epoch: 928 Train loss: 0.0069037 Validation loss: 0.021033
# Epoch: 929 Train loss: 0.0069023 Validation loss: 0.021031
# Epoch: 930 Train loss: 0.0069008 Validation loss: 0.02103
# Epoch: 931 Train loss: 0.0068994 Validation loss: 0.021029
# Epoch: 932 Train loss: 0.0068979 Validation loss: 0.021027
# Epoch: 933 Train loss: 0.0068965 Validation loss: 0.021026
# Epoch: 934 Train loss: 0.0068951 Validation loss: 0.021024
# Epoch: 935 Train loss: 0.0068936 Validation loss: 0.021023
# Epoch: 936 Train loss: 0.0068922 Validation loss: 0.021021
# Epoch: 937 Train loss: 0.0068908 Validation loss: 0.02102
# Epoch: 938 Train loss: 0.0068893 Validation loss: 0.021018
# Epoch: 939 Train loss: 0.0068879 Validation loss: 0.021017
# Epoch: 940 Train loss: 0.0068865 Validation loss: 0.021015
# Epoch: 941 Train loss: 0.0068851 Validation loss: 0.021014
# Epoch: 942 Train loss: 0.0068836 Validation loss: 0.021013
# Epoch: 943 Train loss: 0.0068822 Validation loss: 0.021011
# Epoch: 944 Train loss: 0.0068808 Validation loss: 0.02101
# Epoch: 945 Train loss: 0.0068794 Validation loss: 0.021008
# Epoch: 946 Train loss: 0.006878 Validation loss: 0.021007
# Epoch: 947 Train loss: 0.0068766 Validation loss: 0.021005
# Epoch: 948 Train loss: 0.0068752 Validation loss: 0.021004
# Epoch: 949 Train loss: 0.0068738 Validation loss: 0.021002
# Epoch: 950 Train loss: 0.0068724 Validation loss: 0.021001
# Epoch: 951 Train loss: 0.006871 Validation loss: 0.021
# Epoch: 952 Train loss: 0.0068696 Validation loss: 0.020998
# Epoch: 953 Train loss: 0.0068682 Validation loss: 0.020997
# Epoch: 954 Train loss: 0.0068668 Validation loss: 0.020995
# Epoch: 955 Train loss: 0.0068655 Validation loss: 0.020994
# Epoch: 956 Train loss: 0.0068641 Validation loss: 0.020992
# Epoch: 957 Train loss: 0.0068627 Validation loss: 0.020991
# Epoch: 958 Train loss: 0.0068613 Validation loss: 0.020989
# Epoch: 959 Train loss: 0.00686 Validation loss: 0.020988
# Epoch: 960 Train loss: 0.0068586 Validation loss: 0.020987
# Epoch: 961 Train loss: 0.0068572 Validation loss: 0.020985
# Epoch: 962 Train loss: 0.0068559 Validation loss: 0.020984
# Epoch: 963 Train loss: 0.0068545 Validation loss: 0.020982
# Epoch: 964 Train loss: 0.0068531 Validation loss: 0.020981
# Epoch: 965 Train loss: 0.0068518 Validation loss: 0.020979
# Epoch: 966 Train loss: 0.0068504 Validation loss: 0.020978
# Epoch: 967 Train loss: 0.0068491 Validation loss: 0.020977
# Epoch: 968 Train loss: 0.0068477 Validation loss: 0.020975
# Epoch: 969 Train loss: 0.0068464 Validation loss: 0.020974
# Epoch: 970 Train loss: 0.006845 Validation loss: 0.020972
# Epoch: 971 Train loss: 0.0068437 Validation loss: 0.020971
# Epoch: 972 Train loss: 0.0068424 Validation loss: 0.02097
# Epoch: 973 Train loss: 0.006841 Validation loss: 0.020968
# Epoch: 974 Train loss: 0.0068397 Validation loss: 0.020967
# Epoch: 975 Train loss: 0.0068384 Validation loss: 0.020965
# Epoch: 976 Train loss: 0.006837 Validation loss: 0.020964
# Epoch: 977 Train loss: 0.0068357 Validation loss: 0.020962
# Epoch: 978 Train loss: 0.0068344 Validation loss: 0.020961
# Epoch: 979 Train loss: 0.0068331 Validation loss: 0.02096
# Epoch: 980 Train loss: 0.0068318 Validation loss: 0.020958
# Epoch: 981 Train loss: 0.0068304 Validation loss: 0.020957
# Epoch: 982 Train loss: 0.0068291 Validation loss: 0.020955
# Epoch: 983 Train loss: 0.0068278 Validation loss: 0.020954
# Epoch: 984 Train loss: 0.0068265 Validation loss: 0.020952
# Epoch: 985 Train loss: 0.0068252 Validation loss: 0.020951
# Epoch: 986 Train loss: 0.0068239 Validation loss: 0.02095
# Epoch: 987 Train loss: 0.0068226 Validation loss: 0.020948
# Epoch: 988 Train loss: 0.0068213 Validation loss: 0.020947
# Epoch: 989 Train loss: 0.00682 Validation loss: 0.020945
# Epoch: 990 Train loss: 0.0068187 Validation loss: 0.020944
# Epoch: 991 Train loss: 0.0068174 Validation loss: 0.020943
# Epoch: 992 Train loss: 0.0068161 Validation loss: 0.020941
# Epoch: 993 Train loss: 0.0068148 Validation loss: 0.02094
# Epoch: 994 Train loss: 0.0068136 Validation loss: 0.020938
# Epoch: 995 Train loss: 0.0068123 Validation loss: 0.020937
# Epoch: 996 Train loss: 0.006811 Validation loss: 0.020935
# Epoch: 997 Train loss: 0.0068097 Validation loss: 0.020934
# Epoch: 998 Train loss: 0.0068084 Validation loss: 0.020933
# Epoch: 999 Train loss: 0.0068072 Validation loss: 0.020931

# %% [markdown]
# Predicting with this model shows overfitting. For recognizing overfitting a comparison of the validation and training loss is very useful. If the training loss decreases during training while the validation loss consistently increases, the model you are training is probably overfitting. Plotting the models prediction and the target also shows that there is a significant discrepancy between the target and the prediction of the model.

# %%
y_pred = big_mdl.__call__(x)# Predict on x with "big_mdl"
plt.scatter(x_train_overfit, y_train_overfit)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Target", "Prediction", "Training samples"])
plt.show()

# %% [markdown]
# In order to implement a regularization we need to modify the loss function. Since the loss function in this exercise is computed during the training step, we define a new training step with a regularization.

# %%
""" In order to avoid overfitting we implement a training step that also includes a regularization on the weights of our big model. For this we use the Frobenius/squared l2-norm of each weight matrix/vector. 
Hint: Use the tf.reduce_sum() function on a list of individual regularization terms for each matrix/vector of the network."""

def regularized_train_step(model, optimizer, x, y, lmbd):
    with tf.GradientTape() as tape:
        tape.watch(model.trainable_variables)
        y_pred = model.__call__ (x)# Compute a prediction with "model" on the input "x"
        y = tf.reshape(y, [-1,1])
        loss_val = tf.compat.v1.losses.mean_squared_error(y, y_pred) # Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y"
        regul_list = []
        for index in range(len(model.trainable_variables)):
            train_var =model.trainable_variables [index]
            #print(train_var)
            if index % 2 == 0:
                append_val = tf.norm(train_var)
            else:
                append_val = tf.pow(tf.norm(train_var, ord = 2),2)
            regul_list.append(append_val)
                #tf.pow(tf.linalg.norm(train_var, ord= 'fro', axis = [-2,-1]),2))
        regul_val = tf.reduce_sum(regul_list) # Compute the regularization based on the list "model.trainable_variables"
        total_loss = loss_val + lmbd * regul_val# Add the loss with a the regularization term weighted by "lmbd"
    grads = tape.gradient(total_loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    return loss_val
# regul_list = []
# for train_var in big_reg_mdl.trainable_variables:
#     #print(train_var)
#     regul_list.append(2*tf.nn.l2_loss(train_var))
#         #tf.pow(tf.linalg.norm(train_var, ord= 'fro', axis = [-2,-1]),2))
# regul_val = tf.reduce_sum(regul_list) # Compute the regularization based on the list "model.trainable_variables"
# print(regul_val)
# print(regul_list)
# total_loss = 0 + lmbd * regul_val

# %% [markdown]
# We can now set the strength of the regularization and retrain the big model with a regularization. We create another instance of the big model in order to compare the big model with and without regularization.

# %%
""" Implement the training for the bigger model with the regularized_train_step function. Note: We are plotting the MSE loss without the regularization in order to compare it with the unregularized model. """

lmbd = 0.005

big_reg_mdl = MyBigModel()
big_opt = tf.optimizers.SGD(learning_rate)

epoch = 0
train_iters = 0
train_loss = 0.0
for x_t, y_t in train_overfit_ds:
    train_loss += regularized_train_step(big_reg_mdl, big_opt, x_t, y_t, lmbd) # Perform a regularized training step with the model "big_mdl" and the optimizer "big_opt" on the inputs "x_t" and the corresponding targets "y_t" with the regularization parameter being "lmbd"
    train_iters += 1
    if train_iters == batch_size:# An epoch is completed
        for x_v, y_v in validation_ds:
            y_pred =big_reg_mdl.__call__(x_v) # Compute a prediction with "big_mdl" on the input "x_v"
            y_v = tf.reshape(y_v, [-1,1])
            validation_loss = tf.compat.v1.losses.mean_squared_error(y_v, y_pred)# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_v"
        print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
        train_iters = 0
        train_loss = 0.0
        train_reg = 0.0
        epoch += 1
    if (epoch == N_epochs):
        break

# %% [markdown]
# During the training of the regularized model we can already notice, that, although there is still a difference between training and validation loss, the validation loss decreases as the training loss dreases. The effect of the regularization becomes even more evident if we plot the predictions of the regularized model and the overfitting model.

# %%
""" We now want to plot the prediction of the regularized and unregularized big model. """

y_pred = big_reg_mdl.__call__(x)# Predict with "big_reg_mdl" on "x"
y_pred_overfit = big_mdl.__call__(x)# Predict with "reg_mdl" on "x"
plt.scatter(x_train_overfit, y_train_overfit)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.plot(x, y_pred_overfit.numpy())
plt.legend(["Target", "Regularization", "No regularization", "Training samples"])
plt.show()

# %% [markdown]
# The model with regularization seems to follow the overall trend of the data, while the model without any regularization very precisely fits the training samples. This is espacilly evident in the interval $\left[0,0.5\right]$, where the prediction of the unregularized model shows an oscillating behavior. Such oscillations are however not present in the ground truth and therefore undesirable. The regularized model on the other hand is not as flexible as the unregularized model and therefore does not fit the target function well in the interval $\left[2.25, 3.0\right]$.
#
# ## Conclusion
# In this exercise we revisited the mathematical background for a simple regression task and covered it's practical implementation in Tensorflow 2. We also explored the phenomenon of overfitting and derived different regularizations from a probabilistic perspective. This exercise covers a very simple task with a very basic neural architecture and is intended as a primer for the second part of the regression exercise, which is dealing with a bigger and more realistic problem. In this second part we will consider the problem of estimating the age of a person from a potrait picture.
